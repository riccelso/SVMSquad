# %% [markdown]
# # Fontes (biblioteca e links):

# %% [markdown]
# https://www.kaggle.com/olistbr/brazilian-ecommerce?select=olist_order_payments_dataset.csv

# %%
#!pip install pandas numpy matplotlib seaborn sklearn
# em caso de erro na importação do seaborn use -> %pip install seaborn

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import timedelta, datetime
sns.set()

from IPython.display import display
from IPython.display import Image
pd.set_option('display.max_columns', None)

# %% [markdown]
# # Estrutura dos dados:

# %%
Image('https://i.imgur.com/HRhd2Y0.png', width=700)

# %% [markdown]
# ## Informações sobre dataset:

# %% [markdown]
# #### customer_id:
#
# key to the orders dataset. Each order has a unique customer_id.
#
# #### customer_unique_id:
#
# unique identifier of a customer.
#
# #### customer_zip_code_prefix:
#
# first five digits of customer zip code
#
# #### customer_city:
#
# customer city name
#
# #### order_id:
#
# order unique identifier
#
# #### order_item_id:
#
# sequential number identifying number of items included in the same order.
#
# #### product_id:
#
# product unique identifier
#
# #### seller_id:
#
# seller unique identifier
#
# #### shipping_limit_date:
#
# Shows the seller shipping limit date for handling the order over to the logistic partner.
#
# #### price:
#
# price item
#
# #### freight_value;
#
# freight value item (if an order has more than one item the freight value is splitted between items)
#
# #### payment_sequential:
#
# a customer may pay an order with more than one payment method. If he does so, a sequence will be created to
#
# #### payment_type:
#
# method of payment chosen by the customer.
#
# #### payment_installments:
#
# number of installments chosen by the customer.
#
# #### review_score:
#
# Note ranging from 1 to 5 given by the customer on a satisfaction survey.
#
# #### review_comment_title:
#
# Comment title from the review left by the customer, in Portuguese.
#
# #### review_comment_message:
#
# Comment message from the review left by the customer, in Portuguese.
#
# #### review_creation_date:
#
# Shows the date in which the satisfaction survey was sent to the customer.
#
# #### review_answer_timestamp:
#
# Shows satisfaction survey answer timestamp.
#
# #### customer_id:
#
# key to the customer dataset. Each order has a unique customer_id.
#
# #### order_status:
#
# Reference to the order status (delivered, shipped, etc).
#
# #### order_purchase_timestamp:
#
# Shows the purchase timestamp.
#
# #### order_approved_at:
#
# Shows the payment approval timestamp.
#
# #### order_delivered_carrier_date:
#
# Shows the order posting timestamp. When it was handled to the logistic partner.
#
# #### order_delivered_customer_date:
#
# Shows the actual order delivery date to the customer.
#
# #### order_estimated_delivery_date:
#
# Shows the estimated delivery date that was informed to customer at the purchase moment.
#
# #### product_name_lenght:
#
# number of characters extracted from the product name.
#
# #### product_description_lenght:
#
# number of characters extracted from the product description.
#
# #### product_photos_qty:
#
# number of product published photos
#
# #### product_weight_g:
#
# product weight measured in grams.
#
# #### product_length_cm:
#
# product length measured in centimeters.
#
# #### product_height_cm:
#
# product height measured in centimeters.
#
# #### product_width_cm:
#
# product width measured in centimeters.

# %% [markdown]
# ### Atenção:
#
# 1. An order might have multiple items.
# 2. Each item might be fulfilled by a distinct seller.

# %% [markdown]
# ### Algumas anotações:
#
# 1.
# Olist is a Brazilian departmental store (marketplace) that operates in e-commerce segment, but is not an e-commerce itself (as she says). It operates as a SaaS (Software as a Service) technology company since 2015. It offers a marketplace solution (of e-commerce segment) to shopkeepers of all sizes (and for most segments) to increase their sales whether they have online presence or not.
#
# 2.
# Olist’s solution consists of three aspects: Software, Contracts with the main marketplaces and Reputation sharing. The diagram below shows how Olist links marketplaces, consumers (Portuguese: consumidores), and retailers (Portuguese: varejistas)
#
# 3.
# Olist:
# - … is a large department store within marketplaces.
# - … is connected to the main e-commerces of Brazil.
# - … does not buy products.
# - … does not keep products in stock.
# - … does not carry out shipping of any products offered in its store.
# - All products are sold and shipped by the thousands of shopkeepers (registered on Olist*) who sell through Olist.
# - Her strength lies in union of all participating shopkeepers, who are selling physical products.
# - Participant shopkeeper is responsible for separating, packing, and taking products to the logistics operator.

# %% [markdown]
# ## Desafio:
# - Modelo de machine learning que agrupe clientes como: ouro, prata e bronze
# - Features usadas -> receita média, quantidade de pedidos, retenção, recência

# %% [markdown]
# ## Observando estrutura dos arquivos:

# %%
import pathlib
x = tuple(pathlib.Path('.').rglob('olistcsv/*.csv'))
for i, each in enumerate(x): 
    print(i, each, sep='\n')
    v = pd.read_csv(x[i])
    print(tuple(v.columns))
    print(f'{v.shape[0]} lines', f'{v.shape[1]} columns\n')

# %% [markdown]
# ## Passo-a-passo:

# %% [markdown]
# Para conseguirmos variáveis relevantes para elaborar nosso modelo primeiro devemos tratar nossos dados para que obtenhamos uma estrutura organizada e o menos defeituosa possível para extrair as informações que precisamos. Iniciaremos este processo com as seguintes estapas:
# - Reunir os dados brutos através das chaves que os conectam ("primary keys" e "foreign keys" como no contexto de banco de dados).
# - Tratar os tipos de dados incorretos
# - Tratar os dados nulos
# - Fazer a seleção ou "criação" das variáveis necessárias através do feature selection
# - Criação do modelo a partir dessa reestruturação dos dados, formulando assim nossa variável explicada e nossas variáveis explicativas

# %% [markdown]
# # Raw datasets (extração bruta):

# %% [markdown]
# ### Anotações sobre os arquivos e colunas importantes:
# **olistcsv/olist_order_items_dataset.csv ->**
# o preço do produto é preço + frete
# order_id, product_id
#
# **olistcsv/olist_order_payments_dataset.csv ->**
# order_id, payment_sequential, payment_type, payment_installments, payment_value
#
# **olistcsv/olist_customers_dataset.csv -> informações sobre o cliente**
# customer_id, customer_unique_id
#
# **olistcsv/olist_order_reviews_dataset.csv ->**
# order_id, review_id, review_score, review_comment_message
#
# **time notes ->**
# considerar compra por tempo, quantidade, compra média no tempo, primeira e última compra

# %% [markdown]
# ### Lendo dados brutos:

# %%
# ADICIONAR ETAPA DO MinIO
raw_price_freight = pd.read_csv('olist_order_items_dataset.csv')
raw_payment = pd.read_csv('olist_order_payments_dataset.csv')
raw_client_review = pd.read_csv('olist_order_reviews_dataset.csv')
raw_orders_central = pd.read_csv('olist_orders_dataset.csv')
raw_costumer = pd.read_csv('olist_customers_dataset.csv')

# %% [markdown]
# ### Unindos as tabelas e descrevendo "shape" e colunas:

# %% [markdown]
# raw_orders_central # Tabela dimensão -> 'order_id', 'customer_id'
#
# raw_costumer # Tabela dimensão -> 'customer_id', 'customer_unique_id'
#
#
# raw_price_freight # Tabela fato
#
# raw_payment # Tabela fato
#
# raw_client_review # Tabela fato

# %%
# Formação de tabelas e seus vínculos explicativos

df1 = pd.merge(left=raw_orders_central, right=raw_costumer, on='customer_id', how='outer')
price_freight = pd.merge(left=raw_price_freight, right=df1, on='order_id', how='left')
payment = pd.merge(left=raw_payment, right=df1, on='order_id', how='left')
client_review = pd.merge(left=raw_client_review, right=df1, on='order_id', how='left')

# %%
del raw_client_review, raw_costumer, raw_orders_central, raw_payment, raw_price_freight

# %% [markdown]
# ## Uma investigação sobre a organização dos dados:

# %% [markdown]
# Queremos entender se **payment_value** representa a soma da coluna **price** e da coluna **freight_value**
#
# 1. Primeiramente usaremos os clientes com maior diversidade em seus pedidos:

# %%
display(price_freight[['customer_id', 'order_id']].value_counts().head(2))
display(price_freight[['customer_id', 'order_id']].value_counts().tail(1))

display(payment[['customer_id', 'order_id']].value_counts().head(2))
display(payment[['customer_id', 'order_id']].value_counts().tail(2))
# Out:
# customer_id                       order_id
# fc3d1daec319d62d49bfb5e1f83123e9  8272b63d03f5f79c56e9e4120aec44ef    21
# bd5d39761aa56689a265d95d8d32b8be  ab14fdcfbe524636d65ee38360e22ce8    20
# dtype: int64
# customer_id                       order_id
# 00012a2ce6f8dcda20d059ce98491703  5f79b5b0931d63f1a42989eb65b9da6e    1
# dtype: int64
# customer_id                       order_id
# 9af2372a1e49340278e7c1ef8d749f34  fa65dad1b0e818e3ccc5cb0e39231352    29
# 92cd3ec6e2d643d4ebd0e3d6238f69e2  ccf804e764ed5650cd8759557269dc13    26
# dtype: int64
# customer_id                       order_id
# a92dcbd9afbc87cfcf0923eed2df56ab  fb7e82c858b82e6021869acd02bff2ab    1
# 00012a2ce6f8dcda20d059ce98491703  5f79b5b0931d63f1a42989eb65b9da6e    1
# dtype: int64

# %% [markdown]
# ->

# %% [markdown]
# 2. Agora usaremos eles como nossas variáveis de comparação:
#
# **8272b63d03f5f79c56e9e4120aec44ef**,
#
# **1b15974a0141d54e36626dca3fdc731a**,
#
# **fa65dad1b0e818e3ccc5cb0e39231352**,
#
# **ccf804e764ed5650cd8759557269dc13**,
#
# **971602526032659f775bbbe5b9142179**,
#
# **4f601391cdfe2a3984a4b1680c2c3d9a**

# %%
def comparar_pedidos(df1, df2, cod_pedido):
    d1 = df1[df1['order_id'] == cod_pedido]
    d2 = df2[df2['order_id'] == cod_pedido]
    d1.columns = d2.columns = ['order_id', 'result']
    print(f'{d1["result"].to_numpy()[0]} == {d1["result"].to_numpy()[0]}')

# %%
newdf = price_freight.copy()
newdf['result'] = price_freight.price + price_freight.freight_value

test1 = payment.groupby('order_id', as_index=False).sum()[['order_id', 'payment_value']]
test2 = newdf.groupby('order_id', as_index=False).sum()[['order_id', 'result']]

lista = '8272b63d03f5f79c56e9e4120aec44ef, 1b15974a0141d54e36626dca3fdc731a, fa65dad1b0e818e3ccc5cb0e39231352, ccf804e764ed5650cd8759557269dc13, 971602526032659f775bbbe5b9142179, 4f601391cdfe2a3984a4b1680c2c3d9a'.split(', ')
awnser = np.arange(len(lista))

for order in lista:
    comparar_pedidos(test1, test2, order)
# Out:
# 196.11 == 196.11
# 2202.4 == 2202.4
# 457.99 == 457.99
# 62.680000000000014 == 62.680000000000014
# 251.64 == 251.64
# 174.11 == 174.11

# %% [markdown]
# Nossa investigação demonstrou que a soma da coluna "price" e "freight_value" agrupada pela colunar "Order_id" é a forma correta de se compreender a coluna "payment_value". Usamos esta investigação para podermos explicitar a igualdade entre as colunas que existem em diferentes tabelas (A tabela price_freight e a payment)

# %%
del newdf, test1, test2, lista, awnser

# %% [markdown]
# ## Tratando os tipos de dados:

# %%
def transform(df: pd.DataFrame, colunas: list) -> pd.DataFrame:
    for each in colunas:
        df[each] = pd.to_datetime(df[each], errors='coerce')
    df['customer_zip_code_prefix'].astype('object')

# %%
# payment.dtypes,
# price_freight.dtypes)

# Tabela client_review
colunas = ('review_creation_date review_answer_timestamp order_purchase_timestamp order_approved_at ' +
'order_delivered_carrier_date order_delivered_customer_date order_estimated_delivery_date').split()

transform(client_review, colunas)


# Tabela payment 
colunas = ('order_purchase_timestamp order_approved_at order_delivered_carrier_date'
          + ' order_delivered_customer_date order_estimated_delivery_date').split()

transform(payment, colunas)


# Tabela price_freight
colunas = ('shipping_limit_date order_purchase_timestamp order_approved_at order_delivered_carrier_date'
          + ' order_delivered_customer_date order_estimated_delivery_date').split()

transform(price_freight, colunas)

# %%
del colunas

# %% [markdown]
# ## Tratando dados nulos

# %%
price_freight.name = 'price_freight'
payment.name = 'payment'
client_review.name = 'client_review'

# %%
dados = [price_freight, payment, client_review]

for v in dados:
    print(f'Tabela {v.name.capitalize()}:')
    display(v.isna().sum()[v.isna().sum() > 0])
    print('-'*20, '\n')
# Out:
# Tabela Price_freight:
# order_approved_at                  15
# order_delivered_carrier_date     1194
# order_delivered_customer_date    2454
# dtype: int64
# --------------------
#
# Tabela Payment:
# order_approved_at                 175
# order_delivered_carrier_date     1888
# order_delivered_customer_date    3132
# dtype: int64
# --------------------
#
# Tabela Client_review:
# review_comment_title             87656
# review_comment_message           58247
# order_approved_at                  156
# order_delivered_carrier_date      1756
# order_delivered_customer_date     2865
# dtype: int64
# --------------------

# %% [markdown]
# Considerando que o modelo que será criado agrupara os clientes baseados nas variáveis **receita média**, **quantidade de pedidos**, **retenção** e **recência**, os valores nulos descritos por tabela e por coluna acima não afetam os resultados

# %% [markdown]
# # Investigando distribuição e composição dos dados:

# %% [markdown]
# ### Observando a distribuição dos dados numéricos:

# %%
num_att1 = price_freight.select_dtypes(include=['int', 'float']).drop(columns=['order_item_id', 'customer_zip_code_prefix'])
num_att2 = payment['payment_value']
num_att3 = client_review['review_score']


p1 = pd.concat([pd.Series(price_freight.price.skew()), pd.Series(price_freight.freight_value.skew())], axis=0, ignore_index=True)
p2 = pd.concat([pd.Series(price_freight.price.kurt()), pd.Series(price_freight.freight_value.kurt())], axis=0, ignore_index=True)
p2.index = p1.index = ['freight_value', 'price']

p = pd.concat([num_att1.describe().T, p1.T, p2.T], axis=1, ignore_index=True)
p.columns = ['count', 'mean', 'std', 'min', '25%', '50%', '75%', 'max', 'skew', 'kurtosis']
p
# Out:
#                   count        mean         std   min    25%    50%     75%  \
# price          112650.0  120.653739  183.633928  0.85  39.90  74.99  134.90
# freight_value  112650.0   19.990320   15.806405  0.00  13.08  16.26   21.15
#
#                    max      skew    kurtosis
# price          6735.00  5.639870   59.788253
# freight_value   409.68  7.923208  120.828298

# %% [markdown]
# Podemos perceber que ambas as distribuições são significativamente dispersas, o frete apesar de mt menos  possui a mesma caracteristica comportamental que o preço em que possuem boa parte de sua dispersão demonstrada no último quartil.
#
# Observemos agora sua distribuição em um gráfico para observar como se distribui a quantidade de dados em sua estrutura.

# %%
# Tabela Price_freight: ver distribuição do price, freight_value, order_purchase_timestamp (max, min e dist.)
# Tabela Payment: ver distribuição do payment_sequential, payment_type
# Tabela Client_review: ver distribuição do review_score, 

plt.figure(figsize=(16,8))

plt.subplot(2, 1, 1)
sns.kdeplot(price_freight.price, label='Price distribution', shade=True)
sns.kdeplot(payment.payment_value, label='Payment distribution', shade=True)
plt.annotate(
    'Maior valor da coluna "price"',
    (price_freight.price.max(), 0.0001),
    arrowprops=dict(facecolor='black', shrink=0.05),
    xytext=(price_freight.price.max(), 0.002),
    horizontalalignment='left',
    verticalalignment='top'
    )
plt.annotate(
    'Maior valor da coluna "payment.payment_value"',
    (payment.payment_value.max(), 0.0001),
    arrowprops=dict(facecolor='black', shrink=0.05),
    xytext=(payment.payment_value.max(), 0.003),
    horizontalalignment='right',
    verticalalignment='top'
    )
plt.annotate(
    'Maior valor da coluna "freight_value"',
    (price_freight.freight_value.max(), 0.0001),
    arrowprops=dict(facecolor='black', shrink=0.05),
    xytext=(price_freight.freight_value.max(), 0.004),
    horizontalalignment='left',
    verticalalignment='top'
    )
plt.legend(loc='best')

plt.subplot(2, 1, 2)
sns.kdeplot(price_freight.freight_value, label='Freight distribution', shade=True)
plt.annotate(
    'Maior valor da coluna "freight_value"',
    (price_freight.freight_value.max(), 0.001),
    arrowprops=dict(facecolor='black', shrink=0.05),
    xytext=(price_freight.freight_value.max(), 0.02),
    horizontalalignment='right',
    verticalalignment='top'
    )
plt.legend(loc='best')

plt.show()

# %%
# Plotar boxplot
plt.figure(figsize=(16,8))

for i, cl in enumerate(['price', 'freight_value']):
    plt.subplot(1, 2, i+1)
    sns.boxplot(x=price_freight[cl])

# %% [markdown]
# # Desenhar boxplot sem outliers -> FAZER

# %% [markdown]
# Torna-se possível, agora, perceber visualmente a capacidade de influência dos outliers sobre a estrutura. É importante notar onde está localizada a maior parte dos dados, se nos valores dispersos ou se nos valores concentrados para considerações finais

# %%
# Encontrar a contagem (unidades) de cada diferente preço e depois soma-los
p1 = price_freight.price.value_counts()[price_freight.price.value_counts() < 100].sum()
p2 = price_freight.price.value_counts()[price_freight.price.value_counts() > 100].sum()
ptotal = p1 + p2

print(f'Valores abaixo de 100: {p1} unidades', end=' --- ')
print(f'Porcentagem de {p1/ptotal:.2%}')
print()
print(f'Valores acima de 100: {p2} unidades', end=' --- ')
print(f'Porcentagem de {p2/ptotal:.2%}')
# Out:
# Valores abaixo de 100: 39400 unidades --- Porcentagem de 35.04%
#
# Valores acima de 100: 73050 unidades --- Porcentagem de 64.96%

# %% [markdown]
# Portanto, a conclusão que podemos tirar desses dados é que os outliers não são somente dados extraordinários que podemos considerar retira-los pois sua predominancia é consideravelmente maior que os dados menos dispersos (em torno da mediana)

# %%
del p1, p2, ptotal

# %% [markdown]
# ## Extraindo as colunas (features) para o modelo:

# %% [markdown]
# Antes de tudo devemos definir o que queremos e o que cada um desses objetivos significa:
# receita média, quantidade de pedidos, retenção, recência
# 1. **Quantidade de pedidos**: quantidade de pedidos realizados por cliente.
# 2. **Retenção**: Período de compras do cliente, o tempo inicial sobre tempo final de suas compras realizadas.
# 3. **Recência**: Diferença entre a data da última compra e a data de hoje.
# 4. **Receita média**: receita gerada por cliente sobre a quantidade de pedidos realizados (receita média gerada pelo cliente) ou sobre o período que ele comprou (receita média gerada por cliente sobre tempo).

# %%
# DELETAR ESTA CÉLULA
for d in dados: print(d.name, d.columns, sep='\n', end='\n\n')
# Out:
# price_freight
# Index(['order_id', 'order_item_id', 'product_id', 'seller_id',
#        'shipping_limit_date', 'price', 'freight_value', 'customer_id',
#        'order_status', 'order_purchase_timestamp', 'order_approved_at',
#        'order_delivered_carrier_date', 'order_delivered_customer_date',
#        'order_estimated_delivery_date', 'customer_unique_id',
#        'customer_zip_code_prefix', 'customer_city', 'customer_state'],
#       dtype='object')
#
# payment
# Index(['order_id', 'payment_sequential', 'payment_type',
#        'payment_installments', 'payment_value', 'customer_id', 'order_status',
#        'order_purchase_timestamp', 'order_approved_at',
#        'order_delivered_carrier_date', 'order_delivered_customer_date',
#        'order_estimated_delivery_date', 'customer_unique_id',
#        'customer_zip_code_prefix', 'customer_city', 'customer_state'],
#       dtype='object')
#
# client_review
# Index(['review_id', 'order_id', 'review_score', 'review_comment_title',
#        'review_comment_message', 'review_creation_date',
#        'review_answer_timestamp', 'customer_id', 'order_status',
#        'order_purchase_timestamp', 'order_approved_at',
#        'order_delivered_carrier_date', 'order_delivered_customer_date',
#        'order_estimated_delivery_date', 'customer_unique_id',
#        'customer_zip_code_prefix', 'customer_city', 'customer_state'],
#       dtype='object')

# %% [markdown]
# ### 1. Quantidade de pedidos:

# %% [markdown]
# Os dados abaixo descrevem a quantidade de compras feitas por cliente e a quantidade de itens por cliente

# %%
Cliente = dados[0][['customer_unique_id', 'order_id']].groupby(['customer_unique_id']).agg(['nunique','count']).sort_values([('order_id', 'count'), ('order_id', 'nunique')], ascending=False)
Cliente
# Out:
#                                  order_id
#                                   nunique count
# customer_unique_id
# c8460e4251689ba205045f3ea17884a1        4    24
# 4546caea018ad8c692964e3382debd19        1    21
# 698e1cf81d01a3d389d96145f7fa6df8        1    20
# c402f431464c72e27330a67f7b94d4fb        1    20
# 0f5ac8d5c31de21d2f25e24be15bbffb        2    18
# ...                                   ...   ...
# fffcc512b7dfecaffd80f13614af1d16        1     1
# fffea47cd6d3cc0a88bd621562a9d061        1     1
# ffff371b4d645b6ecea244b27531430a        1     1
# ffff5962728ec6157033ef9805bacc48        1     1
# ffffd2657e2aad2907e67c3e9daecbeb        1     1
#
# [95420 rows x 2 columns]

# %% [markdown]
# A partir da tabela encontrada extrairemos os dados da contagem de pedidos realizados por cliente (order_id + nunique)

# %%
Cliente = Cliente['order_id']['nunique'].sort_values(ascending=False)
Cliente
# Out:
# customer_unique_id
# 8d50f5eadf50201ccdcedfb9e2ac8455    16
# 3e43e6105506432c953e165fb2acf44c     9
# 6469f99c1f9dfae7733b25662e7f1782     7
# 1b6c7548a2a1f9037c1fd3ddfed95f33     7
# ca77025e7201e3b30c44b472ff346268     7
#                                     ..
# 9e4c1e8466ff1c0e9d7eaed108b74bdb     1
# 9e4c21635f640562de1a6976374fba03     1
# 9e4cec36a7f9294540b39950eade4190     1
# 9e4cffe6d5ed5cf8e03ceae1ff2c963e     1
# 6d2a77a5ce09274a069d85de67e3fd37     1
# Name: nunique, Length: 95420, dtype: int64

# %% [markdown]
# ### Etapa intermediária:

# %% [markdown]
# Visando encontrar a retenção e a recência iremos trabalhar com a variável tempo, analisando seu comportamento e anexado a tabela principal que usaremos para o modelo. Usaremos a coluna "order_purchase_timestamp" para tal análise

# %%
p2 = dados[0][['customer_unique_id', 'order_purchase_timestamp']].groupby(['customer_unique_id'], as_index=False).agg(['max', 'min'])['order_purchase_timestamp']
p2['time'] = p2['max'] - p2['min']
p2 = p2.reset_index()

# %% [markdown]
# substituiremos os valores que possuem "0 dias" de compra por "1 dia" de compra pois a diferença entre tempo máximo e mínimo das compras dos clientes que compraram somente uma vez gerou essa incoerência lógica.

# %%
p2.time[p2.time < timedelta(days=1)] = timedelta(days=1)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
p2.sort_values('time', ascending=False)
# Out:
#                      customer_unique_id                 max  \
# 19031  32ea3bdedab835c3aa6cb68ce66565ef 2018-06-28 11:46:04
# 76403  ccafc1c3f270410521c3c6f3b249870f 2018-06-07 19:03:12
# 80964  d8f3c4f441a9b59a29f977df16724f38 2018-08-24 17:52:59
# 55465  94e5ea5a8c1bf546db2739673060c43f 2018-05-09 13:49:19
# 50627  87b3f231705783eb2217e25851c0a45d 2018-05-04 11:14:37
# ...                                 ...                 ...
# 32158  560f0209de88107bec357f67dade4362 2018-05-16 09:20:00
# 32157  560a6e0ef8a24a50cd83690e297827ca 2017-05-02 21:33:57
# 32156  560a6282f0b9f4176cb56ff6024632d8 2018-08-01 15:25:31
# 32155  560a4662eb4a058fa759def32ff39feb 2018-04-01 20:56:06
# 95419  ffffd2657e2aad2907e67c3e9daecbeb 2017-05-02 20:18:45
#
#                       min              time
# 19031 2016-10-03 09:44:50 633 days 02:01:14
# 76403 2016-10-06 19:33:34 608 days 23:29:38
# 80964 2017-01-18 21:08:18 582 days 20:44:41
# 55465 2016-10-05 21:10:56 580 days 16:38:23
# 50627 2016-10-08 18:45:34 572 days 16:29:03
# ...                   ...               ...
# 32158 2018-05-16 09:20:00   1 days 00:00:00
# 32157 2017-05-02 21:33:57   1 days 00:00:00
# 32156 2018-08-01 15:25:31   1 days 00:00:00
# 32155 2018-04-01 20:56:06   1 days 00:00:00
# 95419 2017-05-02 20:18:45   1 days 00:00:00
#
# [95420 rows x 4 columns]

# %% [markdown]
# ### 2. Retenção:

# %% [markdown]
# Podemos ver a distribuição dos dados que demonstram a quantidade de clientes e seus respectivos tempos como clientes.

# %%
fig = plt.figure(figsize=(16, 8))
fig.suptitle('Distribuição do tempo de retenção dos clientes', fontsize=18)

top = p2.time.dt.days.value_counts().nlargest(1).index[0]

plt.subplot(1, 2, 1,)
sns.kdeplot(p2.time.dt.days, palette=sns.palettes.light_palette, shade=True, color='Green')
sns.kdeplot(p2.time[p2.time > timedelta(days=2)].dt.days, shade=True, color='Red')
plt.annotate(
    'Dados mais frequentes entre clientes\ncom mais de um dia de compra',
    (top+20, 0.006),
    arrowprops=dict(facecolor='black', shrink=0.01),
    xytext=(top+100, 0.02),
    horizontalalignment='left',
    verticalalignment='top'
)
plt.annotate(
    'Dados mais frequentes são os de um dia de compra',
    (0, 0.14),
    arrowprops=dict(facecolor='black', shrink=0.01),
    xytext=(100, 0.13),
    horizontalalignment='left',
    verticalalignment='top'
)
plt.xlabel('Distribuição de clientes por tempo de retenção')

plt.subplot(1, 2, 2)
sns.kdeplot(p2.time[p2.time > timedelta(days=2)].dt.days, shade=True, color='Red')
plt.xlabel('Distribuição de clientes por tempo de retenção\ndesconsiderando os menores que 1 dia')
plt.show()

# %%
dist = p2.time.dt.days.sort_values(ascending=False)
dist = pd.Series(np.where(dist == 1, dist.astype(str) + ' dia', dist.astype(str) + ' dias'))
((dist.value_counts().nlargest(4) / dist.value_counts().sum()).round(6) * 100).astype(str) + '%'
# Out:
# 1 dia     97.8809%
# 2 dias     0.0314%
# 6 dias     0.0314%
# 3 dias     0.0272%
# dtype: object

# %% [markdown]
# A visualização de dados acima nos permite enxergar com clareza como a quantidade de compras é feita em somente uma data específica, ou seja, baixa retenção dos clientes

# %% [markdown]
# Agora que compreendemos a composição dos dados que serão inseridos na nossa tabela X (variável explicativa), podemos prosseguir com esta união

# %%
Cliente = pd.merge(left=Cliente, right=p2[['customer_unique_id', 'time']], how='outer', on='customer_unique_id').sort_values('time', ascending=False)

# %% [markdown]
# ### 3. Recência:

# %% [markdown]
# Usaremos a coluna "max" para, através da data da última compra, realizarmos a comparação com a data de hoje visando encontrar o tempo de ausência desde a última compra

# %%
p2['recencia'] = np.array([datetime.today() for _ in range(p2['max'].shape[0])], dtype=np.datetime64) - p2['max']
Cliente = pd.merge(left=Cliente, right=p2[['customer_unique_id', 'recencia']], how='outer', on='customer_unique_id').sort_values('time', ascending=False)

# %%
Cliente.columns = 'cliente quantia_comprada retencao recencia'.split()

# %%
Cliente
# Out:
#                                 cliente  quantia_comprada          retencao  \
# 0      32ea3bdedab835c3aa6cb68ce66565ef                 3 633 days 02:01:14
# 1      ccafc1c3f270410521c3c6f3b249870f                 2 608 days 23:29:38
# 2      d8f3c4f441a9b59a29f977df16724f38                 2 582 days 20:44:41
# 3      94e5ea5a8c1bf546db2739673060c43f                 2 580 days 16:38:23
# 4      87b3f231705783eb2217e25851c0a45d                 2 572 days 16:29:03
# ...                                 ...               ...               ...
# 33177  9e4cec36a7f9294540b39950eade4190                 1   1 days 00:00:00
# 33176  9e4cffe6d5ed5cf8e03ceae1ff2c963e                 1   1 days 00:00:00
# 33175  9e506ab643a922808385ce4b235621f2                 1   1 days 00:00:00
# 33174  9e2c99c58eb12588795e939a6d1a0d68                 1   1 days 00:00:00
# 95419  6d2a77a5ce09274a069d85de67e3fd37                 1   1 days 00:00:00
#
#                        recencia
# 0     1304 days 05:47:01.436395
# 1     1324 days 22:29:53.534699
# 2     1246 days 23:40:06.541668
# 3     1354 days 03:43:46.502670
# 4     1359 days 06:18:28.494960
# ...                         ...
# 33177 1456 days 18:48:45.508435
# 33176 1381 days 18:10:12.508437
# 33175 1375 days 23:57:52.508438
# 33174 1431 days 18:54:41.508369
# 95419 1363 days 17:39:19.479794
#
# [95420 rows x 4 columns]

# %% [markdown]
# ### 4. Receita média:

# %% [markdown]
# Para encontrarmos a receita do total de compras feitas por cliente devemos realizar o agrupamento por cliente, soma-lo e anexa-lo na Tabela Cliente.

# %%
p1 = dados[0][['customer_unique_id', 'price', 'freight_value']].groupby('customer_unique_id', as_index=False).sum() #.groupby()

# MUDAR p1['receita_total_por_cliente'] PARA "p1.price" CASO A RECEITA NÃO DEVA CONSIDERAR O FRETE
# OU p1.rename({'price':'receita_total_por_cliente'}, axis=1) E DELETE A LINHA ABAIXO
p1['receita_total_por_cliente'] = p1.price + p1.freight_value
Cliente = pd.merge(left=Cliente, right=p1[['customer_unique_id', 'receita_total_por_cliente']], left_on='cliente', right_on='customer_unique_id', how='outer').drop(columns='customer_unique_id')

# %% [markdown]
# Agora seram formadas as duas últimas variáveis relacionadas a coluna da receita por cliente

# %%
Cliente['receita_media_por_quantia'] = Cliente['receita_total_por_cliente']/Cliente['quantia_comprada']
Cliente['receita_media_por_dia'] = Cliente['receita_total_por_cliente']/Cliente['retencao'].dt.days
Cliente.drop(columns='receita_total_por_cliente', inplace=True)
Cliente
# Out:
#                                 cliente  quantia_comprada          retencao  \
# 0      32ea3bdedab835c3aa6cb68ce66565ef                 3 633 days 02:01:14
# 1      ccafc1c3f270410521c3c6f3b249870f                 2 608 days 23:29:38
# 2      d8f3c4f441a9b59a29f977df16724f38                 2 582 days 20:44:41
# 3      94e5ea5a8c1bf546db2739673060c43f                 2 580 days 16:38:23
# 4      87b3f231705783eb2217e25851c0a45d                 2 572 days 16:29:03
# ...                                 ...               ...               ...
# 95415  9e4cec36a7f9294540b39950eade4190                 1   1 days 00:00:00
# 95416  9e4cffe6d5ed5cf8e03ceae1ff2c963e                 1   1 days 00:00:00
# 95417  9e506ab643a922808385ce4b235621f2                 1   1 days 00:00:00
# 95418  9e2c99c58eb12588795e939a6d1a0d68                 1   1 days 00:00:00
# 95419  6d2a77a5ce09274a069d85de67e3fd37                 1   1 days 00:00:00
#
#                        recencia  receita_media_por_quantia  \
# 0     1304 days 05:47:01.436395                     45.720
# 1     1324 days 22:29:53.534699                    103.755
# 2     1246 days 23:40:06.541668                     79.255
# 3     1354 days 03:43:46.502670                     93.585
# 4     1359 days 06:18:28.494960                    261.560
# ...                         ...                        ...
# 95415 1456 days 18:48:45.508435                    116.930
# 95416 1381 days 18:10:12.508437                     50.710
# 95417 1375 days 23:57:52.508438                    129.140
# 95418 1431 days 18:54:41.508369                     61.770
# 95419 1363 days 17:39:19.479794                     47.230
#
#        receita_media_por_dia
# 0                   0.216682
# 1                   0.341299
# 2                   0.272354
# 3                   0.322707
# 4                   0.914545
# ...                      ...
# 95415             116.930000
# 95416              50.710000
# 95417             129.140000
# 95418              61.770000
# 95419              47.230000
#
# [95420 rows x 6 columns]

# %%
X = Cliente.drop(columns='cliente')
X['retencao'] = X.retencao.dt.days
X['recencia'] = X.recencia.dt.days

# %% [markdown]
# Nenhuma constatação interessante obtida da correlação.

# %%
sns.heatmap(X.corr(), cmap='Blues', annot=True); plt.show()

# %% [markdown]
# # ------------------------------------------------------------------------

# %% [markdown]
# ### Preprocessamento

# %% [markdown]
# -> scalonar

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.cluster import KMeans, AgglomerativeClustering
from sklearn.decomposition import PCA
from sklearn.metrics import silhouette_score

# %%
X.drop('receita_media_por_dia', axis=1, inplace=True)
X
# Out:
#        quantia_comprada  retencao  recencia  receita_media_por_quantia
# 0                     3       633      1304                     45.720
# 1                     2       608      1324                    103.755
# 2                     2       582      1246                     79.255
# 3                     2       580      1354                     93.585
# 4                     2       572      1359                    261.560
# ...                 ...       ...       ...                        ...
# 95415                 1         1      1456                    116.930
# 95416                 1         1      1381                     50.710
# 95417                 1         1      1375                    129.140
# 95418                 1         1      1431                     61.770
# 95419                 1         1      1363                     47.230
#
# [95420 rows x 4 columns]

# %% [markdown]
# ### Explicação do porquê transformar os dados em uma escala igualitária

# %%
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(X)
scaled_data = pd.DataFrame(scaled_data)
scaled_data.columns = X.columns
scaled_data
# Out:
#        quantia_comprada  retencao  recencia  receita_media_por_quantia
# 0              0.133333  1.000000  0.092033                   0.002646
# 1              0.066667  0.960443  0.119505                   0.006896
# 2              0.066667  0.919304  0.012363                   0.005102
# 3              0.066667  0.916139  0.160714                   0.006151
# 4              0.066667  0.903481  0.167582                   0.018453
# ...                 ...       ...       ...                        ...
# 95415          0.000000  0.000000  0.300824                   0.007861
# 95416          0.000000  0.000000  0.197802                   0.003011
# 95417          0.000000  0.000000  0.189560                   0.008755
# 95418          0.000000  0.000000  0.266484                   0.003821
# 95419          0.000000  0.000000  0.173077                   0.002757
#
# [95420 rows x 4 columns]

# %% [markdown]
# ### Explicação do Kmeans:
# k-means é um método de segregar em torno de centros (centroides) diversos dados, criando o que analogamente na química chamamos de clustering que gera o efeito de particionar n observações dentre k grupos onde cada observação pertence ao grupo mais próximo da média.
# https://pt.wikipedia.org/wiki/K-means

# %%
km = KMeans(n_clusters=3, random_state=0).fit(scaled_data)
np.unique(km.labels_, return_counts=True)
# Out:
# (array([0, 1, 2], dtype=int32), array([36115, 36907, 22398]))

# %%
clustered = pd.concat([Cliente['cliente'], scaled_data, pd.Series(km.predict(scaled_data))], axis=1, ignore_index=True)
cols = ['cliente', 'quantia_comprada', 'retencao', 'recencia', 'receita_media_por_quantia', 'grupo']
clustered.columns = cols
clustered.sort_values(['retencao', 'receita_media_por_quantia'], ascending=False).head(10).style.background_gradient(subset=['receita_media_por_quantia', 'recencia', 'retencao'], cmap='Blues')
# Out:
# <style  type="text/css" >
# #T_5d8522e2_7ba9_11ec_8e30_0242ac1c0002row0_col2,#T_5d8522e2_7ba9_11ec_8e30_0242ac1c0002row4_col4,#T_5d8522e2_7ba9_11ec_8e30_0242ac1c0002row7_col3{
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }#T_5d8522e2_7ba9_11ec_8e30_0242ac1c0002row0_col3{
#             background-color:  #a5cde3;
#             color:  #000000;
#         }#T_5d8522e2_7ba9_11ec_8e30_0242ac1c0002row0_col4,#T_5d8522e2_7ba9_11ec_8e30_0242ac1c0002row2_col3,#T_5d8522e2_7ba9_11ec_8e30_0242ac1c0002row8_col3,#T_5d8522e2_7ba9_11ec_8e30_0242ac1c0002row9_col2{
#             background-color:  #f7fbff;
#             color:  #000000;
#         }#T_5d8522e2_7ba9_11ec_8e30_0242ac1c0002row1_col2{
#             background-color:  #1c6ab0;
#             color:  #f1f1f1;
#         }#T_5d8522e2_7ba9_11ec_8e30_0242ac1c0002row1_col3{
#             background-color:  #75b4d8;
#             color:  #000000;
#         }#T_5d8522e2_7ba9_11ec_8e30_0242ac1c0002row1_col4{
#             background-color:  #c1d9ed;
#             color:  #000000;
#         }#T_5d8522e2_7ba9_11ec_8e30_0242ac1c0002row2_col2{
#             background-color:  #5ca4d0;
#             color:  #000000;
#         }#T_5d8522e2_7ba9_11ec_8e30_0242ac1c0002row2_col4,#T_5d8522e2_7ba9_11ec_8e30_0242ac1c0002row6_col3{
#             background-color:  #d9e7f5;
#             color:  #000000;
#         }#T_5d8522e2_7ba9_11ec_8e30_0242ac1c0002row3_col2{
#             background-color:  #63a8d3;
#             color:  #000000;
#         }#T_5d8522e2_7ba9_11ec_8e30_0242ac1c0002row3_col3{
#             background-color:  #3989c1;
#             color:  #000000;
#         }#T_5d8522e2_7ba9_11ec_8e30_0242ac1c0002row3_col4{
#             background-color:  #ccdff1;
#             color:  #000000;
#         }#T_5d8522e2_7ba9_11ec_8e30_0242ac1c0002row4_col2{
#             background-color:  #7db8da;
#             color:  #000000;
#         }#T_5d8522e2_7ba9_11ec_8e30_0242ac1c0002row4_col3{
#             background-color:  #3181bd;
#             color:  #000000;
#         }#T_5d8522e2_7ba9_11ec_8e30_0242ac1c0002row5_col2{
#             background-color:  #dbe9f6;
#             color:  #000000;
#         }#T_5d8522e2_7ba9_11ec_8e30_0242ac1c0002row5_col3{
#             background-color:  #dae8f6;
#             color:  #000000;
#         }#T_5d8522e2_7ba9_11ec_8e30_0242ac1c0002row5_col4{
#             background-color:  #8fc2de;
#             color:  #000000;
#         }#T_5d8522e2_7ba9_11ec_8e30_0242ac1c0002row6_col2{
#             background-color:  #f0f6fd;
#             color:  #000000;
#         }#T_5d8522e2_7ba9_11ec_8e30_0242ac1c0002row6_col4{
#             background-color:  #deebf7;
#             color:  #000000;
#         }#T_5d8522e2_7ba9_11ec_8e30_0242ac1c0002row7_col2,#T_5d8522e2_7ba9_11ec_8e30_0242ac1c0002row8_col2{
#             background-color:  #f2f8fd;
#             color:  #000000;
#         }#T_5d8522e2_7ba9_11ec_8e30_0242ac1c0002row7_col4{
#             background-color:  #cbdef1;
#             color:  #000000;
#         }#T_5d8522e2_7ba9_11ec_8e30_0242ac1c0002row8_col4{
#             background-color:  #dfebf7;
#             color:  #000000;
#         }#T_5d8522e2_7ba9_11ec_8e30_0242ac1c0002row9_col3{
#             background-color:  #d1e2f3;
#             color:  #000000;
#         }#T_5d8522e2_7ba9_11ec_8e30_0242ac1c0002row9_col4{
#             background-color:  #d0e1f2;
#             color:  #000000;
#         }</style><table id="T_5d8522e2_7ba9_11ec_8e30_0242ac1c0002" class="dataframe"><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >cliente</th>        <th class="col_heading level0 col1" >quantia_comprada</th>        <th class="col_heading level0 col2" >retencao</th>        <th class="col_heading level0 col3" >recencia</th>        <th class="col_heading level0 col4" >receita_media_por_quantia</th>        <th class="col_heading level0 col5" >grupo</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_5d8522e2_7ba9_11ec_8e30_0242ac1c0002level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_5d8522e2_7ba9_11ec_8e30_0242ac1c0002row0_col0" class="data row0 col0" >32ea3bdedab835c3aa6cb68ce66565ef</td>
#                         <td id="T_5d8522e2_7ba9_11ec_8e30_0242ac1c0002row0_col1" class="data row0 col1" >0.133333</td>
#                         <td id="T_5d8522e2_7ba9_11ec_8e30_0242ac1c0002row0_col2" class="data row0 col2" >1.000000</td>
#                         <td id="T_5d8522e2_7ba9_11ec_8e30_0242ac1c0002row0_col3" class="data row0 col3" >0.092033</td>
#                         <td id="T_5d8522e2_7ba9_11ec_8e30_0242ac1c0002row0_col4" class="data row0 col4" >0.002646</td>
#                         <td id="T_5d8522e2_7ba9_11ec_8e30_0242ac1c0002row0_col5" class="data row0 col5" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_5d8522e2_7ba9_11ec_8e30_0242ac1c0002level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_5d8522e2_7ba9_11ec_8e30_0242ac1c0002row1_col0" class="data row1 col0" >ccafc1c3f270410521c3c6f3b249870f</td>
#                         <td id="T_5d8522e2_7ba9_11ec_8e30_0242ac1c0002row1_col1" class="data row1 col1" >0.066667</td>
#                         <td id="T_5d8522e2_7ba9_11ec_8e30_0242ac1c0002row1_col2" class="data row1 col2" >0.960443</td>
#                         <td id="T_5d8522e2_7ba9_11ec_8e30_0242ac1c0002row1_col3" class="data row1 col3" >0.119505</td>
#                         <td id="T_5d8522e2_7ba9_11ec_8e30_0242ac1c0002row1_col4" class="data row1 col4" >0.006896</td>
#                         <td id="T_5d8522e2_7ba9_11ec_8e30_0242ac1c0002row1_col5" class="data row1 col5" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_5d8522e2_7ba9_11ec_8e30_0242ac1c0002level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_5d8522e2_7ba9_11ec_8e30_0242ac1c0002row2_col0" class="data row2 col0" >d8f3c4f441a9b59a29f977df16724f38</td>
#                         <td id="T_5d8522e2_7ba9_11ec_8e30_0242ac1c0002row2_col1" class="data row2 col1" >0.066667</td>
#                         <td id="T_5d8522e2_7ba9_11ec_8e30_0242ac1c0002row2_col2" class="data row2 col2" >0.919304</td>
#                         <td id="T_5d8522e2_7ba9_11ec_8e30_0242ac1c0002row2_col3" class="data row2 col3" >0.012363</td>
#                         <td id="T_5d8522e2_7ba9_11ec_8e30_0242ac1c0002row2_col4" class="data row2 col4" >0.005102</td>
#                         <td id="T_5d8522e2_7ba9_11ec_8e30_0242ac1c0002row2_col5" class="data row2 col5" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_5d8522e2_7ba9_11ec_8e30_0242ac1c0002level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_5d8522e2_7ba9_11ec_8e30_0242ac1c0002row3_col0" class="data row3 col0" >94e5ea5a8c1bf546db2739673060c43f</td>
#                         <td id="T_5d8522e2_7ba9_11ec_8e30_0242ac1c0002row3_col1" class="data row3 col1" >0.066667</td>
#                         <td id="T_5d8522e2_7ba9_11ec_8e30_0242ac1c0002row3_col2" class="data row3 col2" >0.916139</td>
#                         <td id="T_5d8522e2_7ba9_11ec_8e30_0242ac1c0002row3_col3" class="data row3 col3" >0.160714</td>
#                         <td id="T_5d8522e2_7ba9_11ec_8e30_0242ac1c0002row3_col4" class="data row3 col4" >0.006151</td>
#                         <td id="T_5d8522e2_7ba9_11ec_8e30_0242ac1c0002row3_col5" class="data row3 col5" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_5d8522e2_7ba9_11ec_8e30_0242ac1c0002level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_5d8522e2_7ba9_11ec_8e30_0242ac1c0002row4_col0" class="data row4 col0" >87b3f231705783eb2217e25851c0a45d</td>
#                         <td id="T_5d8522e2_7ba9_11ec_8e30_0242ac1c0002row4_col1" class="data row4 col1" >0.066667</td>
#                         <td id="T_5d8522e2_7ba9_11ec_8e30_0242ac1c0002row4_col2" class="data row4 col2" >0.903481</td>
#                         <td id="T_5d8522e2_7ba9_11ec_8e30_0242ac1c0002row4_col3"

# %%
clustered.sort_values(['receita_media_por_quantia'], ascending=False).head(10).style.background_gradient(subset=['receita_media_por_quantia', 'recencia', 'retencao'], cmap='Blues')
# Out:
# <style  type="text/css" >
# #T_5d8f0d84_7ba9_11ec_8e30_0242ac1c0002row0_col2,#T_5d8f0d84_7ba9_11ec_8e30_0242ac1c0002row1_col2,#T_5d8f0d84_7ba9_11ec_8e30_0242ac1c0002row2_col2,#T_5d8f0d84_7ba9_11ec_8e30_0242ac1c0002row3_col2,#T_5d8f0d84_7ba9_11ec_8e30_0242ac1c0002row4_col2,#T_5d8f0d84_7ba9_11ec_8e30_0242ac1c0002row5_col2,#T_5d8f0d84_7ba9_11ec_8e30_0242ac1c0002row6_col2,#T_5d8f0d84_7ba9_11ec_8e30_0242ac1c0002row7_col2,#T_5d8f0d84_7ba9_11ec_8e30_0242ac1c0002row8_col2,#T_5d8f0d84_7ba9_11ec_8e30_0242ac1c0002row9_col2,#T_5d8f0d84_7ba9_11ec_8e30_0242ac1c0002row9_col3,#T_5d8f0d84_7ba9_11ec_8e30_0242ac1c0002row9_col4{
#             background-color:  #f7fbff;
#             color:  #000000;
#         }#T_5d8f0d84_7ba9_11ec_8e30_0242ac1c0002row0_col3{
#             background-color:  #529dcc;
#             color:  #000000;
#         }#T_5d8f0d84_7ba9_11ec_8e30_0242ac1c0002row0_col4,#T_5d8f0d84_7ba9_11ec_8e30_0242ac1c0002row2_col3{
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }#T_5d8f0d84_7ba9_11ec_8e30_0242ac1c0002row1_col3{
#             background-color:  #f0f6fd;
#             color:  #000000;
#         }#T_5d8f0d84_7ba9_11ec_8e30_0242ac1c0002row1_col4{
#             background-color:  #b5d4e9;
#             color:  #000000;
#         }#T_5d8f0d84_7ba9_11ec_8e30_0242ac1c0002row2_col4,#T_5d8f0d84_7ba9_11ec_8e30_0242ac1c0002row3_col4{
#             background-color:  #c2d9ee;
#             color:  #000000;
#         }#T_5d8f0d84_7ba9_11ec_8e30_0242ac1c0002row3_col3,#T_5d8f0d84_7ba9_11ec_8e30_0242ac1c0002row8_col4{
#             background-color:  #f4f9fe;
#             color:  #000000;
#         }#T_5d8f0d84_7ba9_11ec_8e30_0242ac1c0002row4_col3{
#             background-color:  #1561a9;
#             color:  #f1f1f1;
#         }#T_5d8f0d84_7ba9_11ec_8e30_0242ac1c0002row4_col4{
#             background-color:  #c8dcf0;
#             color:  #000000;
#         }#T_5d8f0d84_7ba9_11ec_8e30_0242ac1c0002row5_col3{
#             background-color:  #77b5d9;
#             color:  #000000;
#         }#T_5d8f0d84_7ba9_11ec_8e30_0242ac1c0002row5_col4{
#             background-color:  #d6e5f4;
#             color:  #000000;
#         }#T_5d8f0d84_7ba9_11ec_8e30_0242ac1c0002row6_col3{
#             background-color:  #eff6fc;
#             color:  #000000;
#         }#T_5d8f0d84_7ba9_11ec_8e30_0242ac1c0002row6_col4{
#             background-color:  #f1f7fd;
#             color:  #000000;
#         }#T_5d8f0d84_7ba9_11ec_8e30_0242ac1c0002row7_col3{
#             background-color:  #084f99;
#             color:  #f1f1f1;
#         }#T_5d8f0d84_7ba9_11ec_8e30_0242ac1c0002row7_col4{
#             background-color:  #f2f7fd;
#             color:  #000000;
#         }#T_5d8f0d84_7ba9_11ec_8e30_0242ac1c0002row8_col3{
#             background-color:  #e7f1fa;
#             color:  #000000;
#         }</style><table id="T_5d8f0d84_7ba9_11ec_8e30_0242ac1c0002" class="dataframe"><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >cliente</th>        <th class="col_heading level0 col1" >quantia_comprada</th>        <th class="col_heading level0 col2" >retencao</th>        <th class="col_heading level0 col3" >recencia</th>        <th class="col_heading level0 col4" >receita_media_por_quantia</th>        <th class="col_heading level0 col5" >grupo</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_5d8f0d84_7ba9_11ec_8e30_0242ac1c0002level0_row0" class="row_heading level0 row0" >32754</th>
#                         <td id="T_5d8f0d84_7ba9_11ec_8e30_0242ac1c0002row0_col0" class="data row0 col0" >0a0a92112bd4c708ca5fde585afaa872</td>
#                         <td id="T_5d8f0d84_7ba9_11ec_8e30_0242ac1c0002row0_col1" class="data row0 col1" >0.000000</td>
#                         <td id="T_5d8f0d84_7ba9_11ec_8e30_0242ac1c0002row0_col2" class="data row0 col2" >0.000000</td>
#                         <td id="T_5d8f0d84_7ba9_11ec_8e30_0242ac1c0002row0_col3" class="data row0 col3" >0.465659</td>
#                         <td id="T_5d8f0d84_7ba9_11ec_8e30_0242ac1c0002row0_col4" class="data row0 col4" >1.000000</td>
#                         <td id="T_5d8f0d84_7ba9_11ec_8e30_0242ac1c0002row0_col5" class="data row0 col5" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_5d8f0d84_7ba9_11ec_8e30_0242ac1c0002level0_row1" class="row_heading level0 row1" >32517</th>
#                         <td id="T_5d8f0d84_7ba9_11ec_8e30_0242ac1c0002row1_col0" class="data row1 col0" >763c8b1c9c68a0229c42c9fc6f662b93</td>
#                         <td id="T_5d8f0d84_7ba9_11ec_8e30_0242ac1c0002row1_col1" class="data row1 col1" >0.000000</td>
#                         <td id="T_5d8f0d84_7ba9_11ec_8e30_0242ac1c0002row1_col2" class="data row1 col2" >0.000000</td>
#                         <td id="T_5d8f0d84_7ba9_11ec_8e30_0242ac1c0002row1_col3" class="data row1 col3" >0.068681</td>
#                         <td id="T_5d8f0d84_7ba9_11ec_8e30_0242ac1c0002row1_col4" class="data row1 col4" >0.532081</td>
#                         <td id="T_5d8f0d84_7ba9_11ec_8e30_0242ac1c0002row1_col5" class="data row1 col5" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_5d8f0d84_7ba9_11ec_8e30_0242ac1c0002level0_row2" class="row_heading level0 row2" >67190</th>
#                         <td id="T_5d8f0d84_7ba9_11ec_8e30_0242ac1c0002row2_col0" class="data row2 col0" >dc4802a71eae9be1dd28f5d788ceb526</td>
#                         <td id="T_5d8f0d84_7ba9_11ec_8e30_0242ac1c0002row2_col1" class="data row2 col1" >0.000000</td>
#                         <td id="T_5d8f0d84_7ba9_11ec_8e30_0242ac1c0002row2_col2" class="data row2 col2" >0.000000</td>
#                         <td id="T_5d8f0d84_7ba9_11ec_8e30_0242ac1c0002row2_col3" class="data row2 col3" >0.778846</td>
#                         <td id="T_5d8f0d84_7ba9_11ec_8e30_0242ac1c0002row2_col4" class="data row2 col4" >0.506772</td>
#                         <td id="T_5d8f0d84_7ba9_11ec_8e30_0242ac1c0002row2_col5" class="data row2 col5" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_5d8f0d84_7ba9_11ec_8e30_0242ac1c0002level0_row3" class="row_heading level0 row3" >6521</th>
#                         <td id="T_5d8f0d84_7ba9_11ec_8e30_0242ac1c0002row3_col0" class="data row3 col0" >459bef486812aa25204be022145caa62</td>
#                         <td id="T_5d8f0d84_7ba9_11ec_8e30_0242ac1c0002row3_col1" class="data row3 col1" >0.000000</td>
#                         <td id="T_5d8f0d84_7ba9_11ec_8e30_0242ac1c0002row3_col2" class="data row3 col2" >0.000000</td>
#                         <td id="T_5d8f0d84_7ba9_11ec_8e30_0242ac1c0002row3_col3" class="data row3 col3" >0.053571</td>
#                         <td id="T_5d8f0d84_7ba9_11ec_8e30_0242ac1c0002row3_col4" class="data row3 col4" >0.506253</td>
#                         <td id="T_5d8f0d84_7ba9_11ec_8e30_0242ac1c0002row3_col5" class="data row3 col5" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_5d8f0d84_7ba9_11ec_8e30_0242ac1c0002level0_row4" class="row_heading level0 row4" >63411</th>
#                         <td id="T_5d8f0d84_7ba9_11ec_8e30_0242ac1c0002row4_col0" class="data row4 col0" >ff4159b92c40ebe40454e3e6a7c35ed6</td>
#                         <td id="T_5d8f0d84_7ba9_11ec_8e30_0242ac1c0002row4_col1" class="data row4 col1" >0.000000</td>
#                         <td id="T_5d8f0d84_7ba9_11ec_8e30_0242ac1c0002row4_col2" class="data row4 col2" >0.000000</td>
#                         <td id="T_5d8f0d84_7ba9_11ec_8e30_0242ac1c0002row4_col3" class="data row4 col3" >0.640110</td>
#                         <td id="T_5d8f0d84_7ba9_11ec_8e30_0242ac1c0002row4_col4" class="data row4 col4" >0.491931</td>
#                         <td id="T_5d8f0d84_7ba9_11ec_8e30_0242ac1c0002row4_col5" class="data row4 col5" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_5d8f0d84_7ba9_11ec_8e30_0242ac1c0002level0_row5" class="row_heading level0 row5" >32700</th>
#                         <td id="T_5d8f0d84_7ba9_11ec_8e30_0242ac1c0002row5_col0" class="data row5 col0"

# %% [markdown]
# ### MinMax + PCA + Kmeans

# %%
pca2 = PCA(n_components=2, random_state=0)
pca2 = pca2.fit_transform(scaled_data)

p2 = pd.DataFrame(pca2)

km2 = KMeans(n_clusters=3, random_state=0).fit(p2)
np.unique(km2.labels_, return_counts=True)
# Out:
# (array([0, 1, 2], dtype=int32), array([22543, 36732, 36145]))

# %%
print(np.unique(km.labels_, return_counts=True),
np.unique(km2.labels_, return_counts=True), sep='\n')
# Out:
# (array([0, 1, 2], dtype=int32), array([36115, 36907, 22398]))
# (array([0, 1, 2], dtype=int32), array([22543, 36732, 36145]))

# %%
clustered2 = pd.concat([Cliente['cliente'], p2, pd.Series(km2.predict(p2))], axis=1, ignore_index=True)
cols = ['cliente', 'var_1', 'var_2', 'grupo']
clustered2.columns = cols

# %%
clustered2.sort_values(['var_2', 'var_1'], ascending=False).head(10).style.background_gradient(subset=['var_2', 'var_1'], cmap='Blues')
# Out:
# <style  type="text/css" >
# #T_5e8b95e0_7ba9_11ec_8e30_0242ac1c0002row0_col1{
#             background-color:  #a8cee4;
#             color:  #000000;
#         }#T_5e8b95e0_7ba9_11ec_8e30_0242ac1c0002row0_col2,#T_5e8b95e0_7ba9_11ec_8e30_0242ac1c0002row8_col1{
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }#T_5e8b95e0_7ba9_11ec_8e30_0242ac1c0002row1_col1{
#             background-color:  #77b5d9;
#             color:  #000000;
#         }#T_5e8b95e0_7ba9_11ec_8e30_0242ac1c0002row1_col2{
#             background-color:  #2c7cba;
#             color:  #000000;
#         }#T_5e8b95e0_7ba9_11ec_8e30_0242ac1c0002row2_col1{
#             background-color:  #f2f7fd;
#             color:  #000000;
#         }#T_5e8b95e0_7ba9_11ec_8e30_0242ac1c0002row2_col2{
#             background-color:  #4493c7;
#             color:  #000000;
#         }#T_5e8b95e0_7ba9_11ec_8e30_0242ac1c0002row3_col1,#T_5e8b95e0_7ba9_11ec_8e30_0242ac1c0002row9_col2{
#             background-color:  #f7fbff;
#             color:  #000000;
#         }#T_5e8b95e0_7ba9_11ec_8e30_0242ac1c0002row3_col2{
#             background-color:  #71b1d7;
#             color:  #000000;
#         }#T_5e8b95e0_7ba9_11ec_8e30_0242ac1c0002row4_col1{
#             background-color:  #3a8ac2;
#             color:  #000000;
#         }#T_5e8b95e0_7ba9_11ec_8e30_0242ac1c0002row4_col2{
#             background-color:  #74b3d8;
#             color:  #000000;
#         }#T_5e8b95e0_7ba9_11ec_8e30_0242ac1c0002row5_col1{
#             background-color:  #3282be;
#             color:  #000000;
#         }#T_5e8b95e0_7ba9_11ec_8e30_0242ac1c0002row5_col2{
#             background-color:  #8fc2de;
#             color:  #000000;
#         }#T_5e8b95e0_7ba9_11ec_8e30_0242ac1c0002row6_col1{
#             background-color:  #d9e8f5;
#             color:  #000000;
#         }#T_5e8b95e0_7ba9_11ec_8e30_0242ac1c0002row6_col2{
#             background-color:  #d1e2f3;
#             color:  #000000;
#         }#T_5e8b95e0_7ba9_11ec_8e30_0242ac1c0002row7_col1{
#             background-color:  #d9e7f5;
#             color:  #000000;
#         }#T_5e8b95e0_7ba9_11ec_8e30_0242ac1c0002row7_col2{
#             background-color:  #e5eff9;
#             color:  #000000;
#         }#T_5e8b95e0_7ba9_11ec_8e30_0242ac1c0002row8_col2{
#             background-color:  #f5f9fe;
#             color:  #000000;
#         }#T_5e8b95e0_7ba9_11ec_8e30_0242ac1c0002row9_col1{
#             background-color:  #f6faff;
#             color:  #000000;
#         }</style><table id="T_5e8b95e0_7ba9_11ec_8e30_0242ac1c0002" class="dataframe"><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >cliente</th>        <th class="col_heading level0 col1" >var_1</th>        <th class="col_heading level0 col2" >var_2</th>        <th class="col_heading level0 col3" >grupo</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_5e8b95e0_7ba9_11ec_8e30_0242ac1c0002level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_5e8b95e0_7ba9_11ec_8e30_0242ac1c0002row0_col0" class="data row0 col0" >32ea3bdedab835c3aa6cb68ce66565ef</td>
#                         <td id="T_5e8b95e0_7ba9_11ec_8e30_0242ac1c0002row0_col1" class="data row0 col1" >-0.254387</td>
#                         <td id="T_5e8b95e0_7ba9_11ec_8e30_0242ac1c0002row0_col2" class="data row0 col2" >0.996652</td>
#                         <td id="T_5e8b95e0_7ba9_11ec_8e30_0242ac1c0002row0_col3" class="data row0 col3" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_5e8b95e0_7ba9_11ec_8e30_0242ac1c0002level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_5e8b95e0_7ba9_11ec_8e30_0242ac1c0002row1_col0" class="data row1 col0" >ccafc1c3f270410521c3c6f3b249870f</td>
#                         <td id="T_5e8b95e0_7ba9_11ec_8e30_0242ac1c0002row1_col1" class="data row1 col1" >-0.226323</td>
#                         <td id="T_5e8b95e0_7ba9_11ec_8e30_0242ac1c0002row1_col2" class="data row1 col2" >0.943397</td>
#                         <td id="T_5e8b95e0_7ba9_11ec_8e30_0242ac1c0002row1_col3" class="data row1 col3" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_5e8b95e0_7ba9_11ec_8e30_0242ac1c0002level0_row2" class="row_heading level0 row2" >28</th>
#                         <td id="T_5e8b95e0_7ba9_11ec_8e30_0242ac1c0002row2_col0" class="data row2 col0" >8d50f5eadf50201ccdcedfb9e2ac8455</td>
#                         <td id="T_5e8b95e0_7ba9_11ec_8e30_0242ac1c0002row2_col1" class="data row2 col1" >-0.326592</td>
#                         <td id="T_5e8b95e0_7ba9_11ec_8e30_0242ac1c0002row2_col2" class="data row2 col2" >0.926219</td>
#                         <td id="T_5e8b95e0_7ba9_11ec_8e30_0242ac1c0002row2_col3" class="data row2 col3" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_5e8b95e0_7ba9_11ec_8e30_0242ac1c0002level0_row3" class="row_heading level0 row3" >2</th>
#                         <td id="T_5e8b95e0_7ba9_11ec_8e30_0242ac1c0002row3_col0" class="data row3 col0" >d8f3c4f441a9b59a29f977df16724f38</td>
#                         <td id="T_5e8b95e0_7ba9_11ec_8e30_0242ac1c0002row3_col1" class="data row3 col1" >-0.332951</td>
#                         <td id="T_5e8b95e0_7ba9_11ec_8e30_0242ac1c0002row3_col2" class="data row3 col2" >0.902006</td>
#                         <td id="T_5e8b95e0_7ba9_11ec_8e30_0242ac1c0002row3_col3" class="data row3 col3" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_5e8b95e0_7ba9_11ec_8e30_0242ac1c0002level0_row4" class="row_heading level0 row4" >3</th>
#                         <td id="T_5e8b95e0_7ba9_11ec_8e30_0242ac1c0002row4_col0" class="data row4 col0" >94e5ea5a8c1bf546db2739673060c43f</td>
#                         <td id="T_5e8b95e0_7ba9_11ec_8e30_0242ac1c0002row4_col1" class="data row4 col1" >-0.184572</td>
#                         <td id="T_5e8b95e0_7ba9_11ec_8e30_0242ac1c0002row4_col2" class="data row4 col2" >0.900752</td>
#                         <td id="T_5e8b95e0_7ba9_11ec_8e30_0242ac1c0002row4_col3" class="data row4 col3" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_5e8b95e0_7ba9_11ec_8e30_0242ac1c0002level0_row5" class="row_heading level0 row5" >4</th>
#                         <td id="T_5e8b95e0_7ba9_11ec_8e30_0242ac1c0002row5_col0" class="data row5 col0" >87b3f231705783eb2217e25851c0a45d</td>
#                         <td id="T_5e8b95e0_7ba9_11ec_8e30_0242ac1c0002row5_col1" class="data row5 col1" >-0.177548</td>
#                         <td id="T_5e8b95e0_7ba9_11ec_8e30_0242ac1c0002row5_col2" class="data row5 col2" >0.888459</td>
#                         <td id="T_5e8b95e0_7ba9_11ec_8e30_0242ac1c0002row5_col3" class="data row5 col3" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_5e8b95e0_7ba9_11ec_8e30_0242ac1c0002level0_row6" class="row_heading level0 row6" >5</th>
#                         <td id="T_5e8b95e0_7ba9_11ec_8e30_0242ac1c0002row6_col0" class="data row6 col0" >8f6ce2295bdbec03cd50e34b4bd7ba0a</td>
#                         <td id="T_5e8b95e0_7ba9_11ec_8e30_0242ac1c0002row6_col1" class="data row6 col1" >-0.299217</td>
#                         <td id="T_5e8b95e0_7ba9_11ec_8e30_0242ac1c0002row6_col2" class="data row6 col2" >0.848084</td>
#                         <td id="T_5e8b95e0_7ba9_11ec_8e30_0242ac1c0002row6_col3" class="data row6 col3" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_5e8b95e0_7ba9_11ec_8e30_0242ac1c0002level0_row7" class="row_heading level0 row7" >6</th>
#                         <td id="T_5e8b95e0_7ba9_11ec_8e30_0242ac1c0002row7_col0" class="data row7 col0" >30b782a79466007756f170cb5bd6bbd8</td>
#                         <td id="T_5e8b95e0_7ba9_11ec_8e30_0242ac1c0002row7_col1" class="data row7 col1" >-0.297610</td>
#                         <td id="T_5e8b95e0_7ba9_11ec_8e30_0242ac1c0002row7_col2" class="data row7 col2" >0.829622</td>
#                         <td id="T_5e8b95e0_7ba9_11ec_8e30_0242ac1c0002row7_col3" class="data row7 col3"

# %%
clustered2.sort_values(['var_1'], ascending=False).head(10).style.background_gradient(subset=['var_1', 'var_2'], cmap='Blues')
# Out:
# <style  type="text/css" >
# #T_5e944c44_7ba9_11ec_8e30_0242ac1c0002row0_col1,#T_5e944c44_7ba9_11ec_8e30_0242ac1c0002row1_col1,#T_5e944c44_7ba9_11ec_8e30_0242ac1c0002row1_col2{
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }#T_5e944c44_7ba9_11ec_8e30_0242ac1c0002row0_col2{
#             background-color:  #083674;
#             color:  #f1f1f1;
#         }#T_5e944c44_7ba9_11ec_8e30_0242ac1c0002row2_col1{
#             background-color:  #3a8ac2;
#             color:  #000000;
#         }#T_5e944c44_7ba9_11ec_8e30_0242ac1c0002row2_col2{
#             background-color:  #2b7bba;
#             color:  #000000;
#         }#T_5e944c44_7ba9_11ec_8e30_0242ac1c0002row3_col1,#T_5e944c44_7ba9_11ec_8e30_0242ac1c0002row4_col1{
#             background-color:  #f1f7fd;
#             color:  #000000;
#         }#T_5e944c44_7ba9_11ec_8e30_0242ac1c0002row3_col2{
#             background-color:  #c3daee;
#             color:  #000000;
#         }#T_5e944c44_7ba9_11ec_8e30_0242ac1c0002row4_col2{
#             background-color:  #b9d6ea;
#             color:  #000000;
#         }#T_5e944c44_7ba9_11ec_8e30_0242ac1c0002row5_col1,#T_5e944c44_7ba9_11ec_8e30_0242ac1c0002row5_col2,#T_5e944c44_7ba9_11ec_8e30_0242ac1c0002row6_col1,#T_5e944c44_7ba9_11ec_8e30_0242ac1c0002row7_col1,#T_5e944c44_7ba9_11ec_8e30_0242ac1c0002row8_col1,#T_5e944c44_7ba9_11ec_8e30_0242ac1c0002row9_col1{
#             background-color:  #f7fbff;
#             color:  #000000;
#         }#T_5e944c44_7ba9_11ec_8e30_0242ac1c0002row6_col2{
#             background-color:  #e1edf8;
#             color:  #000000;
#         }#T_5e944c44_7ba9_11ec_8e30_0242ac1c0002row7_col2{
#             background-color:  #dae8f6;
#             color:  #000000;
#         }#T_5e944c44_7ba9_11ec_8e30_0242ac1c0002row8_col2{
#             background-color:  #d7e6f5;
#             color:  #000000;
#         }#T_5e944c44_7ba9_11ec_8e30_0242ac1c0002row9_col2{
#             background-color:  #d6e6f4;
#             color:  #000000;
#         }</style><table id="T_5e944c44_7ba9_11ec_8e30_0242ac1c0002" class="dataframe"><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >cliente</th>        <th class="col_heading level0 col1" >var_1</th>        <th class="col_heading level0 col2" >var_2</th>        <th class="col_heading level0 col3" >grupo</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_5e944c44_7ba9_11ec_8e30_0242ac1c0002level0_row0" class="row_heading level0 row0" >27614</th>
#                         <td id="T_5e944c44_7ba9_11ec_8e30_0242ac1c0002row0_col0" class="data row0 col0" >b7d76e111c89f7ebf14761390f0f7d17</td>
#                         <td id="T_5e944c44_7ba9_11ec_8e30_0242ac1c0002row0_col1" class="data row0 col1" >0.666033</td>
#                         <td id="T_5e944c44_7ba9_11ec_8e30_0242ac1c0002row0_col2" class="data row0 col2" >0.003637</td>
#                         <td id="T_5e944c44_7ba9_11ec_8e30_0242ac1c0002row0_col3" class="data row0 col3" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_5e944c44_7ba9_11ec_8e30_0242ac1c0002level0_row1" class="row_heading level0 row1" >6365</th>
#                         <td id="T_5e944c44_7ba9_11ec_8e30_0242ac1c0002row1_col0" class="data row1 col0" >4854e9b3feff728c13ee5fc7d1547e92</td>
#                         <td id="T_5e944c44_7ba9_11ec_8e30_0242ac1c0002row1_col1" class="data row1 col1" >0.666033</td>
#                         <td id="T_5e944c44_7ba9_11ec_8e30_0242ac1c0002row1_col2" class="data row1 col2" >0.003654</td>
#                         <td id="T_5e944c44_7ba9_11ec_8e30_0242ac1c0002row1_col3" class="data row1 col3" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_5e944c44_7ba9_11ec_8e30_0242ac1c0002level0_row2" class="row_heading level0 row2" >31427</th>
#                         <td id="T_5e944c44_7ba9_11ec_8e30_0242ac1c0002row2_col0" class="data row2 col0" >830d5b7aaa3b6f1e9ad63703bec97d23</td>
#                         <td id="T_5e944c44_7ba9_11ec_8e30_0242ac1c0002row2_col1" class="data row2 col1" >0.652298</td>
#                         <td id="T_5e944c44_7ba9_11ec_8e30_0242ac1c0002row2_col2" class="data row2 col2" >0.003465</td>
#                         <td id="T_5e944c44_7ba9_11ec_8e30_0242ac1c0002row2_col3" class="data row2 col3" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_5e944c44_7ba9_11ec_8e30_0242ac1c0002level0_row3" class="row_heading level0 row3" >42827</th>
#                         <td id="T_5e944c44_7ba9_11ec_8e30_0242ac1c0002row3_col0" class="data row3 col0" >0eb1ee9dba87f5b36b4613a65074337c</td>
#                         <td id="T_5e944c44_7ba9_11ec_8e30_0242ac1c0002row3_col1" class="data row3 col1" >0.627574</td>
#                         <td id="T_5e944c44_7ba9_11ec_8e30_0242ac1c0002row3_col2" class="data row3 col2" >0.003169</td>
#                         <td id="T_5e944c44_7ba9_11ec_8e30_0242ac1c0002row3_col3" class="data row3 col3" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_5e944c44_7ba9_11ec_8e30_0242ac1c0002level0_row4" class="row_heading level0 row4" >9684</th>
#                         <td id="T_5e944c44_7ba9_11ec_8e30_0242ac1c0002row4_col0" class="data row4 col0" >2f64e403852e6893ae37485d5fcacdaf</td>
#                         <td id="T_5e944c44_7ba9_11ec_8e30_0242ac1c0002row4_col1" class="data row4 col1" >0.627574</td>
#                         <td id="T_5e944c44_7ba9_11ec_8e30_0242ac1c0002row4_col2" class="data row4 col2" >0.003189</td>
#                         <td id="T_5e944c44_7ba9_11ec_8e30_0242ac1c0002row4_col3" class="data row4 col3" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_5e944c44_7ba9_11ec_8e30_0242ac1c0002level0_row5" class="row_heading level0 row5" >6415</th>
#                         <td id="T_5e944c44_7ba9_11ec_8e30_0242ac1c0002row5_col0" class="data row5 col0" >45d9410bc1f3c6e36dea41d8f823ada6</td>
#                         <td id="T_5e944c44_7ba9_11ec_8e30_0242ac1c0002row5_col1" class="data row5 col1" >0.626202</td>
#                         <td id="T_5e944c44_7ba9_11ec_8e30_0242ac1c0002row5_col2" class="data row5 col2" >0.002999</td>
#                         <td id="T_5e944c44_7ba9_11ec_8e30_0242ac1c0002row5_col3" class="data row5 col3" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_5e944c44_7ba9_11ec_8e30_0242ac1c0002level0_row6" class="row_heading level0 row6" >10249</th>
#                         <td id="T_5e944c44_7ba9_11ec_8e30_0242ac1c0002row6_col0" class="data row6 col0" >2ad10f49ef1f061d5f6739c89d3ade68</td>
#                         <td id="T_5e944c44_7ba9_11ec_8e30_0242ac1c0002row6_col1" class="data row6 col1" >0.626201</td>
#                         <td id="T_5e944c44_7ba9_11ec_8e30_0242ac1c0002row6_col2" class="data row6 col2" >0.003072</td>
#                         <td id="T_5e944c44_7ba9_11ec_8e30_0242ac1c0002row6_col3" class="data row6 col3" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_5e944c44_7ba9_11ec_8e30_0242ac1c0002level0_row7" class="row_heading level0 row7" >76912</th>
#                         <td id="T_5e944c44_7ba9_11ec_8e30_0242ac1c0002row7_col0" class="data row7 col0" >8d36e7e56a9f8044df728e9cbf5a3eaf</td>
#                         <td id="T_5e944c44_7ba9_11ec_8e30_0242ac1c0002row7_col1" class="data row7 col1" >0.626201</td>
#                         <td id="T_5e944c44_7ba9_11ec_8e30_0242ac1c0002row7_col2" class="data row7 col2" >0.003094</td>
#                         <td id="T_5e944c44_7ba9_11ec_8e30_0242ac1c0002row7_col3" class="data row7 col3" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_5e944c44_7ba9_11ec_8e30_0242ac1c0002level0_row8" class="row_heading level0 row8" >40068</th>
#                         <td id="T_5e944c44_7ba9_11ec_8e30_0242ac1c0002row8_col0" class="data row8 col0" >28706b8dc0fe2a95fbcec1e53253d8e4</td>
#                         <td id="T_5e944c44_7ba9_11ec_8e30_0242ac1c0002row8_col1" class="data row8 col1" >0.626201</td>

# %% [markdown]
# Dedução do comportamento dos dados:
# -> variáveis que caminham em direção oposta como: recencia e receita; gerando assim uma aparência de tradeoff nas variáveis

# %%
sns.scatterplot(x='var_1', y='var_2', hue='grupo', data=clustered2)
plt.show()

# %%
clustered2[['var_1', 'var_2']].corr().style.format({'var_1':'{:,.4f}', 'var_2':'{:,.4f}'})
# Out:
# <style  type="text/css" >
# </style><table id="T_60e38c4e_7ba9_11ec_8e30_0242ac1c0002" class="dataframe"><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >var_1</th>        <th class="col_heading level0 col1" >var_2</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_60e38c4e_7ba9_11ec_8e30_0242ac1c0002level0_row0" class="row_heading level0 row0" >var_1</th>
#                         <td id="T_60e38c4e_7ba9_11ec_8e30_0242ac1c0002row0_col0" class="data row0 col0" >1.0000</td>
#                         <td id="T_60e38c4e_7ba9_11ec_8e30_0242ac1c0002row0_col1" class="data row0 col1" >0.0000</td>
#             </tr>
#             <tr>
#                         <th id="T_60e38c4e_7ba9_11ec_8e30_0242ac1c0002level0_row1" class="row_heading level0 row1" >var_2</th>
#                         <td id="T_60e38c4e_7ba9_11ec_8e30_0242ac1c0002row1_col0" class="data row1 col0" >0.0000</td>
#                         <td id="T_60e38c4e_7ba9_11ec_8e30_0242ac1c0002row1_col1" class="data row1 col1" >1.0000</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ### PCA com 3

# %%
pca3 = PCA(n_components=3, random_state=0)
pca3 = pca3.fit_transform(scaled_data)

p3 = pd.DataFrame(pca3)

km3 = KMeans(n_clusters=3, random_state=0).fit(p3)
np.unique(km3.labels_, return_counts=True)
# Out:
# (array([0, 1, 2], dtype=int32), array([36115, 36907, 22398]))

# %%
clustered3 = pd.concat([Cliente['cliente'], p3, pd.Series(km3.predict(p3))], axis=1, ignore_index=True)
cols = ['cliente', 'var_1', 'var_2', 'var_3', 'grupo']
clustered3.columns = cols
clustered3.sort_values('var_1', ascending=False).head(10).style.background_gradient(subset=['var_1', 'var_2', 'var_3'], cmap='Blues')
# Out:
# <style  type="text/css" >
# #T_61efce0e_7ba9_11ec_8e30_0242ac1c0002row0_col1,#T_61efce0e_7ba9_11ec_8e30_0242ac1c0002row1_col1,#T_61efce0e_7ba9_11ec_8e30_0242ac1c0002row1_col2,#T_61efce0e_7ba9_11ec_8e30_0242ac1c0002row5_col3{
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }#T_61efce0e_7ba9_11ec_8e30_0242ac1c0002row0_col2{
#             background-color:  #083674;
#             color:  #f1f1f1;
#         }#T_61efce0e_7ba9_11ec_8e30_0242ac1c0002row0_col3{
#             background-color:  #d8e7f5;
#             color:  #000000;
#         }#T_61efce0e_7ba9_11ec_8e30_0242ac1c0002row1_col3{
#             background-color:  #ecf4fb;
#             color:  #000000;
#         }#T_61efce0e_7ba9_11ec_8e30_0242ac1c0002row2_col1{
#             background-color:  #3a8ac2;
#             color:  #000000;
#         }#T_61efce0e_7ba9_11ec_8e30_0242ac1c0002row2_col2{
#             background-color:  #2b7bba;
#             color:  #000000;
#         }#T_61efce0e_7ba9_11ec_8e30_0242ac1c0002row2_col3{
#             background-color:  #d6e5f4;
#             color:  #000000;
#         }#T_61efce0e_7ba9_11ec_8e30_0242ac1c0002row3_col1,#T_61efce0e_7ba9_11ec_8e30_0242ac1c0002row4_col1{
#             background-color:  #f1f7fd;
#             color:  #000000;
#         }#T_61efce0e_7ba9_11ec_8e30_0242ac1c0002row3_col2{
#             background-color:  #c3daee;
#             color:  #000000;
#         }#T_61efce0e_7ba9_11ec_8e30_0242ac1c0002row3_col3,#T_61efce0e_7ba9_11ec_8e30_0242ac1c0002row6_col2{
#             background-color:  #e1edf8;
#             color:  #000000;
#         }#T_61efce0e_7ba9_11ec_8e30_0242ac1c0002row4_col2{
#             background-color:  #b9d6ea;
#             color:  #000000;
#         }#T_61efce0e_7ba9_11ec_8e30_0242ac1c0002row4_col3,#T_61efce0e_7ba9_11ec_8e30_0242ac1c0002row5_col1,#T_61efce0e_7ba9_11ec_8e30_0242ac1c0002row5_col2,#T_61efce0e_7ba9_11ec_8e30_0242ac1c0002row6_col1,#T_61efce0e_7ba9_11ec_8e30_0242ac1c0002row7_col1,#T_61efce0e_7ba9_11ec_8e30_0242ac1c0002row8_col1,#T_61efce0e_7ba9_11ec_8e30_0242ac1c0002row9_col1{
#             background-color:  #f7fbff;
#             color:  #000000;
#         }#T_61efce0e_7ba9_11ec_8e30_0242ac1c0002row6_col3{
#             background-color:  #519ccc;
#             color:  #000000;
#         }#T_61efce0e_7ba9_11ec_8e30_0242ac1c0002row7_col2{
#             background-color:  #dae8f6;
#             color:  #000000;
#         }#T_61efce0e_7ba9_11ec_8e30_0242ac1c0002row7_col3{
#             background-color:  #7fb9da;
#             color:  #000000;
#         }#T_61efce0e_7ba9_11ec_8e30_0242ac1c0002row8_col2{
#             background-color:  #d7e6f5;
#             color:  #000000;
#         }#T_61efce0e_7ba9_11ec_8e30_0242ac1c0002row8_col3{
#             background-color:  #9ac8e0;
#             color:  #000000;
#         }#T_61efce0e_7ba9_11ec_8e30_0242ac1c0002row9_col2{
#             background-color:  #d6e6f4;
#             color:  #000000;
#         }#T_61efce0e_7ba9_11ec_8e30_0242ac1c0002row9_col3{
#             background-color:  #a0cbe2;
#             color:  #000000;
#         }</style><table id="T_61efce0e_7ba9_11ec_8e30_0242ac1c0002" class="dataframe"><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >cliente</th>        <th class="col_heading level0 col1" >var_1</th>        <th class="col_heading level0 col2" >var_2</th>        <th class="col_heading level0 col3" >var_3</th>        <th class="col_heading level0 col4" >grupo</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_61efce0e_7ba9_11ec_8e30_0242ac1c0002level0_row0" class="row_heading level0 row0" >27614</th>
#                         <td id="T_61efce0e_7ba9_11ec_8e30_0242ac1c0002row0_col0" class="data row0 col0" >b7d76e111c89f7ebf14761390f0f7d17</td>
#                         <td id="T_61efce0e_7ba9_11ec_8e30_0242ac1c0002row0_col1" class="data row0 col1" >0.666033</td>
#                         <td id="T_61efce0e_7ba9_11ec_8e30_0242ac1c0002row0_col2" class="data row0 col2" >0.003637</td>
#                         <td id="T_61efce0e_7ba9_11ec_8e30_0242ac1c0002row0_col3" class="data row0 col3" >-0.001810</td>
#                         <td id="T_61efce0e_7ba9_11ec_8e30_0242ac1c0002row0_col4" class="data row0 col4" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_61efce0e_7ba9_11ec_8e30_0242ac1c0002level0_row1" class="row_heading level0 row1" >6365</th>
#                         <td id="T_61efce0e_7ba9_11ec_8e30_0242ac1c0002row1_col0" class="data row1 col0" >4854e9b3feff728c13ee5fc7d1547e92</td>
#                         <td id="T_61efce0e_7ba9_11ec_8e30_0242ac1c0002row1_col1" class="data row1 col1" >0.666033</td>
#                         <td id="T_61efce0e_7ba9_11ec_8e30_0242ac1c0002row1_col2" class="data row1 col2" >0.003654</td>
#                         <td id="T_61efce0e_7ba9_11ec_8e30_0242ac1c0002row1_col3" class="data row1 col3" >-0.006289</td>
#                         <td id="T_61efce0e_7ba9_11ec_8e30_0242ac1c0002row1_col4" class="data row1 col4" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_61efce0e_7ba9_11ec_8e30_0242ac1c0002level0_row2" class="row_heading level0 row2" >31427</th>
#                         <td id="T_61efce0e_7ba9_11ec_8e30_0242ac1c0002row2_col0" class="data row2 col0" >830d5b7aaa3b6f1e9ad63703bec97d23</td>
#                         <td id="T_61efce0e_7ba9_11ec_8e30_0242ac1c0002row2_col1" class="data row2 col1" >0.652298</td>
#                         <td id="T_61efce0e_7ba9_11ec_8e30_0242ac1c0002row2_col2" class="data row2 col2" >0.003465</td>
#                         <td id="T_61efce0e_7ba9_11ec_8e30_0242ac1c0002row2_col3" class="data row2 col3" >-0.001281</td>
#                         <td id="T_61efce0e_7ba9_11ec_8e30_0242ac1c0002row2_col4" class="data row2 col4" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_61efce0e_7ba9_11ec_8e30_0242ac1c0002level0_row3" class="row_heading level0 row3" >42827</th>
#                         <td id="T_61efce0e_7ba9_11ec_8e30_0242ac1c0002row3_col0" class="data row3 col0" >0eb1ee9dba87f5b36b4613a65074337c</td>
#                         <td id="T_61efce0e_7ba9_11ec_8e30_0242ac1c0002row3_col1" class="data row3 col1" >0.627574</td>
#                         <td id="T_61efce0e_7ba9_11ec_8e30_0242ac1c0002row3_col2" class="data row3 col2" >0.003169</td>
#                         <td id="T_61efce0e_7ba9_11ec_8e30_0242ac1c0002row3_col3" class="data row3 col3" >-0.003780</td>
#                         <td id="T_61efce0e_7ba9_11ec_8e30_0242ac1c0002row3_col4" class="data row3 col4" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_61efce0e_7ba9_11ec_8e30_0242ac1c0002level0_row4" class="row_heading level0 row4" >9684</th>
#                         <td id="T_61efce0e_7ba9_11ec_8e30_0242ac1c0002row4_col0" class="data row4 col0" >2f64e403852e6893ae37485d5fcacdaf</td>
#                         <td id="T_61efce0e_7ba9_11ec_8e30_0242ac1c0002row4_col1" class="data row4 col1" >0.627574</td>
#                         <td id="T_61efce0e_7ba9_11ec_8e30_0242ac1c0002row4_col2" class="data row4 col2" >0.003189</td>
#                         <td id="T_61efce0e_7ba9_11ec_8e30_0242ac1c0002row4_col3" class="data row4 col3" >-0.008925</td>
#                         <td id="T_61efce0e_7ba9_11ec_8e30_0242ac1c0002row4_col4" class="data row4 col4" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_61efce0e_7ba9_11ec_8e30_0242ac1c0002level0_row5" class="row_heading level0 row5" >6415</th>
#                         <td id="T_61efce0e_7ba9_11ec_8e30_0242ac1c0002row5_col0" class="data row5 col0" >45d9410bc1f3c6e36dea41d8f823ada6</td>
#                         <td id="T_61efce0e_7ba9_11ec_8e30_0242ac1c0002row5_col1" class="data row5 col1" >0.626202</td>
#                         <td id="T_61efce0e_7ba9_11ec_8e30_0242ac1c0002row5_col2" class="data row5 col2" >0.002999</td>
#                         <td id="T_61efce0e_7ba9_11ec_8e30_0242ac1c0002row5_col3" class="data row5 col3" >0.036503</td>
#                         <td id="T_61efce0e_7ba9_11

# %%
clustered3.sort_values('var_2', ascending=False).head(10).style.background_gradient(subset=['var_1', 'var_2', 'var_3'], cmap='Blues')
# Out:
# <style  type="text/css" >
# #T_61f8eac0_7ba9_11ec_8e30_0242ac1c0002row0_col1{
#             background-color:  #a8cee4;
#             color:  #000000;
#         }#T_61f8eac0_7ba9_11ec_8e30_0242ac1c0002row0_col2,#T_61f8eac0_7ba9_11ec_8e30_0242ac1c0002row5_col3,#T_61f8eac0_7ba9_11ec_8e30_0242ac1c0002row8_col1{
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }#T_61f8eac0_7ba9_11ec_8e30_0242ac1c0002row0_col3{
#             background-color:  #b3d3e8;
#             color:  #000000;
#         }#T_61f8eac0_7ba9_11ec_8e30_0242ac1c0002row1_col1{
#             background-color:  #77b5d9;
#             color:  #000000;
#         }#T_61f8eac0_7ba9_11ec_8e30_0242ac1c0002row1_col2{
#             background-color:  #2c7cba;
#             color:  #000000;
#         }#T_61f8eac0_7ba9_11ec_8e30_0242ac1c0002row1_col3{
#             background-color:  #68acd5;
#             color:  #000000;
#         }#T_61f8eac0_7ba9_11ec_8e30_0242ac1c0002row2_col1{
#             background-color:  #f2f7fd;
#             color:  #000000;
#         }#T_61f8eac0_7ba9_11ec_8e30_0242ac1c0002row2_col2{
#             background-color:  #4493c7;
#             color:  #000000;
#         }#T_61f8eac0_7ba9_11ec_8e30_0242ac1c0002row2_col3,#T_61f8eac0_7ba9_11ec_8e30_0242ac1c0002row3_col1,#T_61f8eac0_7ba9_11ec_8e30_0242ac1c0002row9_col2{
#             background-color:  #f7fbff;
#             color:  #000000;
#         }#T_61f8eac0_7ba9_11ec_8e30_0242ac1c0002row3_col2{
#             background-color:  #71b1d7;
#             color:  #000000;
#         }#T_61f8eac0_7ba9_11ec_8e30_0242ac1c0002row3_col3{
#             background-color:  #8cc0dd;
#             color:  #000000;
#         }#T_61f8eac0_7ba9_11ec_8e30_0242ac1c0002row4_col1{
#             background-color:  #3a8ac2;
#             color:  #000000;
#         }#T_61f8eac0_7ba9_11ec_8e30_0242ac1c0002row4_col2{
#             background-color:  #74b3d8;
#             color:  #000000;
#         }#T_61f8eac0_7ba9_11ec_8e30_0242ac1c0002row4_col3{
#             background-color:  #79b5d9;
#             color:  #000000;
#         }#T_61f8eac0_7ba9_11ec_8e30_0242ac1c0002row5_col1{
#             background-color:  #3282be;
#             color:  #000000;
#         }#T_61f8eac0_7ba9_11ec_8e30_0242ac1c0002row5_col2{
#             background-color:  #8fc2de;
#             color:  #000000;
#         }#T_61f8eac0_7ba9_11ec_8e30_0242ac1c0002row6_col1{
#             background-color:  #d9e8f5;
#             color:  #000000;
#         }#T_61f8eac0_7ba9_11ec_8e30_0242ac1c0002row6_col2{
#             background-color:  #d1e2f3;
#             color:  #000000;
#         }#T_61f8eac0_7ba9_11ec_8e30_0242ac1c0002row6_col3{
#             background-color:  #57a0ce;
#             color:  #000000;
#         }#T_61f8eac0_7ba9_11ec_8e30_0242ac1c0002row7_col1{
#             background-color:  #d9e7f5;
#             color:  #000000;
#         }#T_61f8eac0_7ba9_11ec_8e30_0242ac1c0002row7_col2{
#             background-color:  #e5eff9;
#             color:  #000000;
#         }#T_61f8eac0_7ba9_11ec_8e30_0242ac1c0002row7_col3{
#             background-color:  #a4cce3;
#             color:  #000000;
#         }#T_61f8eac0_7ba9_11ec_8e30_0242ac1c0002row8_col2{
#             background-color:  #f5f9fe;
#             color:  #000000;
#         }#T_61f8eac0_7ba9_11ec_8e30_0242ac1c0002row8_col3{
#             background-color:  #82bbdb;
#             color:  #000000;
#         }#T_61f8eac0_7ba9_11ec_8e30_0242ac1c0002row9_col1{
#             background-color:  #f6faff;
#             color:  #000000;
#         }#T_61f8eac0_7ba9_11ec_8e30_0242ac1c0002row9_col3{
#             background-color:  #9dcae1;
#             color:  #000000;
#         }</style><table id="T_61f8eac0_7ba9_11ec_8e30_0242ac1c0002" class="dataframe"><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >cliente</th>        <th class="col_heading level0 col1" >var_1</th>        <th class="col_heading level0 col2" >var_2</th>        <th class="col_heading level0 col3" >var_3</th>        <th class="col_heading level0 col4" >grupo</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_61f8eac0_7ba9_11ec_8e30_0242ac1c0002level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_61f8eac0_7ba9_11ec_8e30_0242ac1c0002row0_col0" class="data row0 col0" >32ea3bdedab835c3aa6cb68ce66565ef</td>
#                         <td id="T_61f8eac0_7ba9_11ec_8e30_0242ac1c0002row0_col1" class="data row0 col1" >-0.254387</td>
#                         <td id="T_61f8eac0_7ba9_11ec_8e30_0242ac1c0002row0_col2" class="data row0 col2" >0.996652</td>
#                         <td id="T_61f8eac0_7ba9_11ec_8e30_0242ac1c0002row0_col3" class="data row0 col3" >-0.003836</td>
#                         <td id="T_61f8eac0_7ba9_11ec_8e30_0242ac1c0002row0_col4" class="data row0 col4" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_61f8eac0_7ba9_11ec_8e30_0242ac1c0002level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_61f8eac0_7ba9_11ec_8e30_0242ac1c0002row1_col0" class="data row1 col0" >ccafc1c3f270410521c3c6f3b249870f</td>
#                         <td id="T_61f8eac0_7ba9_11ec_8e30_0242ac1c0002row1_col1" class="data row1 col1" >-0.226323</td>
#                         <td id="T_61f8eac0_7ba9_11ec_8e30_0242ac1c0002row1_col2" class="data row1 col2" >0.943397</td>
#                         <td id="T_61f8eac0_7ba9_11ec_8e30_0242ac1c0002row1_col3" class="data row1 col3" >0.000683</td>
#                         <td id="T_61f8eac0_7ba9_11ec_8e30_0242ac1c0002row1_col4" class="data row1 col4" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_61f8eac0_7ba9_11ec_8e30_0242ac1c0002level0_row2" class="row_heading level0 row2" >28</th>
#                         <td id="T_61f8eac0_7ba9_11ec_8e30_0242ac1c0002row2_col0" class="data row2 col0" >8d50f5eadf50201ccdcedfb9e2ac8455</td>
#                         <td id="T_61f8eac0_7ba9_11ec_8e30_0242ac1c0002row2_col1" class="data row2 col1" >-0.326592</td>
#                         <td id="T_61f8eac0_7ba9_11ec_8e30_0242ac1c0002row2_col2" class="data row2 col2" >0.926219</td>
#                         <td id="T_61f8eac0_7ba9_11ec_8e30_0242ac1c0002row2_col3" class="data row2 col3" >-0.010954</td>
#                         <td id="T_61f8eac0_7ba9_11ec_8e30_0242ac1c0002row2_col4" class="data row2 col4" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_61f8eac0_7ba9_11ec_8e30_0242ac1c0002level0_row3" class="row_heading level0 row3" >2</th>
#                         <td id="T_61f8eac0_7ba9_11ec_8e30_0242ac1c0002row3_col0" class="data row3 col0" >d8f3c4f441a9b59a29f977df16724f38</td>
#                         <td id="T_61f8eac0_7ba9_11ec_8e30_0242ac1c0002row3_col1" class="data row3 col1" >-0.332951</td>
#                         <td id="T_61f8eac0_7ba9_11ec_8e30_0242ac1c0002row3_col2" class="data row3 col2" >0.902006</td>
#                         <td id="T_61f8eac0_7ba9_11ec_8e30_0242ac1c0002row3_col3" class="data row3 col3" >-0.001344</td>
#                         <td id="T_61f8eac0_7ba9_11ec_8e30_0242ac1c0002row3_col4" class="data row3 col4" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_61f8eac0_7ba9_11ec_8e30_0242ac1c0002level0_row4" class="row_heading level0 row4" >3</th>
#                         <td id="T_61f8eac0_7ba9_11ec_8e30_0242ac1c0002row4_col0" class="data row4 col0" >94e5ea5a8c1bf546db2739673060c43f</td>
#                         <td id="T_61f8eac0_7ba9_11ec_8e30_0242ac1c0002row4_col1" class="data row4 col1" >-0.184572</td>
#                         <td id="T_61f8eac0_7ba9_11ec_8e30_0242ac1c0002row4_col2" class="data row4 col2" >0.900752</td>
#                         <td id="T_61f8eac0_7ba9_11ec_8e30_0242ac1c0002row4_col3" class="data row4 col3" >-0.000309</td>
#                         <td id="T_61f8eac0_7ba9_11ec_8e30_0242ac1c0002row4_col4" class="data row4 col4" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_61f8eac0_7ba9_11ec_8e30_0242ac1c0002level0_row5" class="row_heading level0 row5" >4</th>

# %%
clustered3.sort_values('var_3', ascending=False).head(10).style.background_gradient(subset=['var_1', 'var_2', 'var_3'], cmap='Blues')
# Out:
# <style  type="text/css" >
# #T_6201afc0_7ba9_11ec_8e30_0242ac1c0002row0_col1{
#             background-color:  #529dcc;
#             color:  #000000;
#         }#T_6201afc0_7ba9_11ec_8e30_0242ac1c0002row0_col2{
#             background-color:  #a4cce3;
#             color:  #000000;
#         }#T_6201afc0_7ba9_11ec_8e30_0242ac1c0002row0_col3,#T_6201afc0_7ba9_11ec_8e30_0242ac1c0002row2_col1,#T_6201afc0_7ba9_11ec_8e30_0242ac1c0002row2_col2{
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }#T_6201afc0_7ba9_11ec_8e30_0242ac1c0002row1_col1{
#             background-color:  #f0f6fd;
#             color:  #000000;
#         }#T_6201afc0_7ba9_11ec_8e30_0242ac1c0002row1_col2{
#             background-color:  #f5fafe;
#             color:  #000000;
#         }#T_6201afc0_7ba9_11ec_8e30_0242ac1c0002row1_col3{
#             background-color:  #b5d4e9;
#             color:  #000000;
#         }#T_6201afc0_7ba9_11ec_8e30_0242ac1c0002row2_col3,#T_6201afc0_7ba9_11ec_8e30_0242ac1c0002row3_col3{
#             background-color:  #c2d9ee;
#             color:  #000000;
#         }#T_6201afc0_7ba9_11ec_8e30_0242ac1c0002row3_col1,#T_6201afc0_7ba9_11ec_8e30_0242ac1c0002row8_col3{
#             background-color:  #f4f9fe;
#             color:  #000000;
#         }#T_6201afc0_7ba9_11ec_8e30_0242ac1c0002row3_col2,#T_6201afc0_7ba9_11ec_8e30_0242ac1c0002row9_col1,#T_6201afc0_7ba9_11ec_8e30_0242ac1c0002row9_col3{
#             background-color:  #f7fbff;
#             color:  #000000;
#         }#T_6201afc0_7ba9_11ec_8e30_0242ac1c0002row4_col1{
#             background-color:  #1561a9;
#             color:  #f1f1f1;
#         }#T_6201afc0_7ba9_11ec_8e30_0242ac1c0002row4_col2{
#             background-color:  #1460a8;
#             color:  #f1f1f1;
#         }#T_6201afc0_7ba9_11ec_8e30_0242ac1c0002row4_col3{
#             background-color:  #c8dcf0;
#             color:  #000000;
#         }#T_6201afc0_7ba9_11ec_8e30_0242ac1c0002row5_col1{
#             background-color:  #77b5d9;
#             color:  #000000;
#         }#T_6201afc0_7ba9_11ec_8e30_0242ac1c0002row5_col2{
#             background-color:  #6fb0d7;
#             color:  #000000;
#         }#T_6201afc0_7ba9_11ec_8e30_0242ac1c0002row5_col3{
#             background-color:  #d6e5f4;
#             color:  #000000;
#         }#T_6201afc0_7ba9_11ec_8e30_0242ac1c0002row6_col1{
#             background-color:  #eff6fc;
#             color:  #000000;
#         }#T_6201afc0_7ba9_11ec_8e30_0242ac1c0002row6_col2{
#             background-color:  #e5eff9;
#             color:  #000000;
#         }#T_6201afc0_7ba9_11ec_8e30_0242ac1c0002row6_col3{
#             background-color:  #f1f7fd;
#             color:  #000000;
#         }#T_6201afc0_7ba9_11ec_8e30_0242ac1c0002row7_col1{
#             background-color:  #084f99;
#             color:  #f1f1f1;
#         }#T_6201afc0_7ba9_11ec_8e30_0242ac1c0002row7_col2{
#             background-color:  #083e81;
#             color:  #f1f1f1;
#         }#T_6201afc0_7ba9_11ec_8e30_0242ac1c0002row7_col3{
#             background-color:  #f2f7fd;
#             color:  #000000;
#         }#T_6201afc0_7ba9_11ec_8e30_0242ac1c0002row8_col1{
#             background-color:  #e7f1fa;
#             color:  #000000;
#         }#T_6201afc0_7ba9_11ec_8e30_0242ac1c0002row8_col2{
#             background-color:  #dceaf6;
#             color:  #000000;
#         }#T_6201afc0_7ba9_11ec_8e30_0242ac1c0002row9_col2{
#             background-color:  #ecf4fb;
#             color:  #000000;
#         }</style><table id="T_6201afc0_7ba9_11ec_8e30_0242ac1c0002" class="dataframe"><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >cliente</th>        <th class="col_heading level0 col1" >var_1</th>        <th class="col_heading level0 col2" >var_2</th>        <th class="col_heading level0 col3" >var_3</th>        <th class="col_heading level0 col4" >grupo</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_6201afc0_7ba9_11ec_8e30_0242ac1c0002level0_row0" class="row_heading level0 row0" >32754</th>
#                         <td id="T_6201afc0_7ba9_11ec_8e30_0242ac1c0002row0_col0" class="data row0 col0" >0a0a92112bd4c708ca5fde585afaa872</td>
#                         <td id="T_6201afc0_7ba9_11ec_8e30_0242ac1c0002row0_col1" class="data row0 col1" >0.131769</td>
#                         <td id="T_6201afc0_7ba9_11ec_8e30_0242ac1c0002row0_col2" class="data row0 col2" >-0.006726</td>
#                         <td id="T_6201afc0_7ba9_11ec_8e30_0242ac1c0002row0_col3" class="data row0 col3" >0.988862</td>
#                         <td id="T_6201afc0_7ba9_11ec_8e30_0242ac1c0002row0_col4" class="data row0 col4" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_6201afc0_7ba9_11ec_8e30_0242ac1c0002level0_row1" class="row_heading level0 row1" >32517</th>
#                         <td id="T_6201afc0_7ba9_11ec_8e30_0242ac1c0002row1_col0" class="data row1 col0" >763c8b1c9c68a0229c42c9fc6f662b93</td>
#                         <td id="T_6201afc0_7ba9_11ec_8e30_0242ac1c0002row1_col1" class="data row1 col1" >-0.265195</td>
#                         <td id="T_6201afc0_7ba9_11ec_8e30_0242ac1c0002row1_col2" class="data row1 col2" >-0.009853</td>
#                         <td id="T_6201afc0_7ba9_11ec_8e30_0242ac1c0002row1_col3" class="data row1 col3" >0.520954</td>
#                         <td id="T_6201afc0_7ba9_11ec_8e30_0242ac1c0002row1_col4" class="data row1 col4" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_6201afc0_7ba9_11ec_8e30_0242ac1c0002level0_row2" class="row_heading level0 row2" >67190</th>
#                         <td id="T_6201afc0_7ba9_11ec_8e30_0242ac1c0002row2_col0" class="data row2 col0" >dc4802a71eae9be1dd28f5d788ceb526</td>
#                         <td id="T_6201afc0_7ba9_11ec_8e30_0242ac1c0002row2_col1" class="data row2 col1" >0.444914</td>
#                         <td id="T_6201afc0_7ba9_11ec_8e30_0242ac1c0002row2_col2" class="data row2 col2" >-0.000984</td>
#                         <td id="T_6201afc0_7ba9_11ec_8e30_0242ac1c0002row2_col3" class="data row2 col3" >0.495662</td>
#                         <td id="T_6201afc0_7ba9_11ec_8e30_0242ac1c0002row2_col4" class="data row2 col4" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_6201afc0_7ba9_11ec_8e30_0242ac1c0002level0_row3" class="row_heading level0 row3" >6521</th>
#                         <td id="T_6201afc0_7ba9_11ec_8e30_0242ac1c0002row3_col0" class="data row3 col0" >459bef486812aa25204be022145caa62</td>
#                         <td id="T_6201afc0_7ba9_11ec_8e30_0242ac1c0002row3_col1" class="data row3 col1" >-0.280305</td>
#                         <td id="T_6201afc0_7ba9_11ec_8e30_0242ac1c0002row3_col2" class="data row3 col2" >-0.009942</td>
#                         <td id="T_6201afc0_7ba9_11ec_8e30_0242ac1c0002row3_col3" class="data row3 col3" >0.495127</td>
#                         <td id="T_6201afc0_7ba9_11ec_8e30_0242ac1c0002row3_col4" class="data row3 col4" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_6201afc0_7ba9_11ec_8e30_0242ac1c0002level0_row4" class="row_heading level0 row4" >63411</th>
#                         <td id="T_6201afc0_7ba9_11ec_8e30_0242ac1c0002row4_col0" class="data row4 col0" >ff4159b92c40ebe40454e3e6a7c35ed6</td>
#                         <td id="T_6201afc0_7ba9_11ec_8e30_0242ac1c0002row4_col1" class="data row4 col1" >0.306188</td>
#                         <td id="T_6201afc0_7ba9_11ec_8e30_0242ac1c0002row4_col2" class="data row4 col2" >-0.002642</td>
#                         <td id="T_6201afc0_7ba9_11ec_8e30_0242ac1c0002row4_col3" class="data row4 col3" >0.480818</td>
#                         <td id="T_6201afc0_7ba9_11ec_8e30_0242ac1c0002row4_col4" class="data row4 col4" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_6201afc0_7ba9_11ec_8e30_0242ac1c0002level0_row5" class="row_heading level0 row5" >32700</th>
#                         <td id="T_6201afc0_7ba9_11ec_8e30_0242ac1c0002row5_col0" class="data row5 col0" >4007669dec559734d6f53e029e360987</td>

# %%
clustered3[['var_1', 'var_2', 'var_3']].corr().style.format({'var_1':'{:,.4f}', 'var_2':'{:,.4f}', 'var_3':'{:,.4f}'})
# Out:
# <style  type="text/css" >
# </style><table id="T_62063874_7ba9_11ec_8e30_0242ac1c0002" class="dataframe"><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >var_1</th>        <th class="col_heading level0 col1" >var_2</th>        <th class="col_heading level0 col2" >var_3</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_62063874_7ba9_11ec_8e30_0242ac1c0002level0_row0" class="row_heading level0 row0" >var_1</th>
#                         <td id="T_62063874_7ba9_11ec_8e30_0242ac1c0002row0_col0" class="data row0 col0" >1.0000</td>
#                         <td id="T_62063874_7ba9_11ec_8e30_0242ac1c0002row0_col1" class="data row0 col1" >0.0000</td>
#                         <td id="T_62063874_7ba9_11ec_8e30_0242ac1c0002row0_col2" class="data row0 col2" >-0.0000</td>
#             </tr>
#             <tr>
#                         <th id="T_62063874_7ba9_11ec_8e30_0242ac1c0002level0_row1" class="row_heading level0 row1" >var_2</th>
#                         <td id="T_62063874_7ba9_11ec_8e30_0242ac1c0002row1_col0" class="data row1 col0" >0.0000</td>
#                         <td id="T_62063874_7ba9_11ec_8e30_0242ac1c0002row1_col1" class="data row1 col1" >1.0000</td>
#                         <td id="T_62063874_7ba9_11ec_8e30_0242ac1c0002row1_col2" class="data row1 col2" >-0.0000</td>
#             </tr>
#             <tr>
#                         <th id="T_62063874_7ba9_11ec_8e30_0242ac1c0002level0_row2" class="row_heading level0 row2" >var_3</th>
#                         <td id="T_62063874_7ba9_11ec_8e30_0242ac1c0002row2_col0" class="data row2 col0" >-0.0000</td>
#                         <td id="T_62063874_7ba9_11ec_8e30_0242ac1c0002row2_col1" class="data row2 col1" >-0.0000</td>
#                         <td id="T_62063874_7ba9_11ec_8e30_0242ac1c0002row2_col2" class="data row2 col2" >1.0000</td>
#             </tr>
#     </tbody></table>

# %%
pred_p3 = [km3.predict(p3) == 0, km3.predict(p3) == 1, km3.predict(p3) == 2]
colored_p3 = ['fuchsia', 'darkblue', 'darkorchid']
colors = np.select(pred_p3, colored_p3)

# %%
# from mpl_toolkits.mplot3d import Axes3D
# fig = plt.figure(figsize=(24,7))
# ax = fig.add_subplot(111, projection='3d')
# Axes3D.scatter(xs=p3[0], ys=p3[1], zs=p3[2], ax=ax, c=colors)
# plt.show()

# %% [markdown]
# # KMEANS com maior peso sobre a coluna rendimento medio

# %%
scaled_data2 = scaled_data.copy()
scaled_data2['receita_media_por_quantia'] = scaled_data2['receita_media_por_quantia'] * 4
scaled_data2
# Out:
#        quantia_comprada  retencao  recencia  receita_media_por_quantia
# 0              0.133333  1.000000  0.092033                   0.010584
# 1              0.066667  0.960443  0.119505                   0.027585
# 2              0.066667  0.919304  0.012363                   0.020408
# 3              0.066667  0.916139  0.160714                   0.024606
# 4              0.066667  0.903481  0.167582                   0.073813
# ...                 ...       ...       ...                        ...
# 95415          0.000000  0.000000  0.300824                   0.031445
# 95416          0.000000  0.000000  0.197802                   0.012046
# 95417          0.000000  0.000000  0.189560                   0.035021
# 95418          0.000000  0.000000  0.266484                   0.015286
# 95419          0.000000  0.000000  0.173077                   0.011026
#
# [95420 rows x 4 columns]

# %%
km = KMeans(n_clusters=3, random_state=0).fit(scaled_data2)
np.unique(km.labels_, return_counts=True)
# Out:
# (array([0, 1, 2], dtype=int32), array([36574, 22634, 36212]))

# %%
clustered4 = pd.concat([Cliente['cliente'], scaled_data2, pd.Series(km.predict(scaled_data2))], axis=1, ignore_index=True)
cols = ['cliente', 'quantia_comprada', 'retencao', 'recencia', 'receita_media_por_quantia', 'grupo']
clustered4.columns = cols
clustered4.sort_values(['retencao', 'receita_media_por_quantia'], ascending=False).head(10).style.background_gradient(subset=['receita_media_por_quantia', 'recencia', 'retencao'], cmap='Blues')
# Out:
# <style  type="text/css" >
# #T_63214c9e_7ba9_11ec_8e30_0242ac1c0002row0_col2,#T_63214c9e_7ba9_11ec_8e30_0242ac1c0002row4_col4,#T_63214c9e_7ba9_11ec_8e30_0242ac1c0002row7_col3{
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }#T_63214c9e_7ba9_11ec_8e30_0242ac1c0002row0_col3{
#             background-color:  #a5cde3;
#             color:  #000000;
#         }#T_63214c9e_7ba9_11ec_8e30_0242ac1c0002row0_col4,#T_63214c9e_7ba9_11ec_8e30_0242ac1c0002row2_col3,#T_63214c9e_7ba9_11ec_8e30_0242ac1c0002row8_col3,#T_63214c9e_7ba9_11ec_8e30_0242ac1c0002row9_col2{
#             background-color:  #f7fbff;
#             color:  #000000;
#         }#T_63214c9e_7ba9_11ec_8e30_0242ac1c0002row1_col2{
#             background-color:  #1c6ab0;
#             color:  #f1f1f1;
#         }#T_63214c9e_7ba9_11ec_8e30_0242ac1c0002row1_col3{
#             background-color:  #75b4d8;
#             color:  #000000;
#         }#T_63214c9e_7ba9_11ec_8e30_0242ac1c0002row1_col4{
#             background-color:  #c1d9ed;
#             color:  #000000;
#         }#T_63214c9e_7ba9_11ec_8e30_0242ac1c0002row2_col2{
#             background-color:  #5ca4d0;
#             color:  #000000;
#         }#T_63214c9e_7ba9_11ec_8e30_0242ac1c0002row2_col4,#T_63214c9e_7ba9_11ec_8e30_0242ac1c0002row6_col3{
#             background-color:  #d9e7f5;
#             color:  #000000;
#         }#T_63214c9e_7ba9_11ec_8e30_0242ac1c0002row3_col2{
#             background-color:  #63a8d3;
#             color:  #000000;
#         }#T_63214c9e_7ba9_11ec_8e30_0242ac1c0002row3_col3{
#             background-color:  #3989c1;
#             color:  #000000;
#         }#T_63214c9e_7ba9_11ec_8e30_0242ac1c0002row3_col4{
#             background-color:  #ccdff1;
#             color:  #000000;
#         }#T_63214c9e_7ba9_11ec_8e30_0242ac1c0002row4_col2{
#             background-color:  #7db8da;
#             color:  #000000;
#         }#T_63214c9e_7ba9_11ec_8e30_0242ac1c0002row4_col3{
#             background-color:  #3181bd;
#             color:  #000000;
#         }#T_63214c9e_7ba9_11ec_8e30_0242ac1c0002row5_col2{
#             background-color:  #dbe9f6;
#             color:  #000000;
#         }#T_63214c9e_7ba9_11ec_8e30_0242ac1c0002row5_col3{
#             background-color:  #dae8f6;
#             color:  #000000;
#         }#T_63214c9e_7ba9_11ec_8e30_0242ac1c0002row5_col4{
#             background-color:  #8fc2de;
#             color:  #000000;
#         }#T_63214c9e_7ba9_11ec_8e30_0242ac1c0002row6_col2{
#             background-color:  #f0f6fd;
#             color:  #000000;
#         }#T_63214c9e_7ba9_11ec_8e30_0242ac1c0002row6_col4{
#             background-color:  #deebf7;
#             color:  #000000;
#         }#T_63214c9e_7ba9_11ec_8e30_0242ac1c0002row7_col2,#T_63214c9e_7ba9_11ec_8e30_0242ac1c0002row8_col2{
#             background-color:  #f2f8fd;
#             color:  #000000;
#         }#T_63214c9e_7ba9_11ec_8e30_0242ac1c0002row7_col4{
#             background-color:  #cbdef1;
#             color:  #000000;
#         }#T_63214c9e_7ba9_11ec_8e30_0242ac1c0002row8_col4{
#             background-color:  #dfebf7;
#             color:  #000000;
#         }#T_63214c9e_7ba9_11ec_8e30_0242ac1c0002row9_col3{
#             background-color:  #d1e2f3;
#             color:  #000000;
#         }#T_63214c9e_7ba9_11ec_8e30_0242ac1c0002row9_col4{
#             background-color:  #d0e1f2;
#             color:  #000000;
#         }</style><table id="T_63214c9e_7ba9_11ec_8e30_0242ac1c0002" class="dataframe"><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >cliente</th>        <th class="col_heading level0 col1" >quantia_comprada</th>        <th class="col_heading level0 col2" >retencao</th>        <th class="col_heading level0 col3" >recencia</th>        <th class="col_heading level0 col4" >receita_media_por_quantia</th>        <th class="col_heading level0 col5" >grupo</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_63214c9e_7ba9_11ec_8e30_0242ac1c0002level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_63214c9e_7ba9_11ec_8e30_0242ac1c0002row0_col0" class="data row0 col0" >32ea3bdedab835c3aa6cb68ce66565ef</td>
#                         <td id="T_63214c9e_7ba9_11ec_8e30_0242ac1c0002row0_col1" class="data row0 col1" >0.133333</td>
#                         <td id="T_63214c9e_7ba9_11ec_8e30_0242ac1c0002row0_col2" class="data row0 col2" >1.000000</td>
#                         <td id="T_63214c9e_7ba9_11ec_8e30_0242ac1c0002row0_col3" class="data row0 col3" >0.092033</td>
#                         <td id="T_63214c9e_7ba9_11ec_8e30_0242ac1c0002row0_col4" class="data row0 col4" >0.010584</td>
#                         <td id="T_63214c9e_7ba9_11ec_8e30_0242ac1c0002row0_col5" class="data row0 col5" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_63214c9e_7ba9_11ec_8e30_0242ac1c0002level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_63214c9e_7ba9_11ec_8e30_0242ac1c0002row1_col0" class="data row1 col0" >ccafc1c3f270410521c3c6f3b249870f</td>
#                         <td id="T_63214c9e_7ba9_11ec_8e30_0242ac1c0002row1_col1" class="data row1 col1" >0.066667</td>
#                         <td id="T_63214c9e_7ba9_11ec_8e30_0242ac1c0002row1_col2" class="data row1 col2" >0.960443</td>
#                         <td id="T_63214c9e_7ba9_11ec_8e30_0242ac1c0002row1_col3" class="data row1 col3" >0.119505</td>
#                         <td id="T_63214c9e_7ba9_11ec_8e30_0242ac1c0002row1_col4" class="data row1 col4" >0.027585</td>
#                         <td id="T_63214c9e_7ba9_11ec_8e30_0242ac1c0002row1_col5" class="data row1 col5" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_63214c9e_7ba9_11ec_8e30_0242ac1c0002level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_63214c9e_7ba9_11ec_8e30_0242ac1c0002row2_col0" class="data row2 col0" >d8f3c4f441a9b59a29f977df16724f38</td>
#                         <td id="T_63214c9e_7ba9_11ec_8e30_0242ac1c0002row2_col1" class="data row2 col1" >0.066667</td>
#                         <td id="T_63214c9e_7ba9_11ec_8e30_0242ac1c0002row2_col2" class="data row2 col2" >0.919304</td>
#                         <td id="T_63214c9e_7ba9_11ec_8e30_0242ac1c0002row2_col3" class="data row2 col3" >0.012363</td>
#                         <td id="T_63214c9e_7ba9_11ec_8e30_0242ac1c0002row2_col4" class="data row2 col4" >0.020408</td>
#                         <td id="T_63214c9e_7ba9_11ec_8e30_0242ac1c0002row2_col5" class="data row2 col5" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_63214c9e_7ba9_11ec_8e30_0242ac1c0002level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_63214c9e_7ba9_11ec_8e30_0242ac1c0002row3_col0" class="data row3 col0" >94e5ea5a8c1bf546db2739673060c43f</td>
#                         <td id="T_63214c9e_7ba9_11ec_8e30_0242ac1c0002row3_col1" class="data row3 col1" >0.066667</td>
#                         <td id="T_63214c9e_7ba9_11ec_8e30_0242ac1c0002row3_col2" class="data row3 col2" >0.916139</td>
#                         <td id="T_63214c9e_7ba9_11ec_8e30_0242ac1c0002row3_col3" class="data row3 col3" >0.160714</td>
#                         <td id="T_63214c9e_7ba9_11ec_8e30_0242ac1c0002row3_col4" class="data row3 col4" >0.024606</td>
#                         <td id="T_63214c9e_7ba9_11ec_8e30_0242ac1c0002row3_col5" class="data row3 col5" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_63214c9e_7ba9_11ec_8e30_0242ac1c0002level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_63214c9e_7ba9_11ec_8e30_0242ac1c0002row4_col0" class="data row4 col0" >87b3f231705783eb2217e25851c0a45d</td>
#                         <td id="T_63214c9e_7ba9_11ec_8e30_0242ac1c0002row4_col1" class="data row4 col1" >0.066667</td>
#                         <td id="T_63214c9e_7ba9_11ec_8e30_0242ac1c0002row4_col2" class="data row4 col2" >0.903481</td>
#                         <td id="T_63214c9e_7ba9_11ec_8e30_0242ac1c0002row4_col3"

# %%
clustered4.sort_values(['receita_media_por_quantia'], ascending=False).head(10).style.background_gradient(subset=['receita_media_por_quantia', 'recencia', 'retencao'], cmap='Blues')
# Out:
# <style  type="text/css" >
# #T_632aef56_7ba9_11ec_8e30_0242ac1c0002row0_col2,#T_632aef56_7ba9_11ec_8e30_0242ac1c0002row1_col2,#T_632aef56_7ba9_11ec_8e30_0242ac1c0002row2_col2,#T_632aef56_7ba9_11ec_8e30_0242ac1c0002row3_col2,#T_632aef56_7ba9_11ec_8e30_0242ac1c0002row4_col2,#T_632aef56_7ba9_11ec_8e30_0242ac1c0002row5_col2,#T_632aef56_7ba9_11ec_8e30_0242ac1c0002row6_col2,#T_632aef56_7ba9_11ec_8e30_0242ac1c0002row7_col2,#T_632aef56_7ba9_11ec_8e30_0242ac1c0002row8_col2,#T_632aef56_7ba9_11ec_8e30_0242ac1c0002row9_col2,#T_632aef56_7ba9_11ec_8e30_0242ac1c0002row9_col3,#T_632aef56_7ba9_11ec_8e30_0242ac1c0002row9_col4{
#             background-color:  #f7fbff;
#             color:  #000000;
#         }#T_632aef56_7ba9_11ec_8e30_0242ac1c0002row0_col3{
#             background-color:  #529dcc;
#             color:  #000000;
#         }#T_632aef56_7ba9_11ec_8e30_0242ac1c0002row0_col4,#T_632aef56_7ba9_11ec_8e30_0242ac1c0002row2_col3{
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }#T_632aef56_7ba9_11ec_8e30_0242ac1c0002row1_col3{
#             background-color:  #f0f6fd;
#             color:  #000000;
#         }#T_632aef56_7ba9_11ec_8e30_0242ac1c0002row1_col4{
#             background-color:  #b5d4e9;
#             color:  #000000;
#         }#T_632aef56_7ba9_11ec_8e30_0242ac1c0002row2_col4,#T_632aef56_7ba9_11ec_8e30_0242ac1c0002row3_col4{
#             background-color:  #c2d9ee;
#             color:  #000000;
#         }#T_632aef56_7ba9_11ec_8e30_0242ac1c0002row3_col3,#T_632aef56_7ba9_11ec_8e30_0242ac1c0002row8_col4{
#             background-color:  #f4f9fe;
#             color:  #000000;
#         }#T_632aef56_7ba9_11ec_8e30_0242ac1c0002row4_col3{
#             background-color:  #1561a9;
#             color:  #f1f1f1;
#         }#T_632aef56_7ba9_11ec_8e30_0242ac1c0002row4_col4{
#             background-color:  #c8dcf0;
#             color:  #000000;
#         }#T_632aef56_7ba9_11ec_8e30_0242ac1c0002row5_col3{
#             background-color:  #77b5d9;
#             color:  #000000;
#         }#T_632aef56_7ba9_11ec_8e30_0242ac1c0002row5_col4{
#             background-color:  #d6e5f4;
#             color:  #000000;
#         }#T_632aef56_7ba9_11ec_8e30_0242ac1c0002row6_col3{
#             background-color:  #eff6fc;
#             color:  #000000;
#         }#T_632aef56_7ba9_11ec_8e30_0242ac1c0002row6_col4{
#             background-color:  #f1f7fd;
#             color:  #000000;
#         }#T_632aef56_7ba9_11ec_8e30_0242ac1c0002row7_col3{
#             background-color:  #084f99;
#             color:  #f1f1f1;
#         }#T_632aef56_7ba9_11ec_8e30_0242ac1c0002row7_col4{
#             background-color:  #f2f7fd;
#             color:  #000000;
#         }#T_632aef56_7ba9_11ec_8e30_0242ac1c0002row8_col3{
#             background-color:  #e7f1fa;
#             color:  #000000;
#         }</style><table id="T_632aef56_7ba9_11ec_8e30_0242ac1c0002" class="dataframe"><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >cliente</th>        <th class="col_heading level0 col1" >quantia_comprada</th>        <th class="col_heading level0 col2" >retencao</th>        <th class="col_heading level0 col3" >recencia</th>        <th class="col_heading level0 col4" >receita_media_por_quantia</th>        <th class="col_heading level0 col5" >grupo</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_632aef56_7ba9_11ec_8e30_0242ac1c0002level0_row0" class="row_heading level0 row0" >32754</th>
#                         <td id="T_632aef56_7ba9_11ec_8e30_0242ac1c0002row0_col0" class="data row0 col0" >0a0a92112bd4c708ca5fde585afaa872</td>
#                         <td id="T_632aef56_7ba9_11ec_8e30_0242ac1c0002row0_col1" class="data row0 col1" >0.000000</td>
#                         <td id="T_632aef56_7ba9_11ec_8e30_0242ac1c0002row0_col2" class="data row0 col2" >0.000000</td>
#                         <td id="T_632aef56_7ba9_11ec_8e30_0242ac1c0002row0_col3" class="data row0 col3" >0.465659</td>
#                         <td id="T_632aef56_7ba9_11ec_8e30_0242ac1c0002row0_col4" class="data row0 col4" >4.000000</td>
#                         <td id="T_632aef56_7ba9_11ec_8e30_0242ac1c0002row0_col5" class="data row0 col5" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_632aef56_7ba9_11ec_8e30_0242ac1c0002level0_row1" class="row_heading level0 row1" >32517</th>
#                         <td id="T_632aef56_7ba9_11ec_8e30_0242ac1c0002row1_col0" class="data row1 col0" >763c8b1c9c68a0229c42c9fc6f662b93</td>
#                         <td id="T_632aef56_7ba9_11ec_8e30_0242ac1c0002row1_col1" class="data row1 col1" >0.000000</td>
#                         <td id="T_632aef56_7ba9_11ec_8e30_0242ac1c0002row1_col2" class="data row1 col2" >0.000000</td>
#                         <td id="T_632aef56_7ba9_11ec_8e30_0242ac1c0002row1_col3" class="data row1 col3" >0.068681</td>
#                         <td id="T_632aef56_7ba9_11ec_8e30_0242ac1c0002row1_col4" class="data row1 col4" >2.128323</td>
#                         <td id="T_632aef56_7ba9_11ec_8e30_0242ac1c0002row1_col5" class="data row1 col5" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_632aef56_7ba9_11ec_8e30_0242ac1c0002level0_row2" class="row_heading level0 row2" >67190</th>
#                         <td id="T_632aef56_7ba9_11ec_8e30_0242ac1c0002row2_col0" class="data row2 col0" >dc4802a71eae9be1dd28f5d788ceb526</td>
#                         <td id="T_632aef56_7ba9_11ec_8e30_0242ac1c0002row2_col1" class="data row2 col1" >0.000000</td>
#                         <td id="T_632aef56_7ba9_11ec_8e30_0242ac1c0002row2_col2" class="data row2 col2" >0.000000</td>
#                         <td id="T_632aef56_7ba9_11ec_8e30_0242ac1c0002row2_col3" class="data row2 col3" >0.778846</td>
#                         <td id="T_632aef56_7ba9_11ec_8e30_0242ac1c0002row2_col4" class="data row2 col4" >2.027090</td>
#                         <td id="T_632aef56_7ba9_11ec_8e30_0242ac1c0002row2_col5" class="data row2 col5" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_632aef56_7ba9_11ec_8e30_0242ac1c0002level0_row3" class="row_heading level0 row3" >6521</th>
#                         <td id="T_632aef56_7ba9_11ec_8e30_0242ac1c0002row3_col0" class="data row3 col0" >459bef486812aa25204be022145caa62</td>
#                         <td id="T_632aef56_7ba9_11ec_8e30_0242ac1c0002row3_col1" class="data row3 col1" >0.000000</td>
#                         <td id="T_632aef56_7ba9_11ec_8e30_0242ac1c0002row3_col2" class="data row3 col2" >0.000000</td>
#                         <td id="T_632aef56_7ba9_11ec_8e30_0242ac1c0002row3_col3" class="data row3 col3" >0.053571</td>
#                         <td id="T_632aef56_7ba9_11ec_8e30_0242ac1c0002row3_col4" class="data row3 col4" >2.025010</td>
#                         <td id="T_632aef56_7ba9_11ec_8e30_0242ac1c0002row3_col5" class="data row3 col5" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_632aef56_7ba9_11ec_8e30_0242ac1c0002level0_row4" class="row_heading level0 row4" >63411</th>
#                         <td id="T_632aef56_7ba9_11ec_8e30_0242ac1c0002row4_col0" class="data row4 col0" >ff4159b92c40ebe40454e3e6a7c35ed6</td>
#                         <td id="T_632aef56_7ba9_11ec_8e30_0242ac1c0002row4_col1" class="data row4 col1" >0.000000</td>
#                         <td id="T_632aef56_7ba9_11ec_8e30_0242ac1c0002row4_col2" class="data row4 col2" >0.000000</td>
#                         <td id="T_632aef56_7ba9_11ec_8e30_0242ac1c0002row4_col3" class="data row4 col3" >0.640110</td>
#                         <td id="T_632aef56_7ba9_11ec_8e30_0242ac1c0002row4_col4" class="data row4 col4" >1.967725</td>
#                         <td id="T_632aef56_7ba9_11ec_8e30_0242ac1c0002row4_col5" class="data row4 col5" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_632aef56_7ba9_11ec_8e30_0242ac1c0002level0_row5" class="row_heading level0 row5" >32700</th>
#                         <td id="T_632aef56_7ba9_11ec_8e30_0242ac1c0002row5_col0" class="data row5 col0"

# %% [markdown]
# #### ELBOW 1 (scaled_data), ELBOW 2 (pca com 2), ELBOW3 (pca com 3)
# colocar os elbows juntos lado a lado para comparar o que melhor agrupa tudo com o kmeans de 3

# %% [markdown]
# In cluster analysis, the elbow method is a heuristic used in determining the number of clusters in a data set. The method consists of plotting the explained variation as a function of the number of clusters, and picking the elbow of the curve as the number of clusters to use.
# https://en.wikipedia.org/wiki/Elbow_method_(clustering)

# %% [markdown]
# Diferenças Marginalmente irrelevantes perante as conclusões do método Elbow

# %% [markdown]
# OBS.: FAZER COM O SILHOUTE SCORE TAMBÉM

# %%
# display(silhouette_score(scaled_data, clustered['grupo']),
# silhouette_score(pca2, clustered2['grupo']),
# silhouette_score(pca3, clustered3['grupo']),
# silhouette_score(scaled_data2, clustered4['grupo']))

# %% [markdown]
# # Usando modelo AGGLOMERATIVE CLUSTERING

# %% [markdown]
# **Metric** used to compute the linkage. Can be "euclidean", "l1", "l2",
# "manhattan", "cosine", or "precomputed".
# If linkage is "ward", only "euclidean" is accepted.
# If "precomputed", a distance matrix (instead of a similarity matrix)
# is needed as input for the fit method.
#
# ----
#
# **Linkage** : {'ward', 'complete', 'average', 'single'}, default='ward'
#     Which linkage criterion to use. The linkage criterion determines which
# distance to use between sets of observation. The algorithm will merge
# the pairs of cluster that minimize this criterion.
#
# 'ward' minimizes the variance of the clusters being merged.
#
# 'average' uses the average of the distances of each observation of
# the two sets.
#
# 'complete' or 'maximum' linkage uses the maximum distances between
# all observations of the two sets.
#
# 'single' uses the minimum of the distances between all observations
# of the two sets.

# %%
for lk in ['ward', 'complete', 'average', 'single']:
  agg1 = AgglomerativeClustering(n_clusters=3, linkage=lk)
  newy = agg1.fit_predict(scaled_data)
  print(newy)
