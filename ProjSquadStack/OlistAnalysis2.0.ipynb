# %% [markdown]
# # Fontes (biblioteca e links):

# %% [markdown]
# https://www.kaggle.com/olistbr/brazilian-ecommerce?select=olist_order_payments_dataset.csv

# %%
#!pip install pandas numpy matplotlib seaborn sklearn
# em caso de erro na importação do seaborn use -> %pip install seaborn

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import timedelta, datetime
import scipy
sns.set()

from IPython.display import display
from IPython.display import Image
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
pd.set_option('display.max_columns', None)
# %matplotlib inline

# %% [markdown]
# # Estrutura dos dados:

# %%
Image('https://i.imgur.com/HRhd2Y0.png', width=700)

# %% [markdown]
# ## Informações sobre dataset:

# %% [markdown]
# #### customer_id:
#
# key to the orders dataset. Each order has a unique customer_id.
#
# #### customer_unique_id:
#
# unique identifier of a customer.
#
# #### customer_zip_code_prefix:
#
# first five digits of customer zip code
#
# #### customer_city:
#
# customer city name
#
# #### order_id:
#
# order unique identifier
#
# #### order_item_id:
#
# sequential number identifying number of items included in the same order.
#
# #### product_id:
#
# product unique identifier
#
# #### seller_id:
#
# seller unique identifier
#
# #### shipping_limit_date:
#
# Shows the seller shipping limit date for handling the order over to the logistic partner.
#
# #### price:
#
# price item
#
# #### freight_value;
#
# freight value item (if an order has more than one item the freight value is splitted between items)
#
# #### payment_sequential:
#
# a customer may pay an order with more than one payment method. If he does so, a sequence will be created to
#
# #### payment_type:
#
# method of payment chosen by the customer.
#
# #### payment_installments:
#
# number of installments chosen by the customer.
#
# #### review_score:
#
# Note ranging from 1 to 5 given by the customer on a satisfaction survey.
#
# #### review_comment_title:
#
# Comment title from the review left by the customer, in Portuguese.
#
# #### review_comment_message:
#
# Comment message from the review left by the customer, in Portuguese.
#
# #### review_creation_date:
#
# Shows the date in which the satisfaction survey was sent to the customer.
#
# #### review_answer_timestamp:
#
# Shows satisfaction survey answer timestamp.
#
# #### customer_id:
#
# key to the customer dataset. Each order has a unique customer_id.
#
# #### order_status:
#
# Reference to the order status (delivered, shipped, etc).
#
# #### order_purchase_timestamp:
#
# Shows the purchase timestamp.
#
# #### order_approved_at:
#
# Shows the payment approval timestamp.
#
# #### order_delivered_carrier_date:
#
# Shows the order posting timestamp. When it was handled to the logistic partner.
#
# #### order_delivered_customer_date:
#
# Shows the actual order delivery date to the customer.
#
# #### order_estimated_delivery_date:
#
# Shows the estimated delivery date that was informed to customer at the purchase moment.
#
# #### product_name_lenght:
#
# number of characters extracted from the product name.
#
# #### product_description_lenght:
#
# number of characters extracted from the product description.
#
# #### product_photos_qty:
#
# number of product published photos
#
# #### product_weight_g:
#
# product weight measured in grams.
#
# #### product_length_cm:
#
# product length measured in centimeters.
#
# #### product_height_cm:
#
# product height measured in centimeters.
#
# #### product_width_cm:
#
# product width measured in centimeters.

# %% [markdown]
# ### Atenção:
#
# 1. Um pedido pode ter vários itens.
# 2. Cada item pode ser entregue por um vendedor distinto.

# %% [markdown]
# ### Anotações:
#
# 1.
# A Olist é uma loja de departamentos (marketplace) brasileira que atua no segmento de e-commerce, mas não é um e-commerce em si. Atua como uma empresa de tecnologia SaaS (Software as a Service) desde 2015. Oferece uma solução de marketplace (do segmento de e-commerce) para lojistas de todos os portes (e para a maioria dos segmentos) para aumentar suas vendas com presença online ou não .
#
# 2.
# A solução da Olist consiste em três aspectos: Software, Contratos com os principais marketplaces e Compartilhamento de Reputação. O diagrama abaixo mostra como a Olist vincula marketplaces, consumidores e varejistas
#
# 3.
# Lista:
# - … é uma grande loja de departamentos dentro de marketplaces.
# - … está conectado aos principais e-commerces do Brasil.
# - … não compra produtos.
# - … não mantém produtos em estoque.
# - … não realiza o envio de nenhum produto oferecido em sua loja.
# - Todos os produtos são vendidos e enviados pelos milhares de lojistas (cadastrados na Olist*) que vendem através da Olist.
# - Sua força está na união de todos os lojistas participantes, que estão vendendo produtos físicos.
# - O lojista participante é responsável por separar, embalar e levar os produtos até o operador logístico.

# %% [markdown]
# ## Desafio:
# - Modelo de machine learning que agrupe clientes como: ouro, prata e bronze
# - Features usadas: receita média, quantidade de pedidos, retenção, recência

# %% [markdown]
# ## Passo-a-passo:

# %% [markdown]
# Para conseguirmos variáveis relevantes para elaborar nosso modelo primeiro devemos tratar nossos dados para que obtenhamos uma estrutura organizada e o menos defeituosa possível para extrair as informações que precisamos. Iniciaremos este processo com as seguintes estapas:
# - Reunir os dados brutos através das chaves que os conectam ("primary keys" e "foreign keys" como no contexto de banco de dados).
# - Tratar os tipos de dados incorretos
# - Tratar os dados nulos
# - Fazer a seleção ou "criação" das variáveis necessárias através do feature selection
# - Criação do modelo a partir dessa reestruturação dos dados, formulando assim nossa variável explicada e nossas variáveis explicativas

# %% [markdown]
# # Observando estrutura dos arquivos:

# %%
import pathlib
x = tuple(pathlib.Path('.').rglob('olistcsv/*.csv'))
for i, each in enumerate(x): 
    print(i, each, sep='\n')
    v = pd.read_csv(x[i])
    print(tuple(v.columns))
    print(f'{v.shape[0]} lines', f'{v.shape[1]} columns\n')
# Out:
# 0
# olistcsv/olist_order_items_dataset.csv
# ('order_id', 'order_item_id', 'product_id', 'seller_id', 'shipping_limit_date', 'price', 'freight_value')
# 112650 lines 7 columns
#
# 1
# olistcsv/olist_geolocation_dataset.csv
# ('geolocation_zip_code_prefix', 'geolocation_lat', 'geolocation_lng', 'geolocation_city', 'geolocation_state')
# 1000163 lines 5 columns
#
# 2
# olistcsv/olist_order_payments_dataset.csv
# ('order_id', 'payment_sequential', 'payment_type', 'payment_installments', 'payment_value')
# 103886 lines 5 columns
#
# 3
# olistcsv/olist_sellers_dataset.csv
# ('seller_id', 'seller_zip_code_prefix', 'seller_city', 'seller_state')
# 3095 lines 4 columns
#
# 4
# olistcsv/product_category_name_translation.csv
# ('product_category_name', 'product_category_name_english')
# 71 lines 2 columns
#
# 5
# olistcsv/olist_customers_dataset.csv
# ('customer_id', 'customer_unique_id', 'customer_zip_code_prefix', 'customer_city', 'customer_state')
# 99441 lines 5 columns
#
# 6
# olistcsv/olist_orders_dataset.csv
# ('order_id', 'customer_id', 'order_status', 'order_purchase_timestamp', 'order_approved_at', 'order_delivered_carrier_date', 'order_delivered_customer_date', 'order_estimated_delivery_date')
# 99441 lines 8 columns
#
# 7
# olistcsv/olist_order_reviews_dataset.csv
# ('review_id', 'order_id', 'review_score', 'review_comment_title', 'review_comment_message', 'review_creation_date', 'review_answer_timestamp')
# 99224 lines 7 columns
#
# 8
# olistcsv/olist_products_dataset.csv
# ('product_id', 'product_category_name', 'product_name_lenght', 'product_description_lenght', 'product_photos_qty', 'product_weight_g', 'product_length_cm', 'product_height_cm', 'product_width_cm')
# 32951 lines 9 columns

# %% [markdown]
# # Raw datasets (extração bruta):

# %% [markdown]
# ### Anotações sobre os arquivos e colunas importantes:
# **olistcsv/olist_order_items_dataset.csv ->**
# o preço do produto é preço + frete
# order_id, product_id
#
# **olistcsv/olist_order_payments_dataset.csv ->**
# order_id, payment_sequential, payment_type, payment_installments, payment_value
#
# **olistcsv/olist_customers_dataset.csv -> informações sobre o cliente**
# customer_id, customer_unique_id
#
# **olistcsv/olist_order_reviews_dataset.csv ->**
# order_id, review_id, review_score, review_comment_message
#
# **time notes ->**
# considerar compra por tempo, quantidade, compra média no tempo, primeira e última compra

# %% [markdown]
# ### Lendo dados brutos:

# %%
# ADICIONAR ETAPA DO MinIO
path = '/home/ricardo/Documentos/git/SVMSquad/ProjSquadStack/olistcsv/'
raw_price_freight = pd.read_csv(path + 'olist_order_items_dataset.csv')
raw_payment = pd.read_csv(path + 'olist_order_payments_dataset.csv')
raw_client_review = pd.read_csv(path + 'olist_order_reviews_dataset.csv')
raw_orders_central = pd.read_csv(path + 'olist_orders_dataset.csv')
raw_costumer = pd.read_csv(path + 'olist_customers_dataset.csv')

# %% [markdown]
# ### Unindos as tabelas e descrevendo "shape" e colunas:

# %% [markdown]
# raw_orders_central # Tabela dimensão -> 'order_id', 'customer_id'
#
# raw_costumer # Tabela dimensão -> 'customer_id', 'customer_unique_id'
#
#
# raw_price_freight # Tabela fato
#
# raw_payment # Tabela fato
#
# raw_client_review # Tabela fato

# %%
# Formação de tabelas e seus vínculos explicativos

df1 = pd.merge(left=raw_orders_central, right=raw_costumer, on='customer_id', how='outer')
price_freight = pd.merge(left=raw_price_freight, right=df1, on='order_id', how='left')
payment = pd.merge(left=raw_payment, right=df1, on='order_id', how='left')
client_review = pd.merge(left=raw_client_review, right=df1, on='order_id', how='left')

# %%
del raw_client_review, raw_costumer, raw_orders_central, raw_payment, raw_price_freight

# %% [markdown]
# ## Uma investigação sobre a organização dos dados:

# %% [markdown]
# Queremos entender se **payment_value** representa a soma da coluna **price** e da coluna **freight_value**
#
# 1. Primeiramente usaremos os clientes com maior diversidade em seus pedidos:

# %%
display(price_freight[['customer_id', 'order_id']].value_counts().head(2))
display(price_freight[['customer_id', 'order_id']].value_counts().tail(1))

display(payment[['customer_id', 'order_id']].value_counts().head(2))
display(payment[['customer_id', 'order_id']].value_counts().tail(2))
# Out:
# customer_id                       order_id
# fc3d1daec319d62d49bfb5e1f83123e9  8272b63d03f5f79c56e9e4120aec44ef    21
# be1b70680b9f9694d8c70f41fa3dc92b  1b15974a0141d54e36626dca3fdc731a    20
# dtype: int64
# customer_id                       order_id
# 800512d0215633d567abe5ce2591f01d  971602526032659f775bbbe5b9142179    1
# dtype: int64
# customer_id                       order_id
# 9af2372a1e49340278e7c1ef8d749f34  fa65dad1b0e818e3ccc5cb0e39231352    29
# 92cd3ec6e2d643d4ebd0e3d6238f69e2  ccf804e764ed5650cd8759557269dc13    26
# dtype: int64
# customer_id                       order_id
# 56f10439f7b396c7c7b5445357c22e9b  4f601391cdfe2a3984a4b1680c2c3d9a    1
# ffffe8b65bbe3087b653a978c870db99  2e935fa1d39497aa0ec3f1107fbfb5b8    1
# dtype: int64

# %% [markdown]
# ->

# %% [markdown]
# 2. Agora usaremos eles como nossas variáveis de comparação:
#
# **8272b63d03f5f79c56e9e4120aec44ef**,
#
# **1b15974a0141d54e36626dca3fdc731a**,
#
# **fa65dad1b0e818e3ccc5cb0e39231352**,
#
# **ccf804e764ed5650cd8759557269dc13**,
#
# **971602526032659f775bbbe5b9142179**,
#
# **4f601391cdfe2a3984a4b1680c2c3d9a**

# %%
def comparar_pedidos(df1, df2, cod_pedido):
    d1 = df1[df1['order_id'] == cod_pedido]
    d2 = df2[df2['order_id'] == cod_pedido]
    d1.columns = d2.columns = ['order_id', 'result']
    print(f'{d1["result"].to_numpy()[0]} == {d1["result"].to_numpy()[0]}')

# %%
newdf = price_freight.copy()
newdf['result'] = price_freight.price + price_freight.freight_value

test1 = payment.groupby('order_id', as_index=False).sum()[['order_id', 'payment_value']]
test2 = newdf.groupby('order_id', as_index=False).sum()[['order_id', 'result']]

lista = '8272b63d03f5f79c56e9e4120aec44ef, 1b15974a0141d54e36626dca3fdc731a, fa65dad1b0e818e3ccc5cb0e39231352, ccf804e764ed5650cd8759557269dc13, 971602526032659f775bbbe5b9142179, 4f601391cdfe2a3984a4b1680c2c3d9a'.split(', ')
awnser = np.arange(len(lista))

for order in lista:
    comparar_pedidos(test1, test2, order)
# Out:
# 196.11 == 196.11
# 2202.4 == 2202.4
# 457.99 == 457.99
# 62.68 == 62.68
# 251.64 == 251.64
# 174.11 == 174.11

# %% [markdown]
# Nossa investigação demonstrou que a soma da coluna "price" e "freight_value" agrupada pela colunar "Order_id" é a forma correta de se compreender a coluna "payment_value". Usamos esta investigação para podermos explicitar a igualdade entre as colunas que existem em diferentes tabelas (A tabela price_freight e a payment)

# %%
del newdf, test1, test2, lista, awnser

# %% [markdown]
# # Tratando os tipos de dados:

# %% [markdown]
# ## PERGUNTA: TRATAR TODAS AS TABELAS?

# %%
def transform(df: pd.DataFrame, colunas: list) -> pd.DataFrame:
    for each in colunas:
        df[each] = pd.to_datetime(df[each], errors='coerce')
    df['customer_zip_code_prefix'].astype('object')

# %%
# Tabela client_review
colunas = ('review_creation_date review_answer_timestamp order_purchase_timestamp order_approved_at ' +
'order_delivered_carrier_date order_delivered_customer_date order_estimated_delivery_date').split()

transform(client_review, colunas)


# Tabela payment 
colunas = ('order_purchase_timestamp order_approved_at order_delivered_carrier_date'
          + ' order_delivered_customer_date order_estimated_delivery_date').split()

transform(payment, colunas)


# Tabela price_freight
colunas = ('shipping_limit_date order_purchase_timestamp order_approved_at order_delivered_carrier_date'
          + ' order_delivered_customer_date order_estimated_delivery_date').split()

transform(price_freight, colunas)

# %%
del colunas

# %% [markdown]
# # Análise dos dados nulos

# %%
price_freight.name = 'price_freight'
payment.name = 'payment'
client_review.name = 'client_review'

# %%
dados = [price_freight, payment, client_review]

for v in dados:
    print(f'Tabela {v.name.capitalize()}:')
    display(v.isna().sum()[v.isna().sum() > 0])
    print('-'*20, '\n')
# Out:
# Tabela Price_freight:
# order_approved_at                  15
# order_delivered_carrier_date     1194
# order_delivered_customer_date    2454
# dtype: int64
# --------------------
#
# Tabela Payment:
# order_approved_at                 175
# order_delivered_carrier_date     1888
# order_delivered_customer_date    3132
# dtype: int64
# --------------------
#
# Tabela Client_review:
# review_comment_title             87656
# review_comment_message           58247
# order_approved_at                  156
# order_delivered_carrier_date      1756
# order_delivered_customer_date     2865
# dtype: int64
# --------------------

# %% [markdown]
# Considerando que o modelo que será criado agrupara os clientes baseados nas variáveis **receita média**, **quantidade de pedidos**, **retenção** e **recência**, os valores nulos descritos por tabela e por coluna acima não afetam os resultados

# %% [markdown]
# # Investigando distribuição e composição dos dados:

# %%
num_att1 = price_freight.select_dtypes(include=['int', 'float']).drop(columns=['order_item_id', 'customer_zip_code_prefix'])
num_att2 = payment['payment_value']
num_att3 = client_review['review_score']


p1 = pd.concat([pd.Series(price_freight.price.skew()), pd.Series(price_freight.freight_value.skew())], axis=0, ignore_index=True)
p2 = pd.concat([pd.Series(price_freight.price.kurt()), pd.Series(price_freight.freight_value.kurt())], axis=0, ignore_index=True)
p2.index = p1.index = ['freight_value', 'price']

p = pd.concat([num_att1.describe().T, p1.T, p2.T], axis=1, ignore_index=True)
p.columns = ['count', 'mean', 'std', 'min', '25%', '50%', '75%', 'max', 'skew', 'kurtosis']
p
# Out:
#                   count        mean         std   min    25%    50%     75%  \
# price          112650.0  120.653739  183.633928  0.85  39.90  74.99  134.90
# freight_value  112650.0   19.990320   15.806405  0.00  13.08  16.26   21.15
#
#                    max      skew    kurtosis
# price          6735.00  5.639870   59.788253
# freight_value   409.68  7.923208  120.828298

# %% [markdown]
# Podemos perceber que ambas as distribuições são significativamente dispersas através dos valores do terceiro quartil (coluna "75%") e do valor máximo (coluna "max"). O frete, apesar de ter uma composição muito menos dispersa, possui o mesmo comportamento que o preço em relação ao demonstrado do terceiro ao último quartil.
#
# Observemos agora sua distribuição em um gráfico para observar como se comporta a quantidade de dados em sua estrutura.

# %%
# Tabela Price_freight: ver distribuição do price, freight_value, order_purchase_timestamp (max, min e dist.)
# Tabela Payment: ver distribuição do payment_sequential, payment_type
# Tabela Client_review: ver distribuição do review_score, 

plt.figure(figsize=(16,8))

plt.subplot(2, 1, 1)
sns.kdeplot(price_freight.price, label='Price distribution', shade=True)
sns.kdeplot(payment.payment_value, label='Payment distribution', shade=True)
plt.annotate(
    'Maior valor da coluna "price"',
    (price_freight.price.max(), 0.0001),
    arrowprops=dict(facecolor='black', shrink=0.05),
    xytext=(price_freight.price.max(), 0.002),
    horizontalalignment='left',
    verticalalignment='top'
    )
plt.annotate(
    'Maior valor da coluna "payment.payment_value"',
    (payment.payment_value.max(), 0.0001),
    arrowprops=dict(facecolor='black', shrink=0.05),
    xytext=(payment.payment_value.max(), 0.003),
    horizontalalignment='right',
    verticalalignment='top'
    )
plt.annotate(
    'Maior valor da coluna "freight_value"',
    (price_freight.freight_value.max(), 0.0001),
    arrowprops=dict(facecolor='black', shrink=0.05),
    xytext=(price_freight.freight_value.max(), 0.004),
    horizontalalignment='left',
    verticalalignment='top'
    )
plt.legend(loc='best')

plt.subplot(2, 1, 2)
sns.kdeplot(price_freight.freight_value, label='Freight distribution', shade=True)
plt.annotate(
    'Maior valor da coluna "freight_value"',
    (price_freight.freight_value.max(), 0.001),
    arrowprops=dict(facecolor='black', shrink=0.05),
    xytext=(price_freight.freight_value.max(), 0.02),
    horizontalalignment='right',
    verticalalignment='top'
    )
plt.legend(loc='best')

plt.show()
# Out:
# <AxesSubplot:>
# <AxesSubplot:xlabel='price', ylabel='Density'>
# <AxesSubplot:xlabel='price', ylabel='Density'>
# Text(6735.0, 0.002, 'Maior valor da coluna "price"')
# Text(13664.08, 0.003, 'Maior valor da coluna "payment.payment_value"')
# Text(409.68, 0.004, 'Maior valor da coluna "freight_value"')
# <AxesSubplot:>
# <AxesSubplot:xlabel='freight_value', ylabel='Density'>
# Text(409.68, 0.02, 'Maior valor da coluna "freight_value"')

# %%
# Plotar boxplot
plt.figure(figsize=(16,8))

for i, cl in enumerate(['price', 'freight_value']):
    plt.subplot(1, 2, i+1)
    sns.boxplot(x=price_freight[cl])
# Out:
# <AxesSubplot:>
# <AxesSubplot:xlabel='price'>
# <AxesSubplot:>
# <AxesSubplot:xlabel='freight_value'>

# %% [markdown]
# Torna-se possível, agora, perceber visualmente a capacidade de influência dos outliers sobre a estrutura. É importante notar onde está localizada a maior parte dos dados, se nos valores dispersos ou se nos valores concentrados para considerações finais

# %%
# Encontrar a contagem (unidades) de cada diferente preço e depois soma-los
p1 = price_freight.price.value_counts()[price_freight.price.value_counts() < 100].sum()
p2 = price_freight.price.value_counts()[price_freight.price.value_counts() > 100].sum()
ptotal = p1 + p2

print(f'Valores abaixo de 100: {p1} unidades', end=' --- ')
print(f'Porcentagem de {p1/ptotal:.2%}')
print()
print(f'Valores acima de 100: {p2} unidades', end=' --- ')
print(f'Porcentagem de {p2/ptotal:.2%}')
# Out:
# Valores abaixo de 100: 39400 unidades --- Porcentagem de 35.04%
#
# Valores acima de 100: 73050 unidades --- Porcentagem de 64.96%

# %% [markdown]
# Portanto, a conclusão que podemos tirar desses dados é que os outliers não são somente dados extraordinários que podemos considerar retira-los pois sua predominancia é consideravelmente maior que os dados menos dispersos (em torno da mediana)

# %%
del p1, p2, ptotal

# %% [markdown]
# # Extraindo as colunas (features) para o modelo:

# %% [markdown]
# Antes de tudo devemos definir o que queremos e o que cada um desses objetivos significa:
# receita média, quantidade de pedidos, retenção, recência
# 1. **Quantidade de pedidos**: quantidade de pedidos realizados por cliente.
# 2. **Retenção**: Período de compras do cliente, o tempo inicial sobre tempo final de suas compras realizadas.
# 3. **Recência**: Diferença entre a data da última compra e a data de hoje.
# 4. **Receita média**: receita gerada por cliente sobre a quantidade de pedidos realizados (receita média gerada pelo cliente) ou sobre o período que ele comprou (receita média gerada por cliente sobre tempo).

# %% [markdown]
# ### 1. Quantidade de pedidos:

# %% [markdown]
# Os dados abaixo descrevem a quantidade de compras feitas por cliente e a quantidade de itens por cliente

# %%
Cliente = dados[0][['customer_unique_id', 'order_id']].groupby(['customer_unique_id']).agg(['nunique','count']).sort_values([('order_id', 'nunique'), ('order_id', 'count')], ascending=False)
Cliente['order_id'].head(50).rename(dict(nunique='valores únicos', count='contagem total'), axis=1).style.bar(color=['#C324EB', '#8824EB'])
# Out:
# <style type="text/css">
# #T_c23bb_row0_col0, #T_c23bb_row19_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#8824EB 100.0%, transparent 100.0%);
# }
# #T_c23bb_row0_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#8824EB 60.0%, transparent 60.0%);
# }
# #T_c23bb_row1_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#8824EB 46.2%, transparent 46.2%);
# }
# #T_c23bb_row1_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#8824EB 50.0%, transparent 50.0%);
# }
# #T_c23bb_row2_col0, #T_c23bb_row3_col0, #T_c23bb_row4_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#8824EB 30.8%, transparent 30.8%);
# }
# #T_c23bb_row2_col1, #T_c23bb_row48_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#8824EB 40.0%, transparent 40.0%);
# }
# #T_c23bb_row3_col1, #T_c23bb_row4_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#8824EB 25.0%, transparent 25.0%);
# }
# #T_c23bb_row5_col0, #T_c23bb_row6_col0, #T_c23bb_row7_col0, #T_c23bb_row8_col0, #T_c23bb_row9_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#8824EB 23.1%, transparent 23.1%);
# }
# #T_c23bb_row5_col1, #T_c23bb_row6_col1, #T_c23bb_row49_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#8824EB 35.0%, transparent 35.0%);
# }
# #T_c23bb_row7_col1, #T_c23bb_row10_col1, #T_c23bb_row11_col1, #T_c23bb_row20_col1, #T_c23bb_row21_col1, #T_c23bb_row22_col1, #T_c23bb_row23_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#8824EB 15.0%, transparent 15.0%);
# }
# #T_c23bb_row8_col1, #T_c23bb_row9_col1, #T_c23bb_row12_col1, #T_c23bb_row13_col1, #T_c23bb_row24_col1, #T_c23bb_row25_col1, #T_c23bb_row26_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#8824EB 10.0%, transparent 10.0%);
# }
# #T_c23bb_row10_col0, #T_c23bb_row11_col0, #T_c23bb_row12_col0, #T_c23bb_row13_col0, #T_c23bb_row14_col0, #T_c23bb_row15_col0, #T_c23bb_row16_col0, #T_c23bb_row17_col0, #T_c23bb_row18_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#8824EB 15.4%, transparent 15.4%);
# }
# #T_c23bb_row14_col1, #T_c23bb_row15_col1, #T_c23bb_row16_col1, #T_c23bb_row17_col1, #T_c23bb_row18_col1, #T_c23bb_row27_col1, #T_c23bb_row28_col1, #T_c23bb_row29_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#8824EB 5.0%, transparent 5.0%);
# }
# #T_c23bb_row19_col0, #T_c23bb_row20_col0, #T_c23bb_row21_col0, #T_c23bb_row22_col0, #T_c23bb_row23_col0, #T_c23bb_row24_col0, #T_c23bb_row25_col0, #T_c23bb_row26_col0, #T_c23bb_row27_col0, #T_c23bb_row28_col0, #T_c23bb_row29_col0, #T_c23bb_row30_col0, #T_c23bb_row31_col0, #T_c23bb_row32_col0, #T_c23bb_row33_col0, #T_c23bb_row34_col0, #T_c23bb_row35_col0, #T_c23bb_row36_col0, #T_c23bb_row37_col0, #T_c23bb_row38_col0, #T_c23bb_row39_col0, #T_c23bb_row40_col0, #T_c23bb_row41_col0, #T_c23bb_row42_col0, #T_c23bb_row43_col0, #T_c23bb_row44_col0, #T_c23bb_row45_col0, #T_c23bb_row46_col0, #T_c23bb_row47_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#8824EB 7.7%, transparent 7.7%);
# }
# #T_c23bb_row30_col1, #T_c23bb_row31_col1, #T_c23bb_row32_col1, #T_c23bb_row33_col1, #T_c23bb_row34_col1, #T_c23bb_row35_col1, #T_c23bb_row36_col1, #T_c23bb_row37_col1, #T_c23bb_row38_col1, #T_c23bb_row39_col1, #T_c23bb_row40_col1, #T_c23bb_row41_col1, #T_c23bb_row42_col1, #T_c23bb_row43_col1, #T_c23bb_row44_col1, #T_c23bb_row45_col1, #T_c23bb_row46_col1, #T_c23bb_row47_col1, #T_c23bb_row48_col0, #T_c23bb_row49_col0 {
#   width: 10em;
#   height: 80%;
# }
# </style>
# <table id="T_c23bb_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >valores únicos</th>
#       <th class="col_heading level0 col1" >contagem total</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >customer_unique_id</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c23bb_level0_row0" class="row_heading level0 row0" >8d50f5eadf50201ccdcedfb9e2ac8455</th>
#       <td id="T_c23bb_row0_col0" class="data row0 col0" >16</td>
#       <td id="T_c23bb_row0_col1" class="data row0 col1" >16</td>
#     </tr>
#     <tr>
#       <th id="T_c23bb_level0_row1" class="row_heading level0 row1" >3e43e6105506432c953e165fb2acf44c</th>
#       <td id="T_c23bb_row1_col0" class="data row1 col0" >9</td>
#       <td id="T_c23bb_row1_col1" class="data row1 col1" >14</td>
#     </tr>
#     <tr>
#       <th id="T_c23bb_level0_row2" class="row_heading level0 row2" >ca77025e7201e3b30c44b472ff346268</th>
#       <td id="T_c23bb_row2_col0" class="data row2 col0" >7</td>
#       <td id="T_c23bb_row2_col1" class="data row2 col1" >12</td>
#     </tr>
#     <tr>
#       <th id="T_c23bb_level0_row3" class="row_heading level0 row3" >1b6c7548a2a1f9037c1fd3ddfed95f33</th>
#       <td id="T_c23bb_row3_col0" class="data row3 col0" >7</td>
#       <td id="T_c23bb_row3_col1" class="data row3 col1" >9</td>
#     </tr>
#     <tr>
#       <th id="T_c23bb_level0_row4" class="row_heading level0 row4" >6469f99c1f9dfae7733b25662e7f1782</th>
#       <td id="T_c23bb_row4_col0" class="data row4 col0" >7</td>
#       <td id="T_c23bb_row4_col1" class="data row4 col1" >9</td>
#     </tr>
#     <tr>
#       <th id="T_c23bb_level0_row5" class="row_heading level0 row5" >63cfc61cee11cbe306bff5857d00bfe4</th>
#       <td id="T_c23bb_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_c23bb_row5_col1" class="data row5 col1" >11</td>
#     </tr>
#     <tr>
#       <th id="T_c23bb_level0_row6" class="row_heading level0 row6" >dc813062e0fc23409cd255f7f53c7074</th>
#       <td id="T_c23bb_row6_col0" class="data row6 col0" >6</td>
#       <td id="T_c23bb_row6_col1" class="data row6 col1" >11</td>
#     </tr>
#     <tr>
#       <th id="T_c23bb_level0_row7" class="row_heading level0 row7" >47c1a3033b8b77b3ab6e109eb4d5fdf3</th>
#       <td id="T_c23bb_row7_col0" class="data row7 col0" >6</td>
#       <td id="T_c23bb_row7_col1" class="data row7 col1" >7</td>
#     </tr>
#     <tr>
#       <th id="T_c23bb_level0_row8" class="row_heading level0 row8" >12f5d6e1cbf93dafd9dcc19095df0b3d</th>
#       <td id="T_c23bb_row8_col0" class="data row8 col0" >6</td>
#       <td id="T_c23bb_row8_col1" class="data row8 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_c23bb_level0_row9" class="row_heading level0 row9" >f0e310a6839dce9de1638e0fe5ab282a</th>
#       <td id="T_c23bb_row9_col0" class="data row9 col0" >6</td>
#       <td id="T_c23bb_row9_col1" class="data row9 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_c23bb_level0_row10" class="row_heading level0 row10" >35ecdf6858edc6427223b64804cf028e</th>
#       <td id="T_c23bb_row10_col0" class="data row10 col0" >5</td>
#       <td id="T_c23bb_row10_col1" class="data row10 col1" >7</td>
#     </tr>
#     <tr>
#       <th id="T_c23bb_level0_row11" class="row_heading level0 row11" >56c8638e7c058b98aae6d74d2dd6ea23</th>
#       <td id="T_c23bb_row11_col0" class="data row11 col0" >5</td>
#       <td id="T_c23bb_row11_col1" class="data row11 col1" >7</td>
#     </tr>
#     <tr>
#       <th id="T_c23bb_level0_row12" class="row_heading level0 row12" >394ac4de8f3acb14253c177f0e15bc58</th>
#       <td id="T_c23bb_row12_col0" class="data row12 col0" >5</td>
#       <td id="T_c23bb_row12_col1" class="data row12 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_c23bb_level0_row13" class="row_heading level0 row13" >4e65032f1f574189fb793bac5a867bbc</th>
#       <td id="T_c23bb_row13_col0" class="data row13 col0" >5</td>
#       <td id="T_c23bb_row13_col1" class="data row13 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_c23bb_level0_row14" class="row_heading level0 row14" >5e8f38a9a1c023f3db718edcf926a2db</th>
#       <td id="T_c23bb_row14_col0" class="data row14 col0" >5</td>
#       <td id="T_c23bb_row14_col1" class="data row14 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_c23bb_level0_row15" class="row_heading level0 row15" >74cb1ad7e6d5674325c1f99b5ea30d82</th>
#       <td id="T_c23bb_row15_col0" class="data

# %% [markdown]
# A partir da tabela encontrada extrairemos os dados da contagem de pedidos realizados por cliente (order_id + nunique)

# %%
Cliente = Cliente['order_id']['nunique'].sort_values(ascending=False)
Cliente
# Out:
# customer_unique_id
# 8d50f5eadf50201ccdcedfb9e2ac8455    16
# 3e43e6105506432c953e165fb2acf44c     9
# ca77025e7201e3b30c44b472ff346268     7
# 1b6c7548a2a1f9037c1fd3ddfed95f33     7
# 6469f99c1f9dfae7733b25662e7f1782     7
#                                     ..
# 42c933d49eb9dfdf9db525156e9aa506     1
# 42c8ccbe558d063718d19cff01505af9     1
# 42c837a3d7df8cfa87de63fbc1aade2f     1
# 42c81f944761257c8df3b028e6b738cd     1
# ffffd2657e2aad2907e67c3e9daecbeb     1
# Name: nunique, Length: 95420, dtype: int64

# %% [markdown]
# ### Etapa intermediária:

# %% [markdown]
# Visando encontrar a retenção e a recência iremos trabalhar com a variável tempo, analisando seu comportamento e anexado a tabela principal que usaremos para o modelo. Usaremos a coluna "order_purchase_timestamp" para tal análise

# %%
p2 = dados[0][['customer_unique_id', 'order_purchase_timestamp']].groupby(['customer_unique_id'], as_index=False).agg(['max', 'min'])['order_purchase_timestamp']
p2['time'] = p2['max'] - p2['min']
p2 = p2.reset_index()

# %% [markdown]
# substituiremos os valores que possuem "0 dias" de compra por "1 dia" de compra pois a diferença entre tempo máximo e mínimo das compras dos clientes que compraram somente uma vez gerou essa incoerência lógica.

# %%
p2.time[p2.time < timedelta(days=1)] = timedelta(days=1)
# Out:
# /tmp/ipykernel_5732/3648004967.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   p2.time[p2.time < timedelta(days=1)] = timedelta(days=1)

# %%
p2.sort_values('time', ascending=False)
# Out:
#                      customer_unique_id                 max  \
# 19031  32ea3bdedab835c3aa6cb68ce66565ef 2018-06-28 11:46:04
# 76403  ccafc1c3f270410521c3c6f3b249870f 2018-06-07 19:03:12
# 80964  d8f3c4f441a9b59a29f977df16724f38 2018-08-24 17:52:59
# 55465  94e5ea5a8c1bf546db2739673060c43f 2018-05-09 13:49:19
# 50627  87b3f231705783eb2217e25851c0a45d 2018-05-04 11:14:37
# ...                                 ...                 ...
# 32158  560f0209de88107bec357f67dade4362 2018-05-16 09:20:00
# 32157  560a6e0ef8a24a50cd83690e297827ca 2017-05-02 21:33:57
# 32156  560a6282f0b9f4176cb56ff6024632d8 2018-08-01 15:25:31
# 32155  560a4662eb4a058fa759def32ff39feb 2018-04-01 20:56:06
# 95419  ffffd2657e2aad2907e67c3e9daecbeb 2017-05-02 20:18:45
#
#                       min              time
# 19031 2016-10-03 09:44:50 633 days 02:01:14
# 76403 2016-10-06 19:33:34 608 days 23:29:38
# 80964 2017-01-18 21:08:18 582 days 20:44:41
# 55465 2016-10-05 21:10:56 580 days 16:38:23
# 50627 2016-10-08 18:45:34 572 days 16:29:03
# ...                   ...               ...
# 32158 2018-05-16 09:20:00   1 days 00:00:00
# 32157 2017-05-02 21:33:57   1 days 00:00:00
# 32156 2018-08-01 15:25:31   1 days 00:00:00
# 32155 2018-04-01 20:56:06   1 days 00:00:00
# 95419 2017-05-02 20:18:45   1 days 00:00:00
#
# [95420 rows x 4 columns]

# %% [markdown]
# ### 2. Retenção:

# %% [markdown]
# Podemos ver a distribuição dos dados que demonstram a quantidade de clientes e seus respectivos tempos como clientes.

# %%
fig = plt.figure(figsize=(16, 8))
fig.suptitle('Distribuição do tempo de retenção dos clientes', fontsize=18)

top = p2.time.dt.days.value_counts().nlargest(1).index[0]

plt.subplot(1, 2, 1,)
sns.kdeplot(p2.time.dt.days, palette=sns.palettes.light_palette, shade=True, color='Green')
sns.kdeplot(p2.time[p2.time > timedelta(days=2)].dt.days, shade=True, color='Red')
plt.annotate(
    'Dados mais frequentes entre clientes\ncom mais de um dia de compra',
    (top+20, 0.006),
    arrowprops=dict(facecolor='black', shrink=0.01),
    xytext=(top+100, 0.02),
    horizontalalignment='left',
    verticalalignment='top'
)
plt.annotate(
    'Dados mais frequentes são os de um dia de compra',
    (0, 0.14),
    arrowprops=dict(facecolor='black', shrink=0.01),
    xytext=(100, 0.13),
    horizontalalignment='left',
    verticalalignment='top'
)
plt.xlabel('Distribuição de clientes por tempo de retenção')

plt.subplot(1, 2, 2)
sns.kdeplot(p2.time[p2.time > timedelta(days=2)].dt.days, shade=True, color='Red')
plt.xlabel('Distribuição de clientes por tempo de retenção\ndesconsiderando os menores que 1 dia')
plt.show()
# Out:
# Text(0.5, 0.98, 'Distribuição do tempo de retenção dos clientes')
# <AxesSubplot:>
# <AxesSubplot:xlabel='time', ylabel='Density'>
# <AxesSubplot:xlabel='time', ylabel='Density'>
# Text(101, 0.02, 'Dados mais frequentes entre clientes\ncom mais de um dia de compra')
# Text(100, 0.13, 'Dados mais frequentes são os de um dia de compra')
# Text(0.5, 0, 'Distribuição de clientes por tempo de retenção')
# <AxesSubplot:>
# <AxesSubplot:xlabel='time', ylabel='Density'>
# Text(0.5, 0, 'Distribuição de clientes por tempo de retenção\ndesconsiderando os menores que 1 dia')

# %%
dist = p2.time.dt.days.sort_values(ascending=False)
dist = pd.Series(np.where(dist == 1, dist.astype(str) + ' dia', dist.astype(str) + ' dias'))
((dist.value_counts().nlargest(4) / dist.value_counts().sum()).round(6) * 100).astype(str) + '%'
# Out:
# 1 dia     97.8809%
# 6 dias     0.0314%
# 2 dias     0.0314%
# 3 dias     0.0272%
# dtype: object

# %% [markdown]
# A visualização de dados acima nos permite enxergar com clareza como a quantidade de compras é feita em somente uma data específica, ou seja, baixa retenção dos clientes

# %% [markdown]
# Agora que compreendemos a composição dos dados que serão inseridos na nossa tabela X (variável explicativa), podemos prosseguir com esta união

# %%
Cliente = pd.merge(left=Cliente, right=p2[['customer_unique_id', 'time']], how='outer', on='customer_unique_id').sort_values('time', ascending=False)

# %% [markdown]
# ### 3. Recência:

# %% [markdown]
# Usaremos a coluna "max" para, através da data da última compra, realizarmos a comparação com a data de hoje visando encontrar o tempo de ausência desde a última compra

# %%
p2['recencia'] = np.array([datetime.today() for _ in range(p2['max'].shape[0])], dtype=np.datetime64) - p2['max']
Cliente = pd.merge(left=Cliente, right=p2[['customer_unique_id', 'recencia']], how='outer', on='customer_unique_id').sort_values('time', ascending=False)

# %%
Cliente.columns = 'cliente quantia_comprada retencao recencia'.split()

# %%
Cliente
# Out:
#                                 cliente  quantia_comprada          retencao  \
# 0      32ea3bdedab835c3aa6cb68ce66565ef                 3 633 days 02:01:14
# 1      ccafc1c3f270410521c3c6f3b249870f                 2 608 days 23:29:38
# 2      d8f3c4f441a9b59a29f977df16724f38                 2 582 days 20:44:41
# 3      94e5ea5a8c1bf546db2739673060c43f                 2 580 days 16:38:23
# 4      87b3f231705783eb2217e25851c0a45d                 2 572 days 16:29:03
# ...                                 ...               ...               ...
# 33177  42c837a3d7df8cfa87de63fbc1aade2f                 1   1 days 00:00:00
# 33176  42c81f944761257c8df3b028e6b738cd                 1   1 days 00:00:00
# 33175  42c769ded134d534a9dedabd8f83c547                 1   1 days 00:00:00
# 33174  42f296ed9782627fc7408a950975cfd2                 1   1 days 00:00:00
# 95419  ffffd2657e2aad2907e67c3e9daecbeb                 1   1 days 00:00:00
#
#                        recencia
# 0     1314 days 02:50:34.728348
# 1     1334 days 19:33:26.775449
# 2     1256 days 20:43:39.779190
# 3     1364 days 00:47:19.758477
# 4     1369 days 03:22:01.754597
# ...                         ...
# 33177 1288 days 01:12:32.733131
# 33176 1720 days 20:45:31.733130
# 33175 1424 days 19:08:14.733129
# 33174 1729 days 19:24:40.733183
# 95419 1735 days 18:17:53.790824
#
# [95420 rows x 4 columns]

# %%
sns.kdeplot(Cliente.recencia.dt.days, shade=True, color='purple')
plt.xlabel('Recência')
# Out:
# <AxesSubplot:xlabel='recencia', ylabel='Density'>
# Text(0.5, 0, 'Recência')

# %% [markdown]
# ### 4. Receita média:

# %% [markdown]
# Para encontrarmos a receita do total de compras feitas por cliente devemos realizar o agrupamento por cliente, soma-lo e anexa-lo na Tabela Cliente.

# %%
p1 = dados[0][['customer_unique_id', 'price', 'freight_value']].groupby('customer_unique_id', as_index=False).sum() #.groupby()

# MUDAR p1['receita_total_por_cliente'] PARA "p1.price" CASO A RECEITA NÃO DEVA CONSIDERAR O FRETE
# OU p1.rename({'price':'receita_total_por_cliente'}, axis=1) E DELETE A LINHA ABAIXO
p1['receita_total_por_cliente'] = p1.price + p1.freight_value
Cliente = pd.merge(left=Cliente, right=p1[['customer_unique_id', 'receita_total_por_cliente']], left_on='cliente', right_on='customer_unique_id', how='outer').drop(columns='customer_unique_id')

# %% [markdown]
# Agora seram formadas as duas últimas variáveis relacionadas a coluna da receita por cliente

# %%
Cliente['receita_media_por_quantia'] = Cliente['receita_total_por_cliente']/Cliente['quantia_comprada']
Cliente['receita_media_por_dia'] = Cliente['receita_total_por_cliente']/Cliente['retencao'].dt.days
Cliente.drop(columns='receita_total_por_cliente', inplace=True)
Cliente
# Out:
#                                 cliente  quantia_comprada          retencao  \
# 0      32ea3bdedab835c3aa6cb68ce66565ef                 3 633 days 02:01:14
# 1      ccafc1c3f270410521c3c6f3b249870f                 2 608 days 23:29:38
# 2      d8f3c4f441a9b59a29f977df16724f38                 2 582 days 20:44:41
# 3      94e5ea5a8c1bf546db2739673060c43f                 2 580 days 16:38:23
# 4      87b3f231705783eb2217e25851c0a45d                 2 572 days 16:29:03
# ...                                 ...               ...               ...
# 95415  42c837a3d7df8cfa87de63fbc1aade2f                 1   1 days 00:00:00
# 95416  42c81f944761257c8df3b028e6b738cd                 1   1 days 00:00:00
# 95417  42c769ded134d534a9dedabd8f83c547                 1   1 days 00:00:00
# 95418  42f296ed9782627fc7408a950975cfd2                 1   1 days 00:00:00
# 95419  ffffd2657e2aad2907e67c3e9daecbeb                 1   1 days 00:00:00
#
#                        recencia  receita_media_por_quantia  \
# 0     1314 days 02:50:34.728348                     45.720
# 1     1334 days 19:33:26.775449                    103.755
# 2     1256 days 20:43:39.779190                     79.255
# 3     1364 days 00:47:19.758477                     93.585
# 4     1369 days 03:22:01.754597                    261.560
# ...                         ...                        ...
# 95415 1288 days 01:12:32.733131                     98.900
# 95416 1720 days 20:45:31.733130                     76.620
# 95417 1424 days 19:08:14.733129                     37.030
# 95418 1729 days 19:24:40.733183                     86.150
# 95419 1735 days 18:17:53.790824                     71.560
#
#        receita_media_por_dia
# 0                   0.216682
# 1                   0.341299
# 2                   0.272354
# 3                   0.322707
# 4                   0.914545
# ...                      ...
# 95415              98.900000
# 95416              76.620000
# 95417              37.030000
# 95418              86.150000
# 95419              71.560000
#
# [95420 rows x 6 columns]

# %%
plt.figure(figsize=(12, 6))
demo = Cliente[Cliente['receita_media_por_quantia'] < 1000]
sns.jointplot(y='receita_media_por_quantia', x=np.linspace(0,100,demo.shape[0]), data=demo, kind="hex", color="#4CB391")
plt.ylabel('Receita média por quantidade')
demo.sort_values('receita_media_por_quantia')
# Out:
# Text(25.125, 0.5, 'Receita média por quantidade')
#                                 cliente  quantia_comprada        retencao  \
# 89312  317cfc692e3f86c45c95697c61c853a6                 1 1 days 00:00:00
# 40982  bd06ce0e06ad77a7f681f1a4960a3cc6                 1 1 days 00:00:00
# 9310   b33336f46234b24a613ad9064d13106d                 1 1 days 00:00:00
# 57662  2878e5b88167faab17d4fb83a986d38b                 1 1 days 00:00:00
# 80715  6f5b9d1cdccc4d28f0483a612edecacf                 1 1 days 00:00:00
# ...                                 ...               ...             ...
# 73679  5897410e62336f05afe673aed70c88c1                 1 1 days 00:00:00
# 64764  6183466d2bb310b5b0698d30fff75685                 1 1 days 00:00:00
# 64625  74182c655b0270d9dde23ca43bb16a2e                 1 1 days 00:00:00
# 65010  4bcd3e861302b9a73210348ebb7621ad                 1 1 days 00:00:00
# 2025   0341bbd5c969923a0f801b9e2d10a7b8                 2 1 days 22:41:37
#
#                        recencia  receita_media_por_quantia  \
# 89312 1255 days 17:15:48.727928                       9.59
# 40982 1601 days 19:23:18.770762                      10.07
# 9310  1320 days 18:07:13.767772                      10.89
# 57662 1555 days 18:07:47.723294                      11.63
# 80715 1612 days 22:31:04.747294                      11.63
# ...                         ...                        ...
# 73679 1584 days 22:07:46.740168                     997.54
# 64764 1280 days 23:27:45.743148                     998.10
# 64625 1601 days 23:28:53.748704                     998.50
# 65010 1596 days 22:41:05.735869                     999.68
# 2025  1343 days 01:36:35.705004                     999.84
#
#        receita_media_por_dia
# 89312                   9.59
# 40982                  10.07
# 9310                   10.89
# 57662                  11.63
# 80715                  11.63
# ...                      ...
# 73679                 997.54
# 64764                 998.10
# 64625                 998.50
# 65010                 999.68
# 2025                 1999.68
#
# [94308 rows x 6 columns]

# %%
X = Cliente.drop(columns='cliente')
X['retencao'] = X.retencao.dt.days
X['recencia'] = X.recencia.dt.days

# %% [markdown]
# # Preprocessamento

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.cluster import KMeans, AgglomerativeClustering
from sklearn.decomposition import PCA
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split

# %% [markdown]
# #### Mudar etapa abaixo caso mude de receita_media_por_dia para receita_media_por_quantia

# %%
X.drop('receita_media_por_dia', axis=1, inplace=True)
X
# Out:
#        quantia_comprada  retencao  recencia  receita_media_por_quantia
# 0                     3       633      1314                     45.720
# 1                     2       608      1334                    103.755
# 2                     2       582      1256                     79.255
# 3                     2       580      1364                     93.585
# 4                     2       572      1369                    261.560
# ...                 ...       ...       ...                        ...
# 95415                 1         1      1288                     98.900
# 95416                 1         1      1720                     76.620
# 95417                 1         1      1424                     37.030
# 95418                 1         1      1729                     86.150
# 95419                 1         1      1735                     71.560
#
# [95420 rows x 4 columns]

# %% [markdown]
# MinMaxScaler dimensiona todos os recursos de dados no intervalo [0, 1] ou então no intervalo [-1, 1] se houver valores negativos no conjunto de dados. Na presença de outliers, o StandardScaler não garante escalas de recursos balanceadas, devido à influência dos outliers ao calcular a média empírica e o desvio padrão. Isso leva à redução na faixa dos valores do recurso.
#
# https://sigmoidal.ai/guia-basico-de-pre-processamento-de-dados/

# %%
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(X)
scaled_data = pd.DataFrame(scaled_data)
scaled_data.columns = X.columns
scaled_data.sort_values('receita_media_por_quantia', ascending=False)
# Out:
#        quantia_comprada  retencao  recencia  receita_media_por_quantia
# 64677               0.0       0.0  0.464286                   1.000000
# 64608               0.0       0.0  0.067308                   0.532081
# 29904               0.0       0.0  0.778846                   0.506772
# 90606               0.0       0.0  0.053571                   0.506253
# 33951               0.0       0.0  0.640110                   0.491931
# ...                 ...       ...       ...                        ...
# 80715               0.0       0.0  0.501374                   0.000149
# 57662               0.0       0.0  0.423077                   0.000149
# 9310                0.0       0.0  0.100275                   0.000095
# 40982               0.0       0.0  0.486264                   0.000035
# 89312               0.0       0.0  0.010989                   0.000000
#
# [95420 rows x 4 columns]

# %% [markdown]
# ### Explicação do Kmeans:
# k-means é um método de segregar em torno de centros (centroides) diversos dados, criando o que analogamente na química chamamos de clustering que gera o efeito de particionar n observações dentre k grupos onde cada observação pertence ao grupo mais próximo da média.
# https://pt.wikipedia.org/wiki/K-means

# %%
palette = ['#e41a1c', '#377eb8', '#4daf4a']

# %%
km = KMeans(n_clusters=3, random_state=0).fit(scaled_data)
np.unique(km.labels_, return_counts=True)
# Out:
# (array([0, 1, 2], dtype=int32), array([36269, 22619, 36532]))

# %%
clustered = pd.concat([Cliente['cliente'], scaled_data, pd.Series(km.predict(scaled_data))], axis=1, ignore_index=True)
cols = ['cliente', 'quantia_comprada', 'retencao', 'recencia', 'receita_media_por_quantia', 'grupo']
clustered.columns = cols

# %%
sns.pairplot(clustered, hue='grupo', diag_kind="hist", palette=palette)
plt.show()

# %%
clustered.sort_values(['retencao', 'receita_media_por_quantia'], ascending=False).head(10).style.background_gradient(subset=['receita_media_por_quantia', 'recencia', 'retencao'], cmap='Blues')
# Out:
# <style type="text/css">
# #T_601bd_row0_col2, #T_601bd_row4_col4, #T_601bd_row7_col3 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_601bd_row0_col3 {
#   background-color: #a5cde3;
#   color: #000000;
# }
# #T_601bd_row0_col4, #T_601bd_row2_col3, #T_601bd_row8_col3, #T_601bd_row9_col2 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_601bd_row1_col2 {
#   background-color: #1c6ab0;
#   color: #f1f1f1;
# }
# #T_601bd_row1_col3 {
#   background-color: #75b4d8;
#   color: #000000;
# }
# #T_601bd_row1_col4 {
#   background-color: #c1d9ed;
#   color: #000000;
# }
# #T_601bd_row2_col2 {
#   background-color: #5ca4d0;
#   color: #f1f1f1;
# }
# #T_601bd_row2_col4, #T_601bd_row6_col3 {
#   background-color: #d9e7f5;
#   color: #000000;
# }
# #T_601bd_row3_col2 {
#   background-color: #63a8d3;
#   color: #f1f1f1;
# }
# #T_601bd_row3_col3 {
#   background-color: #3989c1;
#   color: #f1f1f1;
# }
# #T_601bd_row3_col4 {
#   background-color: #ccdff1;
#   color: #000000;
# }
# #T_601bd_row4_col2 {
#   background-color: #7db8da;
#   color: #000000;
# }
# #T_601bd_row4_col3 {
#   background-color: #3181bd;
#   color: #f1f1f1;
# }
# #T_601bd_row5_col2 {
#   background-color: #dbe9f6;
#   color: #000000;
# }
# #T_601bd_row5_col3 {
#   background-color: #dae8f6;
#   color: #000000;
# }
# #T_601bd_row5_col4 {
#   background-color: #8fc2de;
#   color: #000000;
# }
# #T_601bd_row6_col2 {
#   background-color: #f0f6fd;
#   color: #000000;
# }
# #T_601bd_row6_col4 {
#   background-color: #deebf7;
#   color: #000000;
# }
# #T_601bd_row7_col2, #T_601bd_row8_col2 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_601bd_row7_col4 {
#   background-color: #cbdef1;
#   color: #000000;
# }
# #T_601bd_row8_col4 {
#   background-color: #dfebf7;
#   color: #000000;
# }
# #T_601bd_row9_col3 {
#   background-color: #d2e3f3;
#   color: #000000;
# }
# #T_601bd_row9_col4 {
#   background-color: #d0e1f2;
#   color: #000000;
# }
# </style>
# <table id="T_601bd_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >cliente</th>
#       <th class="col_heading level0 col1" >quantia_comprada</th>
#       <th class="col_heading level0 col2" >retencao</th>
#       <th class="col_heading level0 col3" >recencia</th>
#       <th class="col_heading level0 col4" >receita_media_por_quantia</th>
#       <th class="col_heading level0 col5" >grupo</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_601bd_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_601bd_row0_col0" class="data row0 col0" >32ea3bdedab835c3aa6cb68ce66565ef</td>
#       <td id="T_601bd_row0_col1" class="data row0 col1" >0.133333</td>
#       <td id="T_601bd_row0_col2" class="data row0 col2" >1.000000</td>
#       <td id="T_601bd_row0_col3" class="data row0 col3" >0.092033</td>
#       <td id="T_601bd_row0_col4" class="data row0 col4" >0.002646</td>
#       <td id="T_601bd_row0_col5" class="data row0 col5" >2</td>
#     </tr>
#     <tr>
#       <th id="T_601bd_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_601bd_row1_col0" class="data row1 col0" >ccafc1c3f270410521c3c6f3b249870f</td>
#       <td id="T_601bd_row1_col1" class="data row1 col1" >0.066667</td>
#       <td id="T_601bd_row1_col2" class="data row1 col2" >0.960443</td>
#       <td id="T_601bd_row1_col3" class="data row1 col3" >0.119505</td>
#       <td id="T_601bd_row1_col4" class="data row1 col4" >0.006896</td>
#       <td id="T_601bd_row1_col5" class="data row1 col5" >2</td>
#     </tr>
#     <tr>
#       <th id="T_601bd_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_601bd_row2_col0" class="data row2 col0" >d8f3c4f441a9b59a29f977df16724f38</td>
#       <td id="T_601bd_row2_col1" class="data row2 col1" >0.066667</td>
#       <td id="T_601bd_row2_col2" class="data row2 col2" >0.919304</td>
#       <td id="T_601bd_row2_col3" class="data row2 col3" >0.012363</td>
#       <td id="T_601bd_row2_col4" class="data row2 col4" >0.005102</td>
#       <td id="T_601bd_row2_col5" class="data row2 col5" >2</td>
#     </tr>
#     <tr>
#       <th id="T_601bd_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_601bd_row3_col0" class="data row3 col0" >94e5ea5a8c1bf546db2739673060c43f</td>
#       <td id="T_601bd_row3_col1" class="data row3 col1" >0.066667</td>
#       <td id="T_601bd_row3_col2" class="data row3 col2" >0.916139</td>
#       <td id="T_601bd_row3_col3" class="data row3 col3" >0.160714</td>
#       <td id="T_601bd_row3_col4" class="data row3 col4" >0.006151</td>
#       <td id="T_601bd_row3_col5" class="data row3 col5" >2</td>
#     </tr>
#     <tr>
#       <th id="T_601bd_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_601bd_row4_col0" class="data row4 col0" >87b3f231705783eb2217e25851c0a45d</td>
#       <td id="T_601bd_row4_col1" class="data row4 col1" >0.066667</td>
#       <td id="T_601bd_row4_col2" class="data row4 col2" >0.903481</td>
#       <td id="T_601bd_row4_col3" class="data row4 col3" >0.167582</td>
#       <td id="T_601bd_row4_col4" class="data row4 col4" >0.018453</td>
#       <td id="T_601bd_row4_col5" class="data row4 col5" >2</td>
#     </tr>
#     <tr>
#       <th id="T_601bd_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_601bd_row5_col0" class="data row5 col0" >8f6ce2295bdbec03cd50e34b4bd7ba0a</td>
#       <td id="T_601bd_row5_col1" class="data row5 col1" >0.133333</td>
#       <td id="T_601bd_row5_col2" class="data row5 col2" >0.848101</td>
#       <td id="T_601bd_row5_col3" class="data row5 col3" >0.045330</td>
#       <td id="T_601bd_row5_col4" class="data row5 col4" >0.009185</td>
#       <td id="T_601bd_row5_col5" class="data row5 col5" >2</td>
#     </tr>
#     <tr>
#       <th id="T_601bd_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_601bd_row6_col0" class="data row6 col0" >30b782a79466007756f170cb5bd6bbd8</td>
#       <td id="T_601bd_row6_col1" class="data row6 col1" >0.133333</td>
#       <td id="T_601bd_row6_col2" class="data row6 col2" >0.829114</td>
#       <td id="T_601bd_row6_col3" class="data row6 col3" >0.046703</td>
#       <td id="T_601bd_row6_col4" class="data row6 col4" >0.004638</td>
#       <td id="T_601bd_row6_col5" class="data row6 col5" >2</td>
#     </tr>
#     <tr>
#       <th id="T_601bd_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_601bd_row7_col0" class="data row7 col0" >4e23e1826902ec9f208e8cc61329b494</td>
#       <td id="T_601bd_row7_col1" class="data row7 col1" >0.066667</td>
#       <td id="T_601bd_row7_col2" class="data row7 col2" >0.827532</td>
#       <td id="T_601bd_row7_col3" class="data row7 col3" >0.237637</td>
#       <td id="T_601bd_row7_col4" class="data row7 col4" >0.006173</td>
#       <td id="T_601bd_row7_col5" class="data row7 col5" >2</td>
#     </tr>
#     <tr>
#       <th id="T_601bd_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_601bd_row8_col0" class="data row8 col0" >a1c61f8566347ec44ea37d22854634a1</td>
#       <td id="T_601bd_row8_col1" class="data row8 col1" >0.066667</td>
#       <td id="T_601bd_row8_col2" class="data row8 col2" >0.827532</td>
#       <td id="T_601bd_row8_col3" class="data row8 col3" >0.012363</td>
#       <td id="T_601bd_row8_col4" class="data row8 col4" >0.004588</td>
#       <td id="T_601bd_row8_col5" class="data row8 col5" >2</td>
#     </tr>
#     <tr>
#       <th id="T_601bd_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_601bd_row9_col0" class="data row9 col0" >a262442e3ab89611b44877c7aaf77468</td>
#       <td id="T_601bd_row9_col1" class="data row9 col1" >0.066667</td>
#       <td id="T_601bd_row9_col2" class="data row9 col2" >0.822785</td>
#       <td id="T_601bd_row9_col3" class="data row9 col3" >0.054945</td>
#       <td id="T_601bd_row9_col4" class="data row9 col4" >0.005809</td>
#       <td id="T_601bd_row9_col5" class="data row9 col5" >2</td>
#     </tr>
#   </tbody>
# </table>

# %%
clustered.sort_values(['receita_media_por_quantia'], ascending=False).head(10).style.background_gradient(subset=['receita_media_por_quantia', 'recencia', 'retencao'], cmap='Blues')
# Out:
# <style type="text/css">
# #T_2ccba_row0_col2, #T_2ccba_row1_col2, #T_2ccba_row2_col2, #T_2ccba_row3_col2, #T_2ccba_row4_col2, #T_2ccba_row5_col2, #T_2ccba_row6_col2, #T_2ccba_row7_col2, #T_2ccba_row8_col2, #T_2ccba_row9_col2, #T_2ccba_row9_col3, #T_2ccba_row9_col4 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_2ccba_row0_col3 {
#   background-color: #539ecd;
#   color: #f1f1f1;
# }
# #T_2ccba_row0_col4, #T_2ccba_row2_col3 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_2ccba_row1_col3 {
#   background-color: #f0f6fd;
#   color: #000000;
# }
# #T_2ccba_row1_col4 {
#   background-color: #b5d4e9;
#   color: #000000;
# }
# #T_2ccba_row2_col4, #T_2ccba_row3_col4 {
#   background-color: #c2d9ee;
#   color: #000000;
# }
# #T_2ccba_row3_col3, #T_2ccba_row8_col4 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_2ccba_row4_col3 {
#   background-color: #1561a9;
#   color: #f1f1f1;
# }
# #T_2ccba_row4_col4 {
#   background-color: #c8dcf0;
#   color: #000000;
# }
# #T_2ccba_row5_col3 {
#   background-color: #77b5d9;
#   color: #000000;
# }
# #T_2ccba_row5_col4 {
#   background-color: #d6e5f4;
#   color: #000000;
# }
# #T_2ccba_row6_col3 {
#   background-color: #eff6fc;
#   color: #000000;
# }
# #T_2ccba_row6_col4 {
#   background-color: #f1f7fd;
#   color: #000000;
# }
# #T_2ccba_row7_col3 {
#   background-color: #084f99;
#   color: #f1f1f1;
# }
# #T_2ccba_row7_col4 {
#   background-color: #f2f7fd;
#   color: #000000;
# }
# #T_2ccba_row8_col3 {
#   background-color: #e7f1fa;
#   color: #000000;
# }
# </style>
# <table id="T_2ccba_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >cliente</th>
#       <th class="col_heading level0 col1" >quantia_comprada</th>
#       <th class="col_heading level0 col2" >retencao</th>
#       <th class="col_heading level0 col3" >recencia</th>
#       <th class="col_heading level0 col4" >receita_media_por_quantia</th>
#       <th class="col_heading level0 col5" >grupo</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2ccba_level0_row0" class="row_heading level0 row0" >64677</th>
#       <td id="T_2ccba_row0_col0" class="data row0 col0" >0a0a92112bd4c708ca5fde585afaa872</td>
#       <td id="T_2ccba_row0_col1" class="data row0 col1" >0.000000</td>
#       <td id="T_2ccba_row0_col2" class="data row0 col2" >0.000000</td>
#       <td id="T_2ccba_row0_col3" class="data row0 col3" >0.464286</td>
#       <td id="T_2ccba_row0_col4" class="data row0 col4" >1.000000</td>
#       <td id="T_2ccba_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_2ccba_level0_row1" class="row_heading level0 row1" >64608</th>
#       <td id="T_2ccba_row1_col0" class="data row1 col0" >763c8b1c9c68a0229c42c9fc6f662b93</td>
#       <td id="T_2ccba_row1_col1" class="data row1 col1" >0.000000</td>
#       <td id="T_2ccba_row1_col2" class="data row1 col2" >0.000000</td>
#       <td id="T_2ccba_row1_col3" class="data row1 col3" >0.067308</td>
#       <td id="T_2ccba_row1_col4" class="data row1 col4" >0.532081</td>
#       <td id="T_2ccba_row1_col5" class="data row1 col5" >2</td>
#     </tr>
#     <tr>
#       <th id="T_2ccba_level0_row2" class="row_heading level0 row2" >29904</th>
#       <td id="T_2ccba_row2_col0" class="data row2 col0" >dc4802a71eae9be1dd28f5d788ceb526</td>
#       <td id="T_2ccba_row2_col1" class="data row2 col1" >0.000000</td>
#       <td id="T_2ccba_row2_col2" class="data row2 col2" >0.000000</td>
#       <td id="T_2ccba_row2_col3" class="data row2 col3" >0.778846</td>
#       <td id="T_2ccba_row2_col4" class="data row2 col4" >0.506772</td>
#       <td id="T_2ccba_row2_col5" class="data row2 col5" >1</td>
#     </tr>
#     <tr>
#       <th id="T_2ccba_level0_row3" class="row_heading level0 row3" >90606</th>
#       <td id="T_2ccba_row3_col0" class="data row3 col0" >459bef486812aa25204be022145caa62</td>
#       <td id="T_2ccba_row3_col1" class="data row3 col1" >0.000000</td>
#       <td id="T_2ccba_row3_col2" class="data row3 col2" >0.000000</td>
#       <td id="T_2ccba_row3_col3" class="data row3 col3" >0.053571</td>
#       <td id="T_2ccba_row3_col4" class="data row3 col4" >0.506253</td>
#       <td id="T_2ccba_row3_col5" class="data row3 col5" >2</td>
#     </tr>
#     <tr>
#       <th id="T_2ccba_level0_row4" class="row_heading level0 row4" >33951</th>
#       <td id="T_2ccba_row4_col0" class="data row4 col0" >ff4159b92c40ebe40454e3e6a7c35ed6</td>
#       <td id="T_2ccba_row4_col1" class="data row4 col1" >0.000000</td>
#       <td id="T_2ccba_row4_col2" class="data row4 col2" >0.000000</td>
#       <td id="T_2ccba_row4_col3" class="data row4 col3" >0.640110</td>
#       <td id="T_2ccba_row4_col4" class="data row4 col4" >0.491931</td>
#       <td id="T_2ccba_row4_col5" class="data row4 col5" >1</td>
#     </tr>
#     <tr>
#       <th id="T_2ccba_level0_row5" class="row_heading level0 row5" >64188</th>
#       <td id="T_2ccba_row5_col0" class="data row5 col0" >4007669dec559734d6f53e029e360987</td>
#       <td id="T_2ccba_row5_col1" class="data row5 col1" >0.000000</td>
#       <td id="T_2ccba_row5_col2" class="data row5 col2" >0.000000</td>
#       <td id="T_2ccba_row5_col3" class="data row5 col3" >0.388736</td>
#       <td id="T_2ccba_row5_col4" class="data row5 col4" >0.444685</td>
#       <td id="T_2ccba_row5_col5" class="data row5 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_2ccba_level0_row6" class="row_heading level0 row6" >63174</th>
#       <td id="T_2ccba_row6_col0" class="data row6 col0" >5d0a2980b292d049061542014e8960bf</td>
#       <td id="T_2ccba_row6_col1" class="data row6 col1" >0.000000</td>
#       <td id="T_2ccba_row6_col2" class="data row6 col2" >0.000000</td>
#       <td id="T_2ccba_row6_col3" class="data row6 col3" >0.072802</td>
#       <td id="T_2ccba_row6_col4" class="data row6 col4" >0.351522</td>
#       <td id="T_2ccba_row6_col5" class="data row6 col5" >2</td>
#     </tr>
#     <tr>
#       <th id="T_2ccba_level0_row7" class="row_heading level0 row7" >35498</th>
#       <td id="T_2ccba_row7_col0" class="data row7 col0" >eebb5dda148d3893cdaf5b5ca3040ccb</td>
#       <td id="T_2ccba_row7_col1" class="data row7 col1" >0.000000</td>
#       <td id="T_2ccba_row7_col2" class="data row7 col2" >0.000000</td>
#       <td id="T_2ccba_row7_col3" class="data row7 col3" >0.689560</td>
#       <td id="T_2ccba_row7_col4" class="data row7 col4" >0.348219</td>
#       <td id="T_2ccba_row7_col5" class="data row7 col5" >1</td>
#     </tr>
#     <tr>
#       <th id="T_2ccba_level0_row8" class="row_heading level0 row8" >89762</th>
#       <td id="T_2ccba_row8_col0" class="data row8 col0" >48e1ac109decbb87765a3eade6854098</td>
#       <td id="T_2ccba_row8_col1" class="data row8 col1" >0.000000</td>
#       <td id="T_2ccba_row8_col2" class="data row8 col2" >0.000000</td>
#       <td id="T_2ccba_row8_col3" class="data row8 col3" >0.100275</td>
#       <td id="T_2ccba_row8_col4" class="data row8 col4" >0.342172</td>
#       <td id="T_2ccba_row8_col5" class="data row8 col5" >2</td>
#     </tr>
#     <tr>
#       <th id="T_2ccba_level0_row9" class="row_heading level0 row9" >27991</th>
#       <td id="T_2ccba_row9_col0" class="data row9 col0" >edde2314c6c30e864a128ac95d6b2112</td>
#       <td id="T_2ccba_row9_col1" class="data row9 col1" >0.000000</td>
#       <td id="T_2ccba_row9_col2" class="data row9 col2" >0.000000</td>
#       <td id="T_2ccba_row9_col3" class="data row9 col3" >0.041209</td>
#       <td id="T_2ccba_row9_col4" class="data row9 col4" >0.329835</td>
#       <td id="T_2ccba_row9_col5" class="data row9 col5" >2</td>
#     </tr>
#   </tbody>
# </table>

# %%
sns.pairplot(clustered, hue='grupo', diag_kind="hist", palette=palette)
plt.show()

# %% [markdown]
# ### MinMax + PCA com 2 + Kmeans

# %% [markdown]
# EXPLICAÇÃO DO PCA AQUI!!!

# %%
pca2 = PCA(n_components=2, random_state=0)
pca2 = pca2.fit_transform(scaled_data)

p2 = pd.DataFrame(pca2)

km2 = KMeans(n_clusters=3, random_state=0).fit(p2)
np.unique(km2.labels_, return_counts=True)
# Out:
# (array([0, 1, 2], dtype=int32), array([22291, 37042, 36087]))

# %%
print(np.unique(km.labels_, return_counts=True),
np.unique(km2.labels_, return_counts=True), sep='\n')
# Out:
# (array([0, 1, 2], dtype=int32), array([36649, 22577, 36194]))
# (array([0, 1, 2], dtype=int32), array([22291, 37042, 36087]))

# %%
clustered2 = pd.concat([Cliente['cliente'], p2, pd.Series(km2.predict(p2))], axis=1, ignore_index=True)
cols = ['cliente', 'var_1', 'var_2', 'grupo']
clustered2.columns = cols

# %%
Cliente
# Out:
#                                 cliente  quantia_comprada          retencao  \
# 0      32ea3bdedab835c3aa6cb68ce66565ef                 3 633 days 02:01:14
# 1      ccafc1c3f270410521c3c6f3b249870f                 2 608 days 23:29:38
# 2      d8f3c4f441a9b59a29f977df16724f38                 2 582 days 20:44:41
# 3      94e5ea5a8c1bf546db2739673060c43f                 2 580 days 16:38:23
# 4      87b3f231705783eb2217e25851c0a45d                 2 572 days 16:29:03
# ...                                 ...               ...               ...
# 95415  42c837a3d7df8cfa87de63fbc1aade2f                 1   1 days 00:00:00
# 95416  42c81f944761257c8df3b028e6b738cd                 1   1 days 00:00:00
# 95417  42c769ded134d534a9dedabd8f83c547                 1   1 days 00:00:00
# 95418  42f296ed9782627fc7408a950975cfd2                 1   1 days 00:00:00
# 95419  ffffd2657e2aad2907e67c3e9daecbeb                 1   1 days 00:00:00
#
#                        recencia  receita_media_por_quantia  \
# 0     1313 days 10:35:51.633869                     45.720
# 1     1334 days 03:18:43.702411                    103.755
# 2     1256 days 04:28:56.706886                     79.255
# 3     1363 days 08:32:36.681478                     93.585
# 4     1368 days 11:07:18.674994                    261.560
# ...                         ...                        ...
# 95415 1287 days 08:57:49.641804                     98.900
# 95416 1720 days 04:30:48.641804                     76.620
# 95417 1424 days 02:53:31.641801                     37.030
# 95418 1729 days 03:09:57.641872                     86.150
# 95419 1735 days 02:03:10.722377                     71.560
#
#        receita_media_por_dia
# 0                   0.216682
# 1                   0.341299
# 2                   0.272354
# 3                   0.322707
# 4                   0.914545
# ...                      ...
# 95415              98.900000
# 95416              76.620000
# 95417              37.030000
# 95418              86.150000
# 95419              71.560000
#
# [95420 rows x 6 columns]

# %%
sns.scatterplot(x='var_1', y='var_2', hue='grupo', data=clustered2, palette=palette)
plt.show()
# Out:
# <AxesSubplot:xlabel='var_1', ylabel='var_2'>

# %%
Cliente[['cliente', 'receita_media_por_dia']].sort_values(by='receita_media_por_dia', ascending=False)
# Out:
#                                 cliente  receita_media_por_dia
# 64677  0a0a92112bd4c708ca5fde585afaa872           13664.080000
# 2327   da122df9eeddfedc1dc1f5349a1a690c            7571.630000
# 64608  763c8b1c9c68a0229c42c9fc6f662b93            7274.880000
# 29904  dc4802a71eae9be1dd28f5d788ceb526            6929.310000
# 90606  459bef486812aa25204be022145caa62            6922.210000
# ...                                 ...                    ...
# 0      32ea3bdedab835c3aa6cb68ce66565ef               0.216682
# 105    efd22f5f8fc7e5035a4f48bd92c0c69c               0.192869
# 76     c04a6c1c190e47ec62b4bb139921331a               0.173216
# 45     a4030b5e97ffc14114e66d82df860f6f               0.152877
# 32     fb920961e4d8e55fd9c357976a611765               0.146264
#
# [95420 rows x 2 columns]

# %%
clustered2.sort_values(['var_2', 'var_1'], ascending=False).head(10).style.background_gradient(subset=['var_2', 'var_1'], cmap='Blues')
# Out:
# <style type="text/css">
# #T_2b72e_row0_col1 {
#   background-color: #a9cfe5;
#   color: #000000;
# }
# #T_2b72e_row0_col2, #T_2b72e_row8_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_2b72e_row1_col1 {
#   background-color: #75b4d8;
#   color: #000000;
# }
# #T_2b72e_row1_col2 {
#   background-color: #2c7cba;
#   color: #f1f1f1;
# }
# #T_2b72e_row2_col1 {
#   background-color: #f2f7fd;
#   color: #000000;
# }
# #T_2b72e_row2_col2 {
#   background-color: #4493c7;
#   color: #f1f1f1;
# }
# #T_2b72e_row3_col1, #T_2b72e_row9_col1, #T_2b72e_row9_col2 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_2b72e_row3_col2 {
#   background-color: #71b1d7;
#   color: #f1f1f1;
# }
# #T_2b72e_row4_col1 {
#   background-color: #3a8ac2;
#   color: #f1f1f1;
# }
# #T_2b72e_row4_col2 {
#   background-color: #74b3d8;
#   color: #000000;
# }
# #T_2b72e_row5_col1 {
#   background-color: #3282be;
#   color: #f1f1f1;
# }
# #T_2b72e_row5_col2 {
#   background-color: #8fc2de;
#   color: #000000;
# }
# #T_2b72e_row6_col1 {
#   background-color: #d9e8f5;
#   color: #000000;
# }
# #T_2b72e_row6_col2 {
#   background-color: #d1e2f3;
#   color: #000000;
# }
# #T_2b72e_row7_col1 {
#   background-color: #d8e7f5;
#   color: #000000;
# }
# #T_2b72e_row7_col2 {
#   background-color: #e5eff9;
#   color: #000000;
# }
# #T_2b72e_row8_col2 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# </style>
# <table id="T_2b72e_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >cliente</th>
#       <th class="col_heading level0 col1" >var_1</th>
#       <th class="col_heading level0 col2" >var_2</th>
#       <th class="col_heading level0 col3" >grupo</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2b72e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2b72e_row0_col0" class="data row0 col0" >32ea3bdedab835c3aa6cb68ce66565ef</td>
#       <td id="T_2b72e_row0_col1" class="data row0 col1" >-0.254476</td>
#       <td id="T_2b72e_row0_col2" class="data row0 col2" >0.996646</td>
#       <td id="T_2b72e_row0_col3" class="data row0 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_2b72e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_2b72e_row1_col0" class="data row1 col0" >ccafc1c3f270410521c3c6f3b249870f</td>
#       <td id="T_2b72e_row1_col1" class="data row1 col1" >-0.225077</td>
#       <td id="T_2b72e_row1_col2" class="data row1 col2" >0.943408</td>
#       <td id="T_2b72e_row1_col3" class="data row1 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_2b72e_level0_row2" class="row_heading level0 row2" >28</th>
#       <td id="T_2b72e_row2_col0" class="data row2 col0" >8d50f5eadf50201ccdcedfb9e2ac8455</td>
#       <td id="T_2b72e_row2_col1" class="data row2 col1" >-0.325204</td>
#       <td id="T_2b72e_row2_col2" class="data row2 col2" >0.926230</td>
#       <td id="T_2b72e_row2_col3" class="data row2 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_2b72e_level0_row3" class="row_heading level0 row3" >2</th>
#       <td id="T_2b72e_row3_col0" class="data row3 col0" >d8f3c4f441a9b59a29f977df16724f38</td>
#       <td id="T_2b72e_row3_col1" class="data row3 col1" >-0.331557</td>
#       <td id="T_2b72e_row3_col2" class="data row3 col2" >0.902017</td>
#       <td id="T_2b72e_row3_col3" class="data row3 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_2b72e_level0_row4" class="row_heading level0 row4" >3</th>
#       <td id="T_2b72e_row4_col0" class="data row4 col0" >94e5ea5a8c1bf546db2739673060c43f</td>
#       <td id="T_2b72e_row4_col1" class="data row4 col1" >-0.184753</td>
#       <td id="T_2b72e_row4_col2" class="data row4 col2" >0.900746</td>
#       <td id="T_2b72e_row4_col3" class="data row4 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_2b72e_level0_row5" class="row_heading level0 row5" >4</th>
#       <td id="T_2b72e_row5_col0" class="data row5 col0" >87b3f231705783eb2217e25851c0a45d</td>
#       <td id="T_2b72e_row5_col1" class="data row5 col1" >-0.177738</td>
#       <td id="T_2b72e_row5_col2" class="data row5 col2" >0.888454</td>
#       <td id="T_2b72e_row5_col3" class="data row5 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_2b72e_level0_row6" class="row_heading level0 row6" >5</th>
#       <td id="T_2b72e_row6_col0" class="data row6 col0" >8f6ce2295bdbec03cd50e34b4bd7ba0a</td>
#       <td id="T_2b72e_row6_col1" class="data row6 col1" >-0.297867</td>
#       <td id="T_2b72e_row6_col2" class="data row6 col2" >0.848095</td>
#       <td id="T_2b72e_row6_col3" class="data row6 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_2b72e_level0_row7" class="row_heading level0 row7" >6</th>
#       <td id="T_2b72e_row7_col0" class="data row7 col0" >30b782a79466007756f170cb5bd6bbd8</td>
#       <td id="T_2b72e_row7_col1" class="data row7 col1" >-0.296261</td>
#       <td id="T_2b72e_row7_col2" class="data row7 col2" >0.829633</td>
#       <td id="T_2b72e_row7_col3" class="data row7 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_2b72e_level0_row8" class="row_heading level0 row8" >7</th>
#       <td id="T_2b72e_row8_col0" class="data row8 col0" >4e23e1826902ec9f208e8cc61329b494</td>
#       <td id="T_2b72e_row8_col1" class="data row8 col1" >-0.106849</td>
#       <td id="T_2b72e_row8_col2" class="data row8 col2" >0.815382</td>
#       <td id="T_2b72e_row8_col3" class="data row8 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_2b72e_level0_row9" class="row_heading level0 row9" >8</th>
#       <td id="T_2b72e_row9_col0" class="data row9 col0" >a1c61f8566347ec44ea37d22854634a1</td>
#       <td id="T_2b72e_row9_col1" class="data row9 col1" >-0.331797</td>
#       <td id="T_2b72e_row9_col2" class="data row9 col2" >0.812605</td>
#       <td id="T_2b72e_row9_col3" class="data row9 col3" >1</td>
#     </tr>
#   </tbody>
# </table>

# %%
clustered2.sort_values(['var_1'], ascending=False).head(10).style.background_gradient(subset=['var_1', 'var_2'], cmap='Blues')
# Out:
# <style type="text/css">
# #T_13d60_row0_col1, #T_13d60_row0_col2, #T_13d60_row1_col2 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_13d60_row1_col1 {
#   background-color: #083877;
#   color: #f1f1f1;
# }
# #T_13d60_row2_col1 {
#   background-color: #3f8fc5;
#   color: #f1f1f1;
# }
# #T_13d60_row2_col2 {
#   background-color: #2171b5;
#   color: #f1f1f1;
# }
# #T_13d60_row3_col1 {
#   background-color: #eaf2fb;
#   color: #000000;
# }
# #T_13d60_row3_col2 {
#   background-color: #9fcae1;
#   color: #000000;
# }
# #T_13d60_row4_col1, #T_13d60_row5_col1, #T_13d60_row6_col1, #T_13d60_row7_col1 {
#   background-color: #f1f7fd;
#   color: #000000;
# }
# #T_13d60_row4_col2 {
#   background-color: #a9cfe5;
#   color: #000000;
# }
# #T_13d60_row5_col2 {
#   background-color: #a0cbe2;
#   color: #000000;
# }
# #T_13d60_row6_col2, #T_13d60_row7_col2 {
#   background-color: #9dcae1;
#   color: #000000;
# }
# #T_13d60_row8_col1, #T_13d60_row8_col2, #T_13d60_row9_col1, #T_13d60_row9_col2 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_13d60_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >cliente</th>
#       <th class="col_heading level0 col1" >var_1</th>
#       <th class="col_heading level0 col2" >var_2</th>
#       <th class="col_heading level0 col3" >grupo</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_13d60_level0_row0" class="row_heading level0 row0" >69965</th>
#       <td id="T_13d60_row0_col0" class="data row0 col0" >b7d76e111c89f7ebf14761390f0f7d17</td>
#       <td id="T_13d60_row0_col1" class="data row0 col1" >0.666090</td>
#       <td id="T_13d60_row0_col2" class="data row0 col2" >0.003650</td>
#       <td id="T_13d60_row0_col3" class="data row0 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_13d60_level0_row1" class="row_heading level0 row1" >89949</th>
#       <td id="T_13d60_row1_col0" class="data row1 col0" >4854e9b3feff728c13ee5fc7d1547e92</td>
#       <td id="T_13d60_row1_col1" class="data row1 col1" >0.664718</td>
#       <td id="T_13d60_row1_col2" class="data row1 col2" >0.003650</td>
#       <td id="T_13d60_row1_col3" class="data row1 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_13d60_level0_row2" class="row_heading level0 row2" >66030</th>
#       <td id="T_13d60_row2_col0" class="data row2 col0" >830d5b7aaa3b6f1e9ad63703bec97d23</td>
#       <td id="T_13d60_row2_col1" class="data row2 col1" >0.651002</td>
#       <td id="T_13d60_row2_col2" class="data row2 col2" >0.003462</td>
#       <td id="T_13d60_row2_col3" class="data row2 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_13d60_level0_row3" class="row_heading level0 row3" >53730</th>
#       <td id="T_13d60_row3_col0" class="data row3 col0" >0eb1ee9dba87f5b36b4613a65074337c</td>
#       <td id="T_13d60_row3_col1" class="data row3 col1" >0.627684</td>
#       <td id="T_13d60_row3_col2" class="data row3 col2" >0.003183</td>
#       <td id="T_13d60_row3_col3" class="data row3 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_13d60_level0_row4" class="row_heading level0 row4" >21330</th>
#       <td id="T_13d60_row4_col0" class="data row4 col0" >8d3a54507421dbd2ce0a1d58046826e0</td>
#       <td id="T_13d60_row4_col1" class="data row4 col1" >0.626312</td>
#       <td id="T_13d60_row4_col2" class="data row4 col2" >0.003159</td>
#       <td id="T_13d60_row4_col3" class="data row4 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_13d60_level0_row5" class="row_heading level0 row5" >82219</th>
#       <td id="T_13d60_row5_col0" class="data row5 col0" >61db744d2f835035a5625b59350c6b63</td>
#       <td id="T_13d60_row5_col1" class="data row5 col1" >0.626312</td>
#       <td id="T_13d60_row5_col2" class="data row5 col2" >0.003181</td>
#       <td id="T_13d60_row5_col3" class="data row5 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_13d60_level0_row6" class="row_heading level0 row6" >87263</th>
#       <td id="T_13d60_row6_col0" class="data row6 col0" >2f64e403852e6893ae37485d5fcacdaf</td>
#       <td id="T_13d60_row6_col1" class="data row6 col1" >0.626312</td>
#       <td id="T_13d60_row6_col2" class="data row6 col2" >0.003185</td>
#       <td id="T_13d60_row6_col3" class="data row6 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_13d60_level0_row7" class="row_heading level0 row7" >41480</th>
#       <td id="T_13d60_row7_col0" class="data row7 col0" >b8b8726af116a5cfb35b0315ecef9172</td>
#       <td id="T_13d60_row7_col1" class="data row7 col1" >0.626312</td>
#       <td id="T_13d60_row7_col2" class="data row7 col2" >0.003186</td>
#       <td id="T_13d60_row7_col3" class="data row7 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_13d60_level0_row8" class="row_heading level0 row8" >93201</th>
#       <td id="T_13d60_row8_col0" class="data row8 col0" >40b41ade17bb2121b576b07e25ce622b</td>
#       <td id="T_13d60_row8_col1" class="data row8 col1" >0.624943</td>
#       <td id="T_13d60_row8_col2" class="data row8 col2" >0.002906</td>
#       <td id="T_13d60_row8_col3" class="data row8 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_13d60_level0_row9" class="row_heading level0 row9" >48448</th>
#       <td id="T_13d60_row9_col0" class="data row9 col0" >cfbb7c1c3d613d974eef515b180e2c9b</td>
#       <td id="T_13d60_row9_col1" class="data row9 col1" >0.624943</td>
#       <td id="T_13d60_row9_col2" class="data row9 col2" >0.002906</td>
#       <td id="T_13d60_row9_col3" class="data row9 col3" >0</td>
#     </tr>
#   </tbody>
# </table>

# %%
clustered2[clustered2.cliente == '0a0a92112bd4c708ca5fde585afaa872']
# Out:
#                                 cliente     var_1     var_2  grupo
# 64677  0a0a92112bd4c708ca5fde585afaa872  0.131188 -0.006731      2

# %%
clustered2.drop(columns='grupo').corr().style.background_gradient()
# Out:
# <style type="text/css">
# #T_aa01d_row0_col0, #T_aa01d_row1_col1 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_aa01d_row0_col1, #T_aa01d_row1_col0 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# </style>
# <table id="T_aa01d_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >var_1</th>
#       <th class="col_heading level0 col1" >var_2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_aa01d_level0_row0" class="row_heading level0 row0" >var_1</th>
#       <td id="T_aa01d_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_aa01d_row0_col1" class="data row0 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_aa01d_level0_row1" class="row_heading level0 row1" >var_2</th>
#       <td id="T_aa01d_row1_col0" class="data row1 col0" >0.000000</td>
#       <td id="T_aa01d_row1_col1" class="data row1 col1" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Dedução do comportamento dos dados:
# -> variáveis que caminham em direção oposta como: recencia e receita; gerando assim uma aparência de tradeoff nas variáveis

# %% [markdown]
# ### PCA com 3

# %%
pca3 = PCA(n_components=3, random_state=0)
pca3 = pca3.fit_transform(scaled_data)

p3 = pd.DataFrame(pca3)

km3 = KMeans(n_clusters=3, random_state=0).fit(p3)
np.unique(km3.labels_, return_counts=True)
# Out:
# (array([0, 1, 2], dtype=int32), array([36648, 22577, 36195]))

# %%
clustered3 = pd.concat([Cliente['cliente'], p3, pd.Series(km3.predict(p3))], axis=1, ignore_index=True)
cols = ['cliente', 'var_1', 'var_2', 'var_3', 'grupo']
clustered3.columns = cols

# %%
sns.pairplot(clustered3, hue='grupo', palette=palette); plt.show()

# %% [markdown]
# #### ELBOW 1 (scaled_data), ELBOW 2 (pca com 2), ELBOW3 (pca com 3)
# colocar os elbows juntos lado a lado para comparar o que melhor agrupa tudo com o kmeans de 3

# %% [markdown]
# In cluster analysis, the elbow method is a heuristic used in determining the number of clusters in a data set. The method consists of plotting the explained variation as a function of the number of clusters, and picking the elbow of the curve as the number of clusters to use.
# https://en.wikipedia.org/wiki/Elbow_method_(clustering)

# %% [markdown]
# Diferenças Marginalmente irrelevantes perante as conclusões do método Elbow

# %%
i = tuple(range(2,14))
k_elbow1 = [KMeans(n_clusters=clust, random_state=0).fit(scaled_data).inertia_ for clust in i]
k_elbow2 = [KMeans(n_clusters=clust, random_state=0).fit(p2).inertia_ for clust in i]
k_elbow3 = [KMeans(n_clusters=clust, random_state=0).fit(p3).inertia_ for clust in i]

# %% [markdown]
# #### Ausência de diferença entre resultados a partir da metrica de Elbow

# %%
plt.plot(i, k_elbow3, 'o-r')
plt.plot(i, k_elbow2, 'o-g')
plt.plot(i, k_elbow1, 'o-b')
plt.axvline(3, 0, 800, color='r',)
plt.xlabel('Número de clusters')
plt.ylabel('Variância explicada')
plt.savefig('clusters.png')
plt.show()
# Out:
# Text(0.5, 0, 'Número de clusters')
# Text(0, 0.5, 'Variância explicada')

# %% [markdown]
# # Usando modelo AGGLOMERATIVE CLUSTERING

# %% [markdown]
# **Metric** used to compute the linkage. Can be "euclidean", "l1", "l2",
# "manhattan", "cosine", or "precomputed".
# If linkage is "ward", only "euclidean" is accepted.
# If "precomputed", a distance matrix (instead of a similarity matrix)
# is needed as input for the fit method.
#
# ----
#
# **Linkage** : {'ward', 'complete', 'average', 'single'}, default='ward'
#     Which linkage criterion to use. The linkage criterion determines which
# distance to use between sets of observation. The algorithm will merge
# the pairs of cluster that minimize this criterion.
#
# 'ward' minimizes the variance of the clusters being merged.
#
# 'average' uses the average of the distances of each observation of
# the two sets.
#
# 'complete' or 'maximum' linkage uses the maximum distances between
# all observations of the two sets.
#
# 'single' uses the minimum of the distances between all observations
# of the two sets.

# %%
np.random.seed(0)
sample = scaled_data.sample(20000)

# %% [markdown]
# ADICIONAR TESTE ESTATÍSTICO

# %%
def model_agg(X, lk, metric='euclidean'):
    global sample
    model = AgglomerativeClustering(n_clusters=3, linkage=lk, affinity=metric)
    result = model.fit_predict(sample)
    return result, model

# %%
# %%time
data, model = model_agg(scaled_data, 'ward')
final = pd.concat([sample.reset_index(drop=True), pd.Series(data)], axis=1, ignore_index=True)
final.columns = list(X.columns) + ['grupo']
# Out:
# CPU times: user 13.3 s, sys: 3.6 s, total: 16.9 s
# Wall time: 17 s

# %%
sns.pairplot(final, hue='grupo', diag_kind='hist', palette=palette)
plt.show()

# %%
final['grupo'].value_counts(normalize=True)
# Out:
# 0    0.55925
# 1    0.30615
# 2    0.13460
# Name: grupo, dtype: float64

# %%
# %%time
data, model = model_agg(scaled_data, 'complete', metric='euclidean')
final2 = pd.concat([sample.reset_index(drop=True), pd.Series(data)], axis=1, ignore_index=True)
final2.columns = list(X.columns) + ['grupo']
# Out:
# CPU times: user 14.5 s, sys: 2.78 s, total: 17.3 s
# Wall time: 17.3 s

# %%
sns.pairplot(final2, hue='grupo', diag_kind='hist', palette=palette)
plt.show()

# %%
Cliente.columns
# Out:
# Index(['cliente', 'quantia_comprada', 'retencao', 'recencia',
#        'receita_media_por_quantia', 'receita_media_por_dia'],
#       dtype='object')

# %%
final2['grupo'].value_counts(normalize=True)
# Out:
# 0    0.7803
# 2    0.2138
# 1    0.0059
# Name: grupo, dtype: float64

# %%
# %%time

data, model = model_agg(scaled_data, 'complete', metric='cosine')
final3 = pd.concat([sample.reset_index(drop=True), pd.Series(data)], axis=1, ignore_index=True)
final3.columns = list(X.columns) + ['grupo']
# Out:
# CPU times: user 11.4 s, sys: 2.86 s, total: 14.2 s
# Wall time: 14.3 s

# %%
sns.pairplot(final3, hue='grupo', diag_kind='hist', palette=palette)
plt.show()

# %%
final3['grupo'].value_counts(normalize=True)
# Out:
# 0    0.9804
# 2    0.0113
# 1    0.0083
# Name: grupo, dtype: float64

# %%
# %%time
result, model = model_agg(scaled_data, 'single')
final4 = pd.concat([sample.reset_index(drop=True), pd.Series(data)], axis=1, ignore_index=True)
final4.columns = list(X.columns) + ['grupo']
# Out:
# CPU times: user 3.71 s, sys: 15.6 ms, total: 3.73 s
# Wall time: 3.72 s

# %%
sns.pairplot(final4, hue='grupo', diag_kind='hist', palette=palette)
plt.show()

# %%
final4['grupo'].value_counts(normalize=True)
# Out:
# 0    0.9804
# 2    0.0113
# 1    0.0083
# Name: grupo, dtype: float64

# %% [markdown]
# #### Descrever motivos de escolher o Agglomerative Clustering de metric="ward"

# %% [markdown]
# ## Complementando modelo com random forest:

# %% [markdown]
# #### DESCREVER PRIMEIRA ALTERNATIVA:

# %%
step = pd.concat([pd.Series(sample.index), final.grupo], ignore_index=True, axis=1).set_index(0)
rfr = RandomForestClassifier(n_jobs=-1, random_state=0, max_depth=3)

xtrain, xtest, ytrain, ytest = train_test_split(final.drop(columns='grupo'), final['grupo'], test_size=0.35, random_state=0, stratify=final['grupo'])
rfr.fit(xtrain, ytrain)
# Out:
# RandomForestClassifier(max_depth=3, n_jobs=-1, random_state=0)

# %%
prob_and_class = pd.concat([pd.DataFrame(rfr.predict_proba(scaled_data)), pd.Series(rfr.predict(scaled_data))], axis=1, ignore_index=True)

# %%
class_new_threshold = np.vectorize(lambda x, y, z: 0 if x > .94 and (x > z) and (x > y) else (1 if y > z else 2))

result_new_threshold = class_new_threshold(prob_and_class.iloc[:, 0], prob_and_class.iloc[:, 1], prob_and_class.iloc[:, 2])
df_new_threshold = pd.concat([scaled_data, pd.Series(result_new_threshold)], axis=1).rename({0:'grupo'}, axis=1)

# %%
df_new_threshold.grupo.value_counts(normalize=True)
# Out:
# 0    0.526965
# 1    0.339468
# 2    0.133567
# Name: grupo, dtype: float64

# %%
sns.pairplot(df_new_threshold, hue='grupo', diag_kind='hist', palette=palette)

# %%
sns.PairGrid(df_new_threshold, hue='grupo').map(plt.scatter)

# %%
sns.scatterplot(data=df_new_threshold[['recencia', 'receita_media_por_quantia', 'grupo']], x='receita_media_por_quantia', y='recencia', hue='grupo', palette=palette)
# Out:
# <AxesSubplot:xlabel='receita_media_por_quantia', ylabel='recencia'>

# %%
sns.pairplot(df_new_threshold, hue='grupo', diag_kind='hist', palette=['#3AC3C2', '#6E3AC3', '#AA3AC3'])
plt.show()

# %%
print('Train: \n', classification_report(ytrain, rfr.predict(xtrain)), '\n\nTest:\n')
print(classification_report(ytest, rfr.predict(xtest)))
# Out:
# Train:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      7270
#            1       0.99      0.99      0.99      3980
#            2       1.00      0.99      0.99      1750
#
#     accuracy                           1.00     13000
#    macro avg       1.00      0.99      1.00     13000
# weighted avg       1.00      1.00      1.00     13000
#
#
# Test:
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      3915
#            1       0.99      0.99      0.99      2143
#            2       0.99      0.99      0.99       942
#
#     accuracy                           1.00      7000
#    macro avg       0.99      0.99      0.99      7000
# weighted avg       1.00      1.00      1.00      7000

# %%
predicted_data = scaled_data.copy()
predicted_data = pd.concat([predicted_data, step], axis=1)
predicted_data.rename({1:'grupo'}, axis=1, inplace=True)
step = pd.Series(rfr.predict(predicted_data[predicted_data.grupo.isnull()].drop(columns='grupo')))
step.index = predicted_data[predicted_data.grupo.isnull()].index
dataFrame = pd.concat([predicted_data, step], axis=1)
dataFrame.rename({0:'grupo2'}, inplace=True, axis=1)
dataFrame.loc[dataFrame.grupo.isnull(), 'grupo'] = dataFrame.loc[dataFrame.grupo2.notnull(), 'grupo2']
dataFrame.drop('grupo2', axis=1, inplace=True)
dataFrame = dataFrame.astype({'grupo':int}).astype({'grupo':'category'})
# Out:
# 0        0
# 1        0
# 2        0
# 4        0
# 5        0
#         ..
# 95413    0
# 95415    0
# 95416    2
# 95417    0
# 95419    2
# Length: 75420, dtype: int64

# %%
dataFrame.grupo.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(dataFrame, hue='grupo')

# %%
plt.figure(figsize=(14,8))
sns.barplot(x=rfr.feature_names_in_, y=rfr.feature_importances_.round(3), palette=['#BA90F6', '#A96EFC', '#6B14E6', '#893CF6'])
plt.show()
# Out:
# <AxesSubplot:>

# %%
dataFrame.grupo.value_counts()
# Out:
# 0    53503
# 1    29169
# 2    12748
# Name: grupo, dtype: int64

# %% [markdown]
# #### DESCREVER SEGUNDA ALTERNATIVA

# %%
## Dataset + agrupamentos final

dataFrame['grupo'] = np.select(
    [
        dataFrame['grupo'] == 0,
        dataFrame['grupo'] == 1,
        dataFrame['grupo'] == 2,
    ],
    [
        'ouro',
        'bronze',
        'prata'
    ]
)

# %%
# dataFrame.to_parquet('dataFrame.parquet', index=None)
